# %% [markdown]
# Agrupacion y Segmentacion de Vecindarios de Toronto<a href="#Agrupacion-y-Segmentacion-de-Vecindarios-de-Toronto" class="anchor-link">¶</a>
# -------------------------------------------------------------------------------------------------------------------------------------------
#
# #### Parte 1<a href="#Parte-1" class="anchor-link">¶</a>
#
# In \[1\]:
#
#      !jupyter nbconvert --to html TorontoFinal3.ipynb
#     # Importacion de Librerias necesarias
#
#     [NbConvertApp] Converting notebook TorontoFinal3.ipynb to html
#     [NbConvertApp] Writing 892800 bytes to TorontoFinal3.html
#
# In \[2\]:
#
#     pip install BeautifulSoup4
#
#     Collecting BeautifulSoup4
#       Downloading https://files.pythonhosted.org/packages/d1/41/e6495bd7d3781cee623ce23ea6ac73282a373088fcd0ddc809a047b18eae/beautifulsoup4-4.9.3-py3-none-any.whl (115kB)
#          |████████████████████████████████| 122kB 25.9MB/s eta 0:00:01
#     Collecting soupsieve>1.2; python_version >= "3.0" (from BeautifulSoup4)
#       Downloading https://files.pythonhosted.org/packages/36/69/d82d04022f02733bf9a72bc3b96332d360c0c5307096d76f6bb7489f7e57/soupsieve-2.2.1-py3-none-any.whl
#     Installing collected packages: soupsieve, BeautifulSoup4
#     Successfully installed BeautifulSoup4-4.9.3 soupsieve-2.2.1
#     Note: you may need to restart the kernel to use updated packages.
#
# In \[3\]:
#
#     pip install lxml
#
#     Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.3)
#     Note: you may need to restart the kernel to use updated packages.
#
# In \[4\]:
#
#     from bs4 import BeautifulSoup
#     import requests
#     import pandas as pd
#     import lxml
#
# In \[5\]:
#
#     #Importacion , Scraping y Creacion de Dataframe
#
# In \[6\]:
#
#     url =requests.get ("https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=958430791").text
#
# In \[7\]:
#
#     soup = BeautifulSoup(url,'lxml')
#
# In \[8\]:
#
#     My_table = soup.find('table',{'class':'wikitable sortable'})
#     df = pd.read_html(str(My_table))[0]
#     df.head()
#
# Out\[8\]:
#
# |     | Postal Code | Borough          | Neighborhood              |
# |-----|-------------|------------------|---------------------------|
# | 0   | M1A         | Not assigned     | NaN                       |
# | 1   | M2A         | Not assigned     | NaN                       |
# | 2   | M3A         | North York       | Parkwoods                 |
# | 3   | M4A         | North York       | Victoria Village          |
# | 4   | M5A         | Downtown Toronto | Regent Park, Harbourfront |
#
# In \[9\]:
#
#     # Eliminamos Municipios 'Not assigned'
#
# In \[10\]:
#
#     drop_Not=df[df['Borough']=='Not assigned'].index
#     df.drop (drop_Not, inplace=True)
#     df.reset_index(drop=True, inplace=True)
#
# In \[11\]:
#
#     df.head()
#
# Out\[11\]:
#
# |     | Postal Code | Borough          | Neighborhood                                |
# |-----|-------------|------------------|---------------------------------------------|
# | 0   | M3A         | North York       | Parkwoods                                   |
# | 1   | M4A         | North York       | Victoria Village                            |
# | 2   | M5A         | Downtown Toronto | Regent Park, Harbourfront                   |
# | 3   | M6A         | North York       | Lawrence Manor, Lawrence Heights            |
# | 4   | M7A         | Downtown Toronto | Queen's Park, Ontario Provincial Government |
#
# In \[12\]:
#
#     # Asignamos Vecindarios 'Not assigned' a Municipio
#
# In \[13\]:
#
#     df[df['Neighborhood']=='Not assigned']=df['Borough'].reset_index()
#     df.head()
#
# Out\[13\]:
#
# |     | Postal Code | Borough          | Neighborhood                                |
# |-----|-------------|------------------|---------------------------------------------|
# | 0   | M3A         | North York       | Parkwoods                                   |
# | 1   | M4A         | North York       | Victoria Village                            |
# | 2   | M5A         | Downtown Toronto | Regent Park, Harbourfront                   |
# | 3   | M6A         | North York       | Lawrence Manor, Lawrence Heights            |
# | 4   | M7A         | Downtown Toronto | Queen's Park, Ontario Provincial Government |
#
# In \[14\]:
#
#     # Requerimiento filas-columnas
#
# In \[15\]:
#
#     df.shape
#
# Out\[15\]:
#
#     (103, 3)
#
# #### Parte 2<a href="#Parte-2" class="anchor-link">¶</a>
#
# In \[16\]:
#
#     # Importacion de archivo csv con coordenadas
#
# In \[17\]:
#
#     from io import StringIO
#
#     url = requests.get(' http://cocl.us/Geospatial_data')
#     csv_raw = StringIO(url.text)
#     datos_geo = pd.read_csv(csv_raw)
#
# In \[18\]:
#
#     datos_geo.head()
#
# Out\[18\]:
#
# |     | Postal Code | Latitude  | Longitude  |
# |-----|-------------|-----------|------------|
# | 0   | M1B         | 43.806686 | -79.194353 |
# | 1   | M1C         | 43.784535 | -79.160497 |
# | 2   | M1E         | 43.763573 | -79.188711 |
# | 3   | M1G         | 43.770992 | -79.216917 |
# | 4   | M1H         | 43.773136 | -79.239476 |
#
# In \[19\]:
#
#     # Relacionamos Dataframes
#
# In \[20\]:
#
#     df=pd.merge(df,datos_geo,how='left')
#
# In \[21\]:
#
#     df.head()
#
# Out\[21\]:
#
# |     | Postal Code | Borough          | Neighborhood                                | Latitude  | Longitude  |
# |-----|-------------|------------------|---------------------------------------------|-----------|------------|
# | 0   | M3A         | North York       | Parkwoods                                   | 43.753259 | -79.329656 |
# | 1   | M4A         | North York       | Victoria Village                            | 43.725882 | -79.315572 |
# | 2   | M5A         | Downtown Toronto | Regent Park, Harbourfront                   | 43.654260 | -79.360636 |
# | 3   | M6A         | North York       | Lawrence Manor, Lawrence Heights            | 43.718518 | -79.464763 |
# | 4   | M7A         | Downtown Toronto | Queen's Park, Ontario Provincial Government | 43.662301 | -79.389494 |
#
# #### Parte 3<a href="#Parte-3" class="anchor-link">¶</a>
#
# In \[22\]:
#
#     # Importacion Librerias Necesarias
#
# In \[23\]:
#
#     import numpy as np
#     import json
#     !conda install -c conda-forge geopy --yes
#     from geopy.geocoders import Nominatim
#     from pandas.io.json import json_normalize
#     import matplotlib.pyplot as plt
#     import matplotlib.cm as cm
#     import matplotlib.colors as colors
#     from sklearn.cluster import KMeans
#     import folium
#     print('Librerias importadas')
#
#     Collecting package metadata (current_repodata.json): done
#     Solving environment: done
#
#     ## Package Plan ##
#
#       environment location: /home/jupyterlab/conda/envs/python
#
#       added / updated specs:
#         - geopy
#
#
#     The following packages will be downloaded:
#
#         package                    |            build
#         ---------------------------|-----------------
#         geographiclib-1.52         |     pyhd8ed1ab_0          35 KB  conda-forge
#         geopy-2.2.0                |     pyhd8ed1ab_0          67 KB  conda-forge
#         ------------------------------------------------------------
#                                                Total:         102 KB
#
#     The following NEW packages will be INSTALLED:
#
#       geographiclib      conda-forge/noarch::geographiclib-1.52-pyhd8ed1ab_0
#       geopy              conda-forge/noarch::geopy-2.2.0-pyhd8ed1ab_0
#
#
#
#     Downloading and Extracting Packages
#     geographiclib-1.52   | 35 KB     | ##################################### | 100%
#     geopy-2.2.0          | 67 KB     | ##################################### | 100%
#     Preparing transaction: done
#     Verifying transaction: done
#     Executing transaction: done
#     Librerias importadas
#
# In \[24\]:
#
#     # Filtramos a Municipios que sean ' Toronto '
#
#
#     Tor_d = df[df['Borough'].str.contains('Toronto')].reset_index(drop=True)
#     Tor_d.head()
#
# Out\[24\]:
#
# |     | Postal Code | Borough          | Neighborhood                                | Latitude  | Longitude  |
# |-----|-------------|------------------|---------------------------------------------|-----------|------------|
# | 0   | M5A         | Downtown Toronto | Regent Park, Harbourfront                   | 43.654260 | -79.360636 |
# | 1   | M7A         | Downtown Toronto | Queen's Park, Ontario Provincial Government | 43.662301 | -79.389494 |
# | 2   | M5B         | Downtown Toronto | Garden District, Ryerson                    | 43.657162 | -79.378937 |
# | 3   | M5C         | Downtown Toronto | St. James Town                              | 43.651494 | -79.375418 |
# | 4   | M4E         | East Toronto     | The Beaches                                 | 43.676357 | -79.293031 |
#
# In \[25\]:
#
#     # Obtenemos nro filas
#
#     Tor_d.shape
#
# Out\[25\]:
#
#     (39, 5)
#
# In \[26\]:
#
#     # Obtenemos coordenadas para Toronto
#
#     address = 'Toronto, ON'
#
#     geolocator = Nominatim(user_agent="ny_explorer")
#     location = geolocator.geocode(address)
#     latitude = location.latitude
#     longitude = location.longitude
#     print('Coordenadas Toronto {}, {}.'.format(latitude, longitude))
#
#     Coordenadas Toronto 43.6534817, -79.3839347.
#
# In \[27\]:
#
#     # Creamos mapa de Toronto y añadimos los marcadores
#
#     map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
#
#     for lat, lng, borough, neighborhood in zip(Tor_d['Latitude'], Tor_d['Longitude'], Tor_d['Borough'], Tor_d['Neighborhood']):
#         label = '{}, {}'.format(neighborhood, borough)
#         label = folium.Popup(label, parse_html=True)
#         folium.CircleMarker(
#             [lat, lng],
#             radius=5,
#             popup=label,
#             color='blue',
#             fill=True,
#             fill_color='#3186cc',
#             fill_opacity=2,
#             parse_html=False).add_to(map_Toronto)
#
#     map_Toronto
#
# Out\[27\]:
#
# <span style="color:#565656">Make this Notebook Trusted to load map: File
# -\> Trust Notebook</span>
#
# In \[28\]:
#
#     # Definimos version y credenciales para la API de Foursquare con un limite de 50 devoluciones
#
#     CLIENT_ID = 'DBBPKNBZNEC2JFO4JL13AJOJLMHLHOCOYWGTY5ZXJFXRJXYD'
#     CLIENT_SECRET = 'YA51Q1Y4XHBRUZE1025SHVN3AKMX20MJHBBELS0BANSJWKMA'
#     VERSION = '20180605'
#     LIMIT = 50
#
# In \[29\]:
#
#     # Definimos funcion para obtener los 100 sitios en un radio de 500 mts para cada barrio
#
#     def getNearbyVenues(names, latitudes, longitudes, radius=500):
#
#         venues_list=[]
#         for name, lat, lng in zip(names, latitudes, longitudes):
#             print(name)
#
#             # crear la URL de solicitud de API
#             url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
#                 CLIENT_ID,
#                 CLIENT_SECRET,
#                 VERSION,
#                 lat,
#                 lng,
#                 radius,
#                 LIMIT)
#                     # solicitud GET
#             results = requests.get(url).json()["response"]['groups'][0]['items']
#
#             # regresa solo información relevante de cada sitio cercano
#             venues_list.append([(
#                 name,
#                 lat,
#                 lng,
#                 v['venue']['name'],
#                 v['venue']['location']['lat'],
#                 v['venue']['location']['lng'],
#                 v['venue']['categories'][0]['name']) for v in results])
#
#         nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
#         nearby_venues.columns = ['Neighborhood',
#                       'Neighborhood Latitude',
#                       'Neighborhood Longitude',
#                       'Venue',
#                       'Venue Latitude',
#                       'Venue Longitude',
#                       'Venue Category']
#
#         return(nearby_venues)
#
# In \[30\]:
#
#     # Corremos la funcion getNearbyVenues para cada barrio creando un Dataframe 'Toronto_venues'
#
#     Toronto_venues = getNearbyVenues(names=Tor_d['Neighborhood'],
#                                        latitudes=Tor_d['Latitude'],
#                                        longitudes=Tor_d['Longitude'])
#
#
#     Regent Park, Harbourfront
#     Queen's Park, Ontario Provincial Government
#     Garden District, Ryerson
#     St. James Town
#     The Beaches
#     Berczy Park
#     Central Bay Street
#     Christie
#     Richmond, Adelaide, King
#     Dufferin, Dovercourt Village
#     Harbourfront East, Union Station, Toronto Islands
#     Little Portugal, Trinity
#     The Danforth West, Riverdale
#     Toronto Dominion Centre, Design Exchange
#     Brockton, Parkdale Village, Exhibition Place
#     India Bazaar, The Beaches West
#     Commerce Court, Victoria Hotel
#     Studio District
#     Lawrence Park
#     Roselawn
#     Davisville North
#     Forest Hill North & West, Forest Hill Road Park
#     High Park, The Junction South
#     North Toronto West, Lawrence Park
#     The Annex, North Midtown, Yorkville
#     Parkdale, Roncesvalles
#     Davisville
#     University of Toronto, Harbord
#     Runnymede, Swansea
#     Moore Park, Summerhill East
#     Kensington Market, Chinatown, Grange Park
#     Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
#     CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
#     Rosedale
#     Stn A PO Boxes
#     St. James Town, Cabbagetown
#     First Canadian Place, Underground city
#     Church and Wellesley
#     Business reply mail Processing Centre, South Central Letter Processing Plant Toronto
#
# In \[31\]:
#
#     # mostramos Dataframe y revisamos tamaño
#
#     print(Toronto_venues.shape)
#     Toronto_venues.head()
#
#     (1170, 7)
#
# Out\[31\]:
#
# |     | Neighborhood              | Neighborhood Latitude | Neighborhood Longitude | Venue                  | Venue Latitude | Venue Longitude | Venue Category      |
# |-----|---------------------------|-----------------------|------------------------|------------------------|----------------|-----------------|---------------------|
# | 0   | Regent Park, Harbourfront | 43.65426              | -79.360636             | Roselle Desserts       | 43.653447      | -79.362017      | Bakery              |
# | 1   | Regent Park, Harbourfront | 43.65426              | -79.360636             | Tandem Coffee          | 43.653559      | -79.361809      | Coffee Shop         |
# | 2   | Regent Park, Harbourfront | 43.65426              | -79.360636             | Cooper Koo Family YMCA | 43.653249      | -79.358008      | Distribution Center |
# | 3   | Regent Park, Harbourfront | 43.65426              | -79.360636             | Body Blitz Spa East    | 43.654735      | -79.359874      | Spa                 |
# | 4   | Regent Park, Harbourfront | 43.65426              | -79.360636             | Impact Kitchen         | 43.656369      | -79.356980      | Restaurant          |
#
# In \[32\]:
#
#     # Observemos cuantos sitios se devolvieron por barrio
#
#     Toronto_venues.groupby('Neighborhood').count()
#
# Out\[32\]:
#
# Neighborhood Latitude
#
# Neighborhood Longitude
#
# Venue
#
# Venue Latitude
#
# Venue Longitude
#
# Venue Category
#
# Neighborhood
#
# Berczy Park
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Brockton, Parkdale Village, Exhibition Place
#
# 24
#
# 24
#
# 24
#
# 24
#
# 24
#
# 24
#
# Business reply mail Processing Centre, South Central Letter Processing
# Plant Toronto
#
# 17
#
# 17
#
# 17
#
# 17
#
# 17
#
# 17
#
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst
# Quay, South Niagara, Island airport
#
# 15
#
# 15
#
# 15
#
# 15
#
# 15
#
# 15
#
# Central Bay Street
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Christie
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# 16
#
# Church and Wellesley
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Commerce Court, Victoria Hotel
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Davisville
#
# 36
#
# 36
#
# 36
#
# 36
#
# 36
#
# 36
#
# Davisville North
#
# 9
#
# 9
#
# 9
#
# 9
#
# 9
#
# 9
#
# Dufferin, Dovercourt Village
#
# 14
#
# 14
#
# 14
#
# 14
#
# 14
#
# 14
#
# First Canadian Place, Underground city
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Forest Hill North & West, Forest Hill Road Park
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# Garden District, Ryerson
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Harbourfront East, Union Station, Toronto Islands
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# High Park, The Junction South
#
# 26
#
# 26
#
# 26
#
# 26
#
# 26
#
# 26
#
# India Bazaar, The Beaches West
#
# 20
#
# 20
#
# 20
#
# 20
#
# 20
#
# 20
#
# Kensington Market, Chinatown, Grange Park
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Lawrence Park
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# Little Portugal, Trinity
#
# 41
#
# 41
#
# 41
#
# 41
#
# 41
#
# 41
#
# Moore Park, Summerhill East
#
# 1
#
# 1
#
# 1
#
# 1
#
# 1
#
# 1
#
# North Toronto West, Lawrence Park
#
# 18
#
# 18
#
# 18
#
# 18
#
# 18
#
# 18
#
# Parkdale, Roncesvalles
#
# 14
#
# 14
#
# 14
#
# 14
#
# 14
#
# 14
#
# Queen's Park, Ontario Provincial Government
#
# 33
#
# 33
#
# 33
#
# 33
#
# 33
#
# 33
#
# Regent Park, Harbourfront
#
# 43
#
# 43
#
# 43
#
# 43
#
# 43
#
# 43
#
# Richmond, Adelaide, King
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Rosedale
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# Roselawn
#
# 3
#
# 3
#
# 3
#
# 3
#
# 3
#
# 3
#
# Runnymede, Swansea
#
# 35
#
# 35
#
# 35
#
# 35
#
# 35
#
# 35
#
# St. James Town
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# St. James Town, Cabbagetown
#
# 43
#
# 43
#
# 43
#
# 43
#
# 43
#
# 43
#
# Stn A PO Boxes
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# Studio District
#
# 37
#
# 37
#
# 37
#
# 37
#
# 37
#
# 37
#
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
#
# 14
#
# 14
#
# 14
#
# 14
#
# 14
#
# 14
#
# The Annex, North Midtown, Yorkville
#
# 19
#
# 19
#
# 19
#
# 19
#
# 19
#
# 19
#
# The Beaches
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# 4
#
# The Danforth West, Riverdale
#
# 42
#
# 42
#
# 42
#
# 42
#
# 42
#
# 42
#
# Toronto Dominion Centre, Design Exchange
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# 50
#
# University of Toronto, Harbord
#
# 34
#
# 34
#
# 34
#
# 34
#
# 34
#
# 34

# %% [markdown]
# In \[33\]:
#
#     # Vemos cuantas categorias unicas hay por barrio
#
#     print('There are {} uniques categories.'.format(len(Toronto_venues['Venue Category'].unique())))
#
#     There are 222 uniques categories.

# %% [markdown]
# In \[34\]:
#
#     #Analizamos cada barrio
#
#
#
#     # codificación
#     Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")
#
#     # añadir la columna de barrio de regreso al dataframe
#     Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood']
#
#     # mover la columna de barrio a la primer columna
#     fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
#     Toronto_onehot = Toronto_onehot[fixed_columns]
#
#     Toronto_onehot.shape
#
# Out\[34\]:
#
#     (1170, 222)

# %% [markdown]
# In \[35\]:
#
#     # Agrupamos las filas por barrios tomando el parametro de promedio de ocurrencia de cada categoria
#
#
#     Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()
#     Toronto_grouped
#
# Out\[35\]:
#
# |     | Neighborhood                                      | Yoga Studio | Adult Boutique | Airport  | Airport Food Court | Airport Lounge | Airport Service | Airport Terminal | American Restaurant | Antique Shop | ... | Theme Restaurant | Tibetan Restaurant | Toy / Game Store | Trail   | Train Station | Vegetarian / Vegan Restaurant | Video Game Store | Vietnamese Restaurant | Wine Bar | Wine Shop |
# |-----|---------------------------------------------------|-------------|----------------|----------|--------------------|----------------|-----------------|------------------|---------------------|--------------|-----|------------------|--------------------|------------------|---------|---------------|-------------------------------|------------------|-----------------------|----------|-----------|
# | 0   | Berczy Park                                       | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.020000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 1   | Brockton, Parkdale Village, Exhibition Place      | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 2   | Business reply mail Processing Centre, South C... | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 3   | CN Tower, King and Spadina, Railway Lands, Har... | 0.000000    | 0.00           | 0.066667 | 0.066667           | 0.066667       | 0.133333        | 0.133333         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 4   | Central Bay Street                                | 0.020000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.020000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 5   | Christie                                          | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 6   | Church and Wellesley                              | 0.040000    | 0.02           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.02             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 7   | Commerce Court, Victoria Hotel                    | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.040000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.020000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 8   | Davisville                                        | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.027778         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 9   | Davisville North                                  | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 10  | Dufferin, Dovercourt Village                      | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 11  | First Canadian Place, Underground city            | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.040000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.020000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 12  | Forest Hill North & West, Forest Hill Road Park   | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.25000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 13  | Garden District, Ryerson                          | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 14  | Harbourfront East, Union Station, Toronto Islands | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.02          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 15  | High Park, The Junction South                     | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.038462     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 16  | India Bazaar, The Beaches West                    | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 17  | Kensington Market, Chinatown, Grange Park         | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.060000                      | 0.000000         | 0.040000              | 0.02000  | 0.000000  |
# | 18  | Lawrence Park                                     | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 19  | Little Portugal, Trinity                          | 0.024390    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.048780                      | 0.000000         | 0.048780              | 0.02439  | 0.000000  |
# | 20  | Moore Park, Summerhill East                       | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 21  | North Toronto West, Lawrence Park                 | 0.055556    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 22  | Parkdale, Roncesvalles                            | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 23  | Queen's Park, Ontario Provincial Government       | 0.030303    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.030303                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 24  | Regent Park, Harbourfront                         | 0.023256    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.023256     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.023256  |
# | 25  | Richmond, Adelaide, King                          | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.040000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.020000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 26  | Rosedale                                          | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.25000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 27  | Roselawn                                          | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 28  | Runnymede, Swansea                                | 0.028571    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.028571                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 29  | St. James Town                                    | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.020000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.020000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 30  | St. James Town, Cabbagetown                       | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 31  | Stn A PO Boxes                                    | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.020000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 32  | Studio District                                   | 0.027027    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.054054            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 33  | Summerhill West, Rathnelly, South Hill, Forest... | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.071429            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.071429              | 0.00000  | 0.000000  |
# | 34  | The Annex, North Midtown, Yorkville               | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 35  | The Beaches                                       | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.25000 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 36  | The Danforth West, Riverdale                      | 0.023810    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.023810            | 0.000000     | ... | 0.00             | 0.02381            | 0.000000         | 0.02381 | 0.00          | 0.000000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 37  | Toronto Dominion Centre, Design Exchange          | 0.000000    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.020000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.02          | 0.020000                      | 0.000000         | 0.000000              | 0.00000  | 0.000000  |
# | 38  | University of Toronto, Harbord                    | 0.029412    | 0.00           | 0.000000 | 0.000000           | 0.000000       | 0.000000        | 0.000000         | 0.000000            | 0.000000     | ... | 0.00             | 0.00000            | 0.000000         | 0.00000 | 0.00          | 0.000000                      | 0.029412         | 0.000000              | 0.00000  | 0.000000  |
#
# 39 rows × 222 columns

# %% [markdown]
# In \[36\]:
#
#     #Observamos tamaño Dataframe
#
#     Toronto_grouped.shape
#
# Out\[36\]:
#
#     (39, 222)

# %% [markdown]
# In \[37\]:
#
#     # Visualizamos cada barrio con los 12 lugares mas comunes
#
#     num_top_venues = 12
#
#     for hood in Toronto_grouped['Neighborhood']:
#         print("----"+hood+"----")
#         temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
#         temp.columns = ['venue','freq']
#         temp = temp.iloc[1:]
#         temp['freq'] = temp['freq'].astype(float)
#         temp = temp.round({'freq': 2})
#         print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
#         print('\n')
#
#     ----Berczy Park----
#                           venue  freq
#     0               Coffee Shop  0.06
#     1        Seafood Restaurant  0.04
#     2               Cheese Shop  0.04
#     3              Cocktail Bar  0.04
#     4                  Beer Bar  0.04
#     5                Restaurant  0.04
#     6                    Bakery  0.04
#     7            Farmers Market  0.04
#     8              Concert Hall  0.02
#     9                  Pharmacy  0.02
#     10           Clothing Store  0.02
#     11  Comfort Food Restaurant  0.02
#
#
#     ----Brockton, Parkdale Village, Exhibition Place----
#                          venue  freq
#     0                     Café  0.12
#     1              Coffee Shop  0.08
#     2           Breakfast Spot  0.08
#     3                   Bakery  0.08
#     4        Convenience Store  0.04
#     5                  Stadium  0.04
#     6               Restaurant  0.04
#     7                      Bar  0.04
#     8             Climbing Gym  0.04
#     9       Italian Restaurant  0.04
#     10  Furniture / Home Store  0.04
#     11            Intersection  0.04
#
#
#     ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                        venue  freq
#     0     Light Rail Station  0.12
#     1   Fast Food Restaurant  0.06
#     2          Auto Workshop  0.06
#     3             Comic Shop  0.06
#     4            Pizza Place  0.06
#     5   Gym / Fitness Center  0.06
#     6             Restaurant  0.06
#     7                Butcher  0.06
#     8          Burrito Place  0.06
#     9                Brewery  0.06
#     10            Skate Park  0.06
#     11        Farmers Market  0.06
#
#
#     ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                       venue  freq
#     0       Airport Service  0.13
#     1      Airport Terminal  0.13
#     2       Harbor / Marina  0.07
#     3                   Bar  0.07
#     4   Rental Car Location  0.07
#     5           Coffee Shop  0.07
#     6      Sculpture Garden  0.07
#     7                 Plane  0.07
#     8         Boat or Ferry  0.07
#     9              Boutique  0.07
#     10       Airport Lounge  0.07
#     11              Airport  0.07
#
#
#     ----Central Bay Street----
#                              venue  freq
#     0                  Coffee Shop  0.16
#     1                         Café  0.06
#     2               Sandwich Place  0.06
#     3              Bubble Tea Shop  0.04
#     4           Italian Restaurant  0.04
#     5           Falafel Restaurant  0.02
#     6                    Bookstore  0.02
#     7                 Burger Joint  0.02
#     8    Middle Eastern Restaurant  0.02
#     9           Miscellaneous Shop  0.02
#     10  Modern European Restaurant  0.02
#     11                 Salad Place  0.02
#
#
#     ----Christie----
#                       venue  freq
#     0         Grocery Store  0.25
#     1                  Café  0.19
#     2                  Park  0.12
#     3    Italian Restaurant  0.06
#     4           Candy Store  0.06
#     5            Baby Store  0.06
#     6           Coffee Shop  0.06
#     7    Athletics & Sports  0.06
#     8            Restaurant  0.06
#     9             Nightclub  0.06
#     10  Monument / Landmark  0.00
#     11  Moroccan Restaurant  0.00
#
#
#     ----Church and Wellesley----
#                       venue  freq
#     0           Coffee Shop  0.06
#     1           Yoga Studio  0.04
#     2   Japanese Restaurant  0.04
#     3           Men's Store  0.04
#     4      Sushi Restaurant  0.04
#     5               Gay Bar  0.04
#     6            Restaurant  0.04
#     7              Sake Bar  0.02
#     8    Salon / Barbershop  0.02
#     9                  Café  0.02
#     10        Burrito Place  0.02
#     11     Ramen Restaurant  0.02
#
#
#     ----Commerce Court, Victoria Hotel----
#                       venue  freq
#     0                  Café  0.10
#     1                 Hotel  0.08
#     2           Coffee Shop  0.08
#     3            Restaurant  0.06
#     4    Seafood Restaurant  0.06
#     5                   Gym  0.06
#     6         Deli / Bodega  0.04
#     7                Bakery  0.04
#     8   American Restaurant  0.04
#     9   Japanese Restaurant  0.04
#     10            Gastropub  0.04
#     11             Beer Bar  0.02
#
#
#     ----Davisville----
#                      venue  freq
#     0          Pizza Place  0.11
#     1         Dessert Shop  0.08
#     2       Sandwich Place  0.08
#     3                  Gym  0.06
#     4                 Café  0.06
#     5          Coffee Shop  0.06
#     6   Italian Restaurant  0.06
#     7     Sushi Restaurant  0.06
#     8                 Park  0.03
#     9       Farmers Market  0.03
#     10  Seafood Restaurant  0.03
#     11             Brewery  0.03
#
#
#     ----Davisville North----
#                            venue  freq
#     0                Pizza Place  0.11
#     1                       Park  0.11
#     2          Food & Drink Shop  0.11
#     3             Sandwich Place  0.11
#     4                      Hotel  0.11
#     5           Department Store  0.11
#     6             Breakfast Spot  0.11
#     7       Gym / Fitness Center  0.11
#     8                        Gym  0.11
#     9   Mediterranean Restaurant  0.00
#     10               Men's Store  0.00
#     11       Monument / Landmark  0.00
#
#
#     ----Dufferin, Dovercourt Village----
#                             venue  freq
#     0                    Pharmacy  0.14
#     1                      Bakery  0.14
#     2                 Music Venue  0.07
#     3   Middle Eastern Restaurant  0.07
#     4                        Café  0.07
#     5                 Supermarket  0.07
#     6                         Bar  0.07
#     7                        Bank  0.07
#     8                     Brewery  0.07
#     9                        Park  0.07
#     10              Grocery Store  0.07
#     11       Gym / Fitness Center  0.07
#
#
#     ----First Canadian Place, Underground city----
#                       venue  freq
#     0                  Café  0.12
#     1           Coffee Shop  0.10
#     2            Restaurant  0.06
#     3         Deli / Bodega  0.04
#     4                   Gym  0.04
#     5          Concert Hall  0.04
#     6                 Hotel  0.04
#     7   American Restaurant  0.04
#     8   Japanese Restaurant  0.04
#     9    Seafood Restaurant  0.04
#     10     Asian Restaurant  0.04
#     11       Sandwich Place  0.02
#
#
#     ----Forest Hill North & West, Forest Hill Road Park----
#                                   venue  freq
#     0                              Park  0.25
#     1                     Jewelry Store  0.25
#     2                             Trail  0.25
#     3                  Sushi Restaurant  0.25
#     4                       Yoga Studio  0.00
#     5   Molecular Gastronomy Restaurant  0.00
#     6                  Malay Restaurant  0.00
#     7                            Market  0.00
#     8               Martial Arts School  0.00
#     9          Mediterranean Restaurant  0.00
#     10                      Men's Store  0.00
#     11               Mexican Restaurant  0.00
#
#
#     ----Garden District, Ryerson----
#                          venue  freq
#     0              Coffee Shop  0.08
#     1                     Café  0.06
#     2     Fast Food Restaurant  0.04
#     3           Clothing Store  0.04
#     4           Cosmetics Shop  0.04
#     5                Bookstore  0.04
#     6                  Theater  0.04
#     7         Ramen Restaurant  0.04
#     8                    Diner  0.02
#     9            Movie Theater  0.02
#     10  Furniture / Home Store  0.02
#     11     Sporting Goods Shop  0.02
#
#
#     ----Harbourfront East, Union Station, Toronto Islands----
#                       venue  freq
#     0              Aquarium  0.06
#     1           Coffee Shop  0.04
#     2        Scenic Lookout  0.04
#     3                 Hotel  0.04
#     4           Pizza Place  0.04
#     5                 Plaza  0.04
#     6                  Park  0.04
#     7                  Café  0.04
#     8            Sports Bar  0.02
#     9   Sporting Goods Shop  0.02
#     10  Fried Chicken Joint  0.02
#     11              Brewery  0.02
#
#
#     ----High Park, The Junction South----
#                          venue  freq
#     0          Thai Restaurant  0.08
#     1                     Café  0.08
#     2       Mexican Restaurant  0.08
#     3                   Bakery  0.04
#     4               Restaurant  0.04
#     5   Furniture / Home Store  0.04
#     6                Bookstore  0.04
#     7                      Bar  0.04
#     8                Speakeasy  0.04
#     9     Fast Food Restaurant  0.04
#     10             Music Venue  0.04
#     11      Italian Restaurant  0.04
#
#
#     ----India Bazaar, The Beaches West----
#                        venue  freq
#     0   Fast Food Restaurant  0.05
#     1      Fish & Chips Shop  0.05
#     2          Burrito Place  0.05
#     3          Movie Theater  0.05
#     4     Italian Restaurant  0.05
#     5                    Pub  0.05
#     6           Intersection  0.05
#     7             Steakhouse  0.05
#     8             Restaurant  0.05
#     9            Coffee Shop  0.05
#     10        Ice Cream Shop  0.05
#     11          Liquor Store  0.05
#
#
#     ----Kensington Market, Chinatown, Grange Park----
#                                 venue  freq
#     0                            Café  0.10
#     1                             Bar  0.08
#     2   Vegetarian / Vegan Restaurant  0.06
#     3                          Bakery  0.04
#     4                     Coffee Shop  0.04
#     5              Mexican Restaurant  0.04
#     6                    Burger Joint  0.04
#     7           Vietnamese Restaurant  0.04
#     8                     Fish Market  0.02
#     9                  Farmers Market  0.02
#     10            Filipino Restaurant  0.02
#     11                     Food Court  0.02
#
#
#     ----Lawrence Park----
#                             venue  freq
#     0                        Park  0.25
#     1                    Bus Line  0.25
#     2            Business Service  0.25
#     3                 Swim School  0.25
#     4                 Yoga Studio  0.00
#     5         Monument / Landmark  0.00
#     6                      Market  0.00
#     7         Martial Arts School  0.00
#     8    Mediterranean Restaurant  0.00
#     9                 Men's Store  0.00
#     10         Mexican Restaurant  0.00
#     11  Middle Eastern Restaurant  0.00
#
#
#     ----Little Portugal, Trinity----
#                                 venue  freq
#     0                             Bar  0.12
#     1   Vegetarian / Vegan Restaurant  0.05
#     2                Asian Restaurant  0.05
#     3                     Men's Store  0.05
#     4                      Restaurant  0.05
#     5                            Café  0.05
#     6           Vietnamese Restaurant  0.05
#     7                           Diner  0.02
#     8         New American Restaurant  0.02
#     9                     Coffee Shop  0.02
#     10                   Cocktail Bar  0.02
#     11                           Park  0.02
#
#
#     ----Moore Park, Summerhill East----
#                              venue  freq
#     0                   Restaurant   1.0
#     1                  Yoga Studio   0.0
#     2          Moroccan Restaurant   0.0
#     3             Malay Restaurant   0.0
#     4                       Market   0.0
#     5          Martial Arts School   0.0
#     6     Mediterranean Restaurant   0.0
#     7                  Men's Store   0.0
#     8           Mexican Restaurant   0.0
#     9    Middle Eastern Restaurant   0.0
#     10          Miscellaneous Shop   0.0
#     11  Modern European Restaurant   0.0
#
#
#     ----North Toronto West, Lawrence Park----
#                        venue  freq
#     0            Coffee Shop  0.11
#     1         Clothing Store  0.11
#     2            Yoga Studio  0.06
#     3    Sporting Goods Shop  0.06
#     4         Ice Cream Shop  0.06
#     5   Fast Food Restaurant  0.06
#     6     Mexican Restaurant  0.06
#     7                  Diner  0.06
#     8                   Park  0.06
#     9     Chinese Restaurant  0.06
#     10            Restaurant  0.06
#     11                  Café  0.06
#
#
#     ----Parkdale, Roncesvalles----
#                               venue  freq
#     0                Breakfast Spot  0.14
#     1                     Gift Shop  0.14
#     2                   Coffee Shop  0.07
#     3   Eastern European Restaurant  0.07
#     4                           Bar  0.07
#     5                       Dog Run  0.07
#     6                 Movie Theater  0.07
#     7            Italian Restaurant  0.07
#     8                  Dessert Shop  0.07
#     9                     Bookstore  0.07
#     10                   Restaurant  0.07
#     11             Cuban Restaurant  0.07
#
#
#     ----Queen's Park, Ontario Provincial Government----
#                       venue  freq
#     0           Coffee Shop  0.18
#     1      Sushi Restaurant  0.06
#     2           Yoga Studio  0.03
#     3                  Café  0.03
#     4              Beer Bar  0.03
#     5   Fried Chicken Joint  0.03
#     6                   Spa  0.03
#     7         Burrito Place  0.03
#     8    Mexican Restaurant  0.03
#     9        Sandwich Place  0.03
#     10                 Bank  0.03
#     11          Music Venue  0.03
#
#
#     ----Regent Park, Harbourfront----
#                       venue  freq
#     0           Coffee Shop  0.16
#     1                   Pub  0.07
#     2                Bakery  0.07
#     3                  Park  0.07
#     4        Breakfast Spot  0.05
#     5               Theater  0.05
#     6                  Café  0.05
#     7            Restaurant  0.05
#     8           Event Space  0.02
#     9        Chocolate Shop  0.02
#     10         Dessert Shop  0.02
#     11  Distribution Center  0.02
#
#
#     ----Richmond, Adelaide, King----
#                        venue  freq
#     0            Coffee Shop  0.10
#     1                   Café  0.08
#     2             Steakhouse  0.04
#     3            Pizza Place  0.04
#     4           Concert Hall  0.04
#     5    American Restaurant  0.04
#     6             Restaurant  0.04
#     7        Thai Restaurant  0.04
#     8              Speakeasy  0.02
#     9              Bookstore  0.02
#     10  Brazilian Restaurant  0.02
#     11                Lounge  0.02
#
#
#     ----Rosedale----
#                             venue  freq
#     0                        Park  0.50
#     1                  Playground  0.25
#     2                       Trail  0.25
#     3                 Yoga Studio  0.00
#     4         Monument / Landmark  0.00
#     5            Malay Restaurant  0.00
#     6                      Market  0.00
#     7         Martial Arts School  0.00
#     8    Mediterranean Restaurant  0.00
#     9                 Men's Store  0.00
#     10         Mexican Restaurant  0.00
#     11  Middle Eastern Restaurant  0.00
#
#
#     ----Roselawn----
#                             venue  freq
#     0                        Pool  0.33
#     1                      Garden  0.33
#     2                Home Service  0.33
#     3                 Yoga Studio  0.00
#     4         Moroccan Restaurant  0.00
#     5            Malay Restaurant  0.00
#     6                      Market  0.00
#     7         Martial Arts School  0.00
#     8    Mediterranean Restaurant  0.00
#     9                 Men's Store  0.00
#     10         Mexican Restaurant  0.00
#     11  Middle Eastern Restaurant  0.00
#
#
#     ----Runnymede, Swansea----
#                      venue  freq
#     0                 Café  0.09
#     1          Coffee Shop  0.09
#     2          Pizza Place  0.06
#     3     Sushi Restaurant  0.06
#     4   Italian Restaurant  0.06
#     5                  Pub  0.06
#     6           Comic Shop  0.03
#     7        Burrito Place  0.03
#     8              Butcher  0.03
#     9       Sandwich Place  0.03
#     10          Restaurant  0.03
#     11         Yoga Studio  0.03
#
#
#     ----St. James Town----
#                           venue  freq
#     0                      Café  0.10
#     1            Cosmetics Shop  0.06
#     2               Coffee Shop  0.06
#     3                 Gastropub  0.06
#     4                    Bakery  0.04
#     5                      Park  0.04
#     6        Seafood Restaurant  0.04
#     7                  Creperie  0.04
#     8            Farmers Market  0.04
#     9                 Jazz Club  0.02
#     10                 Beer Bar  0.02
#     11  New American Restaurant  0.02
#
#
#     ----St. James Town, Cabbagetown----
#                      venue  freq
#     0          Coffee Shop  0.09
#     1           Restaurant  0.05
#     2               Bakery  0.05
#     3          Pizza Place  0.05
#     4    Convenience Store  0.05
#     5   Italian Restaurant  0.05
#     6                  Pub  0.05
#     7                 Café  0.05
#     8       Sandwich Place  0.02
#     9         Liquor Store  0.02
#     10         Snack Place  0.02
#     11       Deli / Bodega  0.02
#
#
#     ----Stn A PO Boxes----
#                       venue  freq
#     0                  Café  0.06
#     1           Coffee Shop  0.04
#     2           Cheese Shop  0.04
#     3              Beer Bar  0.04
#     4              Creperie  0.04
#     5    Seafood Restaurant  0.04
#     6                   Pub  0.04
#     7            Restaurant  0.04
#     8                Bakery  0.04
#     9   Japanese Restaurant  0.04
#     10         Cocktail Bar  0.04
#     11       Farmers Market  0.04
#
#
#     ----Studio District----
#                             venue  freq
#     0                 Coffee Shop  0.08
#     1                     Brewery  0.05
#     2                      Bakery  0.05
#     3                   Gastropub  0.05
#     4         American Restaurant  0.05
#     5                        Café  0.05
#     6          Seafood Restaurant  0.03
#     7                   Bookstore  0.03
#     8                        Food  0.03
#     9                 Fish Market  0.03
#     10  Middle Eastern Restaurant  0.03
#     11             Clothing Store  0.03
#
#
#     ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                         venue  freq
#     0             Coffee Shop  0.14
#     1              Restaurant  0.07
#     2        Sushi Restaurant  0.07
#     3     Fried Chicken Joint  0.07
#     4              Bagel Shop  0.07
#     5             Supermarket  0.07
#     6                     Pub  0.07
#     7                    Bank  0.07
#     8     American Restaurant  0.07
#     9      Light Rail Station  0.07
#     10           Liquor Store  0.07
#     11  Vietnamese Restaurant  0.07
#
#
#     ----The Annex, North Midtown, Yorkville----
#                             venue  freq
#     0              Sandwich Place  0.16
#     1                        Café  0.16
#     2                 Coffee Shop  0.11
#     3                 Pizza Place  0.05
#     4                         Pub  0.05
#     5                    Pharmacy  0.05
#     6   Middle Eastern Restaurant  0.05
#     7                Burger Joint  0.05
#     8                Liquor Store  0.05
#     9                  Donut Shop  0.05
#     10          Indian Restaurant  0.05
#     11                  BBQ Joint  0.05
#
#
#     ----The Beaches----
#                             venue  freq
#     0           Health Food Store  0.25
#     1                       Trail  0.25
#     2                         Pub  0.25
#     3                 Yoga Studio  0.00
#     4         Moroccan Restaurant  0.00
#     5            Malay Restaurant  0.00
#     6                      Market  0.00
#     7         Martial Arts School  0.00
#     8    Mediterranean Restaurant  0.00
#     9                 Men's Store  0.00
#     10         Mexican Restaurant  0.00
#     11  Middle Eastern Restaurant  0.00
#
#
#     ----The Danforth West, Riverdale----
#                          venue  freq
#     0         Greek Restaurant  0.17
#     1       Italian Restaurant  0.07
#     2              Coffee Shop  0.07
#     3   Furniture / Home Store  0.05
#     4           Ice Cream Shop  0.05
#     5              Yoga Studio  0.02
#     6          Bubble Tea Shop  0.02
#     7       Frozen Yogurt Shop  0.02
#     8                Juice Bar  0.02
#     9                      Spa  0.02
#     10               Bookstore  0.02
#     11                 Brewery  0.02
#
#
#     ----Toronto Dominion Centre, Design Exchange----
#                       venue  freq
#     0                  Café  0.12
#     1           Coffee Shop  0.12
#     2    Seafood Restaurant  0.06
#     3            Restaurant  0.06
#     4                 Hotel  0.06
#     5                Bakery  0.04
#     6             Gastropub  0.04
#     7   Japanese Restaurant  0.04
#     8              Beer Bar  0.02
#     9                   Bar  0.02
#     10   Mexican Restaurant  0.02
#     11   Basketball Stadium  0.02
#
#
#     ----University of Toronto, Harbord----
#                       venue  freq
#     0                  Café  0.15
#     1                Bakery  0.06
#     2        Sandwich Place  0.06
#     3             Bookstore  0.06
#     4                   Bar  0.06
#     5               Theater  0.06
#     6   Japanese Restaurant  0.06
#     7    Italian Restaurant  0.03
#     8     French Restaurant  0.03
#     9            Beer Store  0.03
#     10             Beer Bar  0.03
#     11           Restaurant  0.03

# %% [markdown]
# In \[38\]:
#
#     # Creamos una funcion para ordenar en forma descendente los lugares
#
#     def return_most_common_venues(row, num_top_venues):
#         row_categories = row.iloc[1:]
#         row_categories_sorted = row_categories.sort_values(ascending=False)
#
#         return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# In \[39\]:
#
#     # mostramos los primeros 12 lugares de cada barrio en un Dataframe nuevo
#
#     num_top_venues = 12
#
#     indicators = ['st', 'nd', 'rd']
#
#     # crear las columnas acorde al numero de sitios populares
#     columns = ['Neighborhood']
#     for ind in np.arange(num_top_venues):
#         try:
#             columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
#         except:
#             columns.append('{}th Most Common Venue'.format(ind+1))
#
#     # crear un nuevo dataframe
#     neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
#     neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']
#
#     for ind in np.arange(Toronto_grouped.shape[0]):
#         neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)
#
#     neighborhoods_venues_sorted.head()
#
# Out\[39\]:
#
# |     | Neighborhood                                      | 1st Most Common Venue | 2nd Most Common Venue | 3rd Most Common Venue | 4th Most Common Venue | 5th Most Common Venue | 6th Most Common Venue | 7th Most Common Venue | 8th Most Common Venue | 9th Most Common Venue | 10th Most Common Venue | 11th Most Common Venue | 12th Most Common Venue |
# |-----|---------------------------------------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|------------------------|------------------------|------------------------|
# | 0   | Berczy Park                                       | Coffee Shop           | Beer Bar              | Farmers Market        | Bakery                | Cocktail Bar          | Seafood Restaurant    | Cheese Shop           | Restaurant            | Clothing Store        | Pub                    | Hotel                  | Bistro                 |
# | 1   | Brockton, Parkdale Village, Exhibition Place      | Café                  | Breakfast Spot        | Bakery                | Coffee Shop           | Climbing Gym          | Burrito Place         | Nightclub             | Restaurant            | Italian Restaurant    | Intersection           | Bar                    | Stadium                |
# | 2   | Business reply mail Processing Centre, South C... | Light Rail Station    | Pizza Place           | Gym / Fitness Center  | Farmers Market        | Auto Workshop         | Restaurant            | Spa                   | Burrito Place         | Butcher               | Fast Food Restaurant   | Comic Shop             | Skate Park             |
# | 3   | CN Tower, King and Spadina, Railway Lands, Har... | Airport Service       | Airport Terminal      | Coffee Shop           | Harbor / Marina       | Plane                 | Rental Car Location   | Sculpture Garden      | Boutique              | Bar                   | Boat or Ferry          | Airport Food Court     | Airport Lounge         |
# | 4   | Central Bay Street                                | Coffee Shop           | Sandwich Place        | Café                  | Italian Restaurant    | Bubble Tea Shop       | Yoga Studio           | Burger Joint          | Indian Restaurant     | Discount Store        | Bookstore              | Diner                  | Salad Place            |

# %% [markdown]
# In \[40\]:
#
#     # establecer el número de agrupaciones en 5
#     kclusters = 5
#
#     Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)
#
#     # ejecutar k-means
#     kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)
#
#     # revisar las etiquetas de las agrupaciones generadas para cada fila del dataframe
#     kmeans.labels_[0:5]
#
# Out\[40\]:
#
#     array([0, 0, 3, 3, 0], dtype=int32)

# %% [markdown]
# In \[41\]:
#
#     # añadir etiquetas
#     neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
#
#     Toronto_merged = Tor_d
#
#     # juntar Toronto_grouped con Toronto_data
#     Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
#     Toronto_merged['Cluster Labels'] = Toronto_merged['Cluster Labels'].fillna("0").astype(int)
#
#
#     Toronto_merged.head() # revisar las ultimas columnas
#
# Out\[41\]:
#
# |     | Postal Code | Borough          | Neighborhood                                | Latitude  | Longitude  | Cluster Labels | 1st Most Common Venue | 2nd Most Common Venue | 3rd Most Common Venue | 4th Most Common Venue | 5th Most Common Venue | 6th Most Common Venue | 7th Most Common Venue | 8th Most Common Venue | 9th Most Common Venue | 10th Most Common Venue | 11th Most Common Venue | 12th Most Common Venue    |
# |-----|-------------|------------------|---------------------------------------------|-----------|------------|----------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|------------------------|------------------------|---------------------------|
# | 0   | M5A         | Downtown Toronto | Regent Park, Harbourfront                   | 43.654260 | -79.360636 | 0              | Coffee Shop           | Pub                   | Bakery                | Park                  | Restaurant            | Breakfast Spot        | Café                  | Theater               | Wine Shop             | Farmers Market         | Performing Arts Venue  | Mexican Restaurant        |
# | 1   | M7A         | Downtown Toronto | Queen's Park, Ontario Provincial Government | 43.662301 | -79.389494 | 0              | Coffee Shop           | Sushi Restaurant      | Yoga Studio           | College Cafeteria     | Spa                   | Smoothie Shop         | Beer Bar              | Sandwich Place        | Burrito Place         | Café                   | College Auditorium     | Music Venue               |
# | 2   | M5B         | Downtown Toronto | Garden District, Ryerson                    | 43.657162 | -79.378937 | 0              | Coffee Shop           | Café                  | Clothing Store        | Bookstore             | Ramen Restaurant      | Theater               | Cosmetics Shop        | Fast Food Restaurant  | Sandwich Place        | Burrito Place          | Shopping Mall          | Hotel                     |
# | 3   | M5C         | Downtown Toronto | St. James Town                              | 43.651494 | -79.375418 | 0              | Café                  | Gastropub             | Cosmetics Shop        | Coffee Shop           | Seafood Restaurant    | Park                  | Bakery                | Creperie              | Farmers Market        | Cocktail Bar           | Department Store       | Middle Eastern Restaurant |
# | 4   | M4E         | East Toronto     | The Beaches                                 | 43.676357 | -79.293031 | 3              | Trail                 | Health Food Store     | Pub                   | Wine Shop             | Cupcake Shop          | Dumpling Restaurant   | Donut Shop            | Doner Restaurant      | Dog Run               | Distribution Center    | Discount Store         | Diner                     |

# %% [markdown]
# In \[42\]:
#
#     # creamos mapa de agrupacion
#     map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)
#
#     # establecer el esquema de color para las agrupaciones
#     x = np.arange(kclusters)
#     ys = [i + x + (i*x)**2 for i in range(kclusters)]
#     colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
#     rainbow = [colors.rgb2hex(i) for i in colors_array]
#
#     # añadir marcadores al mapa
#     markers_colors = []
#     for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
#         label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
#         folium.CircleMarker(
#             [lat, lon],
#             radius=5,
#             popup=label,
#             color=rainbow[cluster-1],
#             fill=True,
#             fill_color=rainbow[cluster-1],
#             fill_opacity=0.7).add_to(map_clusters)
#
#     map_clusters
#
# Out\[42\]:
#
# <span style="color:#565656">Make this Notebook Trusted to load map: File
# -\> Trust Notebook</span>

# %% [markdown]
# In \[43\]:
#
#     # Examinamos las agrupaciones pudiendo observar que categorias distinguen a cada agrupacion

# %% [markdown]
# In \[44\]:
#
#     Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
#
# Out\[44\]:
#
# |     | Neighborhood                                      | Cluster Labels | 1st Most Common Venue | 2nd Most Common Venue | 3rd Most Common Venue         | 4th Most Common Venue | 5th Most Common Venue | 6th Most Common Venue | 7th Most Common Venue | 8th Most Common Venue | 9th Most Common Venue     | 10th Most Common Venue | 11th Most Common Venue  | 12th Most Common Venue    |
# |-----|---------------------------------------------------|----------------|-----------------------|-----------------------|-------------------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|---------------------------|------------------------|-------------------------|---------------------------|
# | 0   | Regent Park, Harbourfront                         | 0              | Coffee Shop           | Pub                   | Bakery                        | Park                  | Restaurant            | Breakfast Spot        | Café                  | Theater               | Wine Shop                 | Farmers Market         | Performing Arts Venue   | Mexican Restaurant        |
# | 1   | Queen's Park, Ontario Provincial Government       | 0              | Coffee Shop           | Sushi Restaurant      | Yoga Studio                   | College Cafeteria     | Spa                   | Smoothie Shop         | Beer Bar              | Sandwich Place        | Burrito Place             | Café                   | College Auditorium      | Music Venue               |
# | 2   | Garden District, Ryerson                          | 0              | Coffee Shop           | Café                  | Clothing Store                | Bookstore             | Ramen Restaurant      | Theater               | Cosmetics Shop        | Fast Food Restaurant  | Sandwich Place            | Burrito Place          | Shopping Mall           | Hotel                     |
# | 3   | St. James Town                                    | 0              | Café                  | Gastropub             | Cosmetics Shop                | Coffee Shop           | Seafood Restaurant    | Park                  | Bakery                | Creperie              | Farmers Market            | Cocktail Bar           | Department Store        | Middle Eastern Restaurant |
# | 5   | Berczy Park                                       | 0              | Coffee Shop           | Beer Bar              | Farmers Market                | Bakery                | Cocktail Bar          | Seafood Restaurant    | Cheese Shop           | Restaurant            | Clothing Store            | Pub                    | Hotel                   | Bistro                    |
# | 6   | Central Bay Street                                | 0              | Coffee Shop           | Sandwich Place        | Café                          | Italian Restaurant    | Bubble Tea Shop       | Yoga Studio           | Burger Joint          | Indian Restaurant     | Discount Store            | Bookstore              | Diner                   | Salad Place               |
# | 7   | Christie                                          | 0              | Grocery Store         | Café                  | Park                          | Candy Store           | Italian Restaurant    | Restaurant            | Athletics & Sports    | Baby Store            | Coffee Shop               | Nightclub              | Dog Run                 | Deli / Bodega             |
# | 8   | Richmond, Adelaide, King                          | 0              | Coffee Shop           | Café                  | Concert Hall                  | Steakhouse            | American Restaurant   | Pizza Place           | Thai Restaurant       | Restaurant            | Gluten-free Restaurant    | Department Store       | Seafood Restaurant      | Salon / Barbershop        |
# | 13  | Toronto Dominion Centre, Design Exchange          | 0              | Café                  | Coffee Shop           | Hotel                         | Restaurant            | Seafood Restaurant    | Japanese Restaurant   | Bakery                | Gastropub             | Beer Bar                  | Speakeasy              | Bar                     | Deli / Bodega             |
# | 14  | Brockton, Parkdale Village, Exhibition Place      | 0              | Café                  | Breakfast Spot        | Bakery                        | Coffee Shop           | Climbing Gym          | Burrito Place         | Nightclub             | Restaurant            | Italian Restaurant        | Intersection           | Bar                     | Stadium                   |
# | 16  | Commerce Court, Victoria Hotel                    | 0              | Café                  | Hotel                 | Coffee Shop                   | Gym                   | Restaurant            | Seafood Restaurant    | Gastropub             | American Restaurant   | Bakery                    | Japanese Restaurant    | Deli / Bodega           | Park                      |
# | 17  | Studio District                                   | 0              | Coffee Shop           | Gastropub             | Bakery                        | Brewery               | Café                  | American Restaurant   | Convenience Store     | Seafood Restaurant    | Cheese Shop               | Clothing Store         | Pet Store               | Comfort Food Restaurant   |
# | 23  | North Toronto West, Lawrence Park                 | 0              | Coffee Shop           | Clothing Store        | Yoga Studio                   | Seafood Restaurant    | Salon / Barbershop    | Diner                 | Spa                   | Sporting Goods Shop   | Restaurant                | Fast Food Restaurant   | Ice Cream Shop          | Mexican Restaurant        |
# | 24  | The Annex, North Midtown, Yorkville               | 0              | Sandwich Place        | Café                  | Coffee Shop                   | History Museum        | Liquor Store          | Burger Joint          | Indian Restaurant     | BBQ Joint             | Middle Eastern Restaurant | Pub                    | Donut Shop              | Park                      |
# | 27  | University of Toronto, Harbord                    | 0              | Café                  | Theater               | Bar                           | Bookstore             | Japanese Restaurant   | Sandwich Place        | Bakery                | Restaurant            | Beer Bar                  | Beer Store             | Italian Restaurant      | Yoga Studio               |
# | 28  | Runnymede, Swansea                                | 0              | Coffee Shop           | Café                  | Italian Restaurant            | Sushi Restaurant      | Pizza Place           | Pub                   | Restaurant            | Falafel Restaurant    | Smoothie Shop             | Indie Movie Theater    | Bookstore               | Sandwich Place            |
# | 30  | Kensington Market, Chinatown, Grange Park         | 0              | Café                  | Bar                   | Vegetarian / Vegan Restaurant | Burger Joint          | Vietnamese Restaurant | Mexican Restaurant    | Coffee Shop           | Bakery                | Cocktail Bar              | Belgian Restaurant     | Comfort Food Restaurant | Italian Restaurant        |
# | 31  | Summerhill West, Rathnelly, South Hill, Forest... | 0              | Coffee Shop           | Fried Chicken Joint   | American Restaurant           | Sushi Restaurant      | Bagel Shop            | Bank                  | Restaurant            | Pizza Place           | Pub                       | Supermarket            | Liquor Store            | Light Rail Station        |
# | 34  | Stn A PO Boxes                                    | 0              | Café                  | Cocktail Bar          | Bakery                        | Coffee Shop           | Creperie              | Cheese Shop           | Pub                   | Restaurant            | Japanese Restaurant       | Beer Bar               | Farmers Market          | Seafood Restaurant        |
# | 35  | St. James Town, Cabbagetown                       | 0              | Coffee Shop           | Restaurant            | Convenience Store             | Pizza Place           | Café                  | Bakery                | Pub                   | Italian Restaurant    | Sandwich Place            | Deli / Bodega          | Japanese Restaurant     | Butcher                   |
# | 36  | First Canadian Place, Underground city            | 0              | Café                  | Coffee Shop           | Restaurant                    | Seafood Restaurant    | Concert Hall          | Gym                   | Deli / Bodega         | Hotel                 | American Restaurant       | Asian Restaurant       | Japanese Restaurant     | Sandwich Place            |

# %% [markdown]
# In \[45\]:
#
#     Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
#
# Out\[45\]:
#
# |     | Neighborhood | Cluster Labels | 1st Most Common Venue | 2nd Most Common Venue | 3rd Most Common Venue | 4th Most Common Venue | 5th Most Common Venue | 6th Most Common Venue | 7th Most Common Venue | 8th Most Common Venue | 9th Most Common Venue | 10th Most Common Venue | 11th Most Common Venue | 12th Most Common Venue |
# |-----|--------------|----------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|------------------------|------------------------|------------------------|
# | 19  | Roselawn     | 1              | Garden                | Pool                  | Home Service          | Wine Shop             | Cupcake Shop          | Dumpling Restaurant   | Donut Shop            | Doner Restaurant      | Dog Run               | Distribution Center    | Discount Store         | Diner                  |

# %% [markdown]
# In \[46\]:
#
#     Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
#
# Out\[46\]:
#
# |     | Neighborhood                | Cluster Labels | 1st Most Common Venue | 2nd Most Common Venue | 3rd Most Common Venue       | 4th Most Common Venue | 5th Most Common Venue | 6th Most Common Venue | 7th Most Common Venue | 8th Most Common Venue | 9th Most Common Venue | 10th Most Common Venue | 11th Most Common Venue | 12th Most Common Venue |
# |-----|-----------------------------|----------------|-----------------------|-----------------------|-----------------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|------------------------|------------------------|------------------------|
# | 29  | Moore Park, Summerhill East | 2              | Restaurant            | College Auditorium    | Eastern European Restaurant | Dumpling Restaurant   | Donut Shop            | Doner Restaurant      | Dog Run               | Distribution Center   | Discount Store        | Diner                  | Dessert Shop           | Department Store       |

# %% [markdown]
# In \[47\]:
#
#     Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
#
# Out\[47\]:
#
# |     | Neighborhood                                      | Cluster Labels | 1st Most Common Venue | 2nd Most Common Venue | 3rd Most Common Venue         | 4th Most Common Venue       | 5th Most Common Venue | 6th Most Common Venue | 7th Most Common Venue | 8th Most Common Venue | 9th Most Common Venue | 10th Most Common Venue | 11th Most Common Venue | 12th Most Common Venue |
# |-----|---------------------------------------------------|----------------|-----------------------|-----------------------|-------------------------------|-----------------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|------------------------|------------------------|------------------------|
# | 4   | The Beaches                                       | 3              | Trail                 | Health Food Store     | Pub                           | Wine Shop                   | Cupcake Shop          | Dumpling Restaurant   | Donut Shop            | Doner Restaurant      | Dog Run               | Distribution Center    | Discount Store         | Diner                  |
# | 9   | Dufferin, Dovercourt Village                      | 3              | Bakery                | Pharmacy              | Middle Eastern Restaurant     | Supermarket                 | Bank                  | Bar                   | Café                  | Gym / Fitness Center  | Grocery Store         | Music Venue            | Park                   | Brewery                |
# | 10  | Harbourfront East, Union Station, Toronto Islands | 3              | Aquarium              | Scenic Lookout        | Plaza                         | Coffee Shop                 | Café                  | Hotel                 | Park                  | Pizza Place           | Bar                   | Baseball Stadium       | Skating Rink           | Basketball Stadium     |
# | 11  | Little Portugal, Trinity                          | 3              | Bar                   | Vietnamese Restaurant | Vegetarian / Vegan Restaurant | Restaurant                  | Café                  | Asian Restaurant      | Men's Store           | Yoga Studio           | Cupcake Shop          | Brewery                | Pizza Place            | Cocktail Bar           |
# | 12  | The Danforth West, Riverdale                      | 3              | Greek Restaurant      | Italian Restaurant    | Coffee Shop                   | Furniture / Home Store      | Ice Cream Shop        | Cosmetics Shop        | Brewery               | Bubble Tea Shop       | Restaurant            | Pub                    | Café                   | Caribbean Restaurant   |
# | 15  | India Bazaar, The Beaches West                    | 3              | Park                  | Fish & Chips Shop     | Brewery                       | Liquor Store                | Burrito Place         | Restaurant            | Italian Restaurant    | Intersection          | Pub                   | Ice Cream Shop         | Steakhouse             | Fast Food Restaurant   |
# | 18  | Lawrence Park                                     | 3              | Park                  | Bus Line              | Swim School                   | Business Service            | Deli / Bodega         | Dumpling Restaurant   | Donut Shop            | Doner Restaurant      | Dog Run               | Distribution Center    | Discount Store         | Diner                  |
# | 20  | Davisville North                                  | 3              | Hotel                 | Gym                   | Department Store              | Sandwich Place              | Food & Drink Shop     | Gym / Fitness Center  | Pizza Place           | Breakfast Spot        | Park                  | Distribution Center    | Dog Run                | Discount Store         |
# | 22  | High Park, The Junction South                     | 3              | Mexican Restaurant    | Café                  | Thai Restaurant               | Italian Restaurant          | Bookstore             | Bar                   | Speakeasy             | Fast Food Restaurant  | Irish Pub             | Discount Store         | Restaurant             | Flea Market            |
# | 25  | Parkdale, Roncesvalles                            | 3              | Gift Shop             | Breakfast Spot        | Cuban Restaurant              | Eastern European Restaurant | Italian Restaurant    | Bar                   | Dog Run               | Dessert Shop          | Restaurant            | Bookstore              | Movie Theater          | Coffee Shop            |
# | 26  | Davisville                                        | 3              | Pizza Place           | Sandwich Place        | Dessert Shop                  | Italian Restaurant          | Coffee Shop           | Café                  | Sushi Restaurant      | Gym                   | Park                  | Restaurant             | Diner                  | Seafood Restaurant     |
# | 32  | CN Tower, King and Spadina, Railway Lands, Har... | 3              | Airport Service       | Airport Terminal      | Coffee Shop                   | Harbor / Marina             | Plane                 | Rental Car Location   | Sculpture Garden      | Boutique              | Bar                   | Boat or Ferry          | Airport Food Court     | Airport Lounge         |
# | 37  | Church and Wellesley                              | 3              | Coffee Shop           | Yoga Studio           | Japanese Restaurant           | Gay Bar                     | Restaurant            | Sushi Restaurant      | Men's Store           | Salon / Barbershop    | Sake Bar              | Burger Joint           | Indian Restaurant      | Distribution Center    |
# | 38  | Business reply mail Processing Centre, South C... | 3              | Light Rail Station    | Pizza Place           | Gym / Fitness Center          | Farmers Market              | Auto Workshop         | Restaurant            | Spa                   | Burrito Place         | Butcher               | Fast Food Restaurant   | Comic Shop             | Skate Park             |

# %% [markdown]
# In \[48\]:
#
#     Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
#
# Out\[48\]:
#
# |     | Neighborhood                                    | Cluster Labels | 1st Most Common Venue | 2nd Most Common Venue | 3rd Most Common Venue | 4th Most Common Venue | 5th Most Common Venue | 6th Most Common Venue | 7th Most Common Venue | 8th Most Common Venue | 9th Most Common Venue | 10th Most Common Venue | 11th Most Common Venue | 12th Most Common Venue |
# |-----|-------------------------------------------------|----------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|-----------------------|------------------------|------------------------|------------------------|
# | 21  | Forest Hill North & West, Forest Hill Road Park | 4              | Park                  | Jewelry Store         | Trail                 | Sushi Restaurant      | Dance Studio          | Dumpling Restaurant   | Donut Shop            | Doner Restaurant      | Dog Run               | Distribution Center    | Discount Store         | Diner                  |
# | 33  | Rosedale                                        | 4              | Park                  | Playground            | Trail                 | Cupcake Shop          | Dumpling Restaurant   | Donut Shop            | Doner Restaurant      | Dog Run               | Distribution Center   | Discount Store         | Diner                  | Dessert Shop           |

# %% [markdown]
# In \[49\]:
#
#     !jupyter trust *.ipynb
#
#     Signing notebook: DS0103ES-Ejercicio-De-Los-Requerimientos-A-La-Recoleccion-py-v2.0_ES.ipynb
#     Signing notebook: DS0103ES-Ejercicio-Del-Problema-al-Enfoque-v2.0_ES (2).ipynb
#     Signing notebook: DV0101ES-Ejercicio-Creacion-de-Mapas-con-Python-py_ES (1).ipynb
#     Signing notebook: DV0101ES-Ejercicio-Creacion-de-Mapas-con-Python-py_ES.ipynb
#     Signing notebook: DV0101ES-Ejercicio-Diagramas-de-Pastel-y-Gráficos-de-Caja-Dispersión-y-Burbuja-py_ES (1).ipynb
#     Signing notebook: ML0101ES-Clas-Decision-Trees-drug-py-v1.ipynb
#     Signing notebook: ML0101ES-Clas-K-Nearest-neighbors-CustCat-py-v1.ipynb
#     Signing notebook: ML0101ES-Clas-Logistic-Reg-churn-py-v1 (1).ipynb
#     Signing notebook: ML0101ES-Clus-Hierarchical-Cars-py-v1.ipynb
#     Signing notebook: ML0101ES-Reg-Mulitple-Linear-Regression-Co2-py-v1.ipynb
#     Signing notebook: ML0101ES-Reg-Simple-Linear-Regression-Co2-py-v1.ipynb
#     Signing notebook: ML0101ES-regresion-polinomica-Co2-py-v1_ES.ipynb
#     Signing notebook: Proyecto Final DC.ipynb
#     Signing notebook: TorontoFinal.ipynb
#     Signing notebook: TorontoFinal2.ipynb
#     Signing notebook: TorontoFinal3.ipynb
#     Signing notebook: TorontoFinal33.ipynb
#     Signing notebook: TorontoFinal333.ipynb
#     Signing notebook: TorontoFinal333fin.ipynb
#     Notebook already signed: TorontoFinal444.ipynb
#     Signing notebook: Untitled.ipynb
#     Signing notebook: Untitled1.ipynb
#     Signing notebook: Untitled10.ipynb
#     Signing notebook: Untitled11.ipynb
#     Signing notebook: Untitled12.ipynb
#     Signing notebook: Untitled13.ipynb
#     Signing notebook: Untitled14.ipynb
#     Signing notebook: Untitled15.ipynb
#     Signing notebook: Untitled16.ipynb
#     Signing notebook: Untitled17.ipynb
#     Signing notebook: Untitled18.ipynb
#     Signing notebook: Untitled19.ipynb
#     Notebook already signed: Untitled2.ipynb
#     Signing notebook: Untitled20.ipynb
#     Signing notebook: Untitled21.ipynb
#     Signing notebook: Untitled22.ipynb
#     Signing notebook: Untitled23.ipynb
#     [TrustNotebookApp] ERROR | Notebook JSON is invalid: Additional properties are not allowed ('execution_count' was unexpected)
#
#     Failed validating 'additionalProperties' in error:
#
#     On instance['cells'][4]['outputs'][0]:
#     {'ename': 'ERROR',
#      'evalue': 'Error in parse(text = x, srcfile = src): <text>:1:5: unexpected '
#                '...',
#      'execution_count': 5,
#      'output_type': 'error',
#      'traceback': ['Error in parse(text = x, srcfile = src): <text>:1:5: '
#                    'unexpected ...']}
#     Signing notebook: Untitled24.ipynb
#     Notebook already signed: Untitled3.ipynb
#     Notebook already signed: Untitled4.ipynb
#     Signing notebook: Untitled5.ipynb
#     Signing notebook: Untitled6.ipynb
#     Signing notebook: Untitled7.ipynb
#     Signing notebook: Untitled8.ipynb
#     Notebook already signed: Untitled9.ipynb
#     Signing notebook: Vecindarios Toronto Final.ipynb
#     Signing notebook: Venta-de-Casas-en-el-Condado-King-EEUU_ES.ipynb
#     Signing notebook: mikibro.ipynb
