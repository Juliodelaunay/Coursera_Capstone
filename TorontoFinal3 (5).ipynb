# %%
## Agrupacion y Segmentacion de Vecindarios de Toronto

# %% [markdown]
# #### Parte 1

# %%
# Importacion de Librerias necesarias

# %%
pip install BeautifulSoup4
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: BeautifulSoup4 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from BeautifulSoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: lxml in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (4.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup  
import requests 
import pandas as pd
import lxml

# %%
#Importacion , Scraping y Creacion de Dataframe

# %%
url =requests.get ("https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=958430791").text

# %%
soup = BeautifulSoup(url,'lxml')

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
df = pd.read_html(str(My_table))[0]
df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned                        NaN
# 1         M2A      Not assigned                        NaN
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Eliminamos Municipios 'Not assigned'

# %%
drop_Not=df[df['Borough']=='Not assigned'].index
df.drop (drop_Not, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Asignamos Vecindarios 'Not assigned' a Municipio

# %%
df[df['Neighborhood']=='Not assigned']=df['Borough'].reset_index()
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Requerimiento filas-columnas

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# #### Parte 2

# %%
# Importacion de archivo csv con coordenadas

# %%
from io import StringIO

url = requests.get(' http://cocl.us/Geospatial_data')
csv_raw = StringIO(url.text)
datos_geo = pd.read_csv(csv_raw)

# %%
datos_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Relacionamos Dataframes

# %%
df=pd.merge(df,datos_geo,how='left')

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# #### Parte 3

# %%
# Importacion Librerias Necesarias

# %%
import numpy as np
import json
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !pip install folium
import folium
print('Librerias importadas')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (1.19.2)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Librerias importadas

# %%
# Filtramos a Municipios que sean ' Toronto '


Tor_d = df[df['Borough'].str.contains('Toronto')].reset_index(drop=True)
Tor_d.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %%
# Obtenemos nro filas 

Tor_d.shape
# Out:
# (39, 5)

# %%
# Obtenemos coordenadas para Toronto

address = 'Toronto, ON'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Coordenadas Toronto {}, {}.'.format(latitude, longitude))
# Out:
# Coordenadas Toronto 43.6534817, -79.3839347.

# %%
# Creamos mapa de Toronto y añadimos los marcadores

map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(Tor_d['Latitude'], Tor_d['Longitude'], Tor_d['Borough'], Tor_d['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=2,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0673c0a015b24fb3a66fbf3ffa77634d%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0673c0a015b24fb3a66fbf3ffa77634d%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0673c0a015b24fb3a66fbf3ffa77634d%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0673c0a015b24fb3a66fbf3ffa77634d%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Definimos version y credenciales para la API de Foursquare con un limite de 50 devoluciones

CLIENT_ID = 'DBBPKNBZNEC2JFO4JL13AJOJLMHLHOCOYWGTY5ZXJFXRJXYD' 
CLIENT_SECRET = 'YA51Q1Y4XHBRUZE1025SHVN3AKMX20MJHBBELS0BANSJWKMA' 
VERSION = '20180605' 
LIMIT = 50

# %%
# Definimos funcion para obtener los 100 sitios en un radio de 500 mts para cada barrio

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # crear la URL de solicitud de API
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
                # solicitud GET
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # regresa solo información relevante de cada sitio cercano
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Corremos la funcion getNearbyVenues para cada barrio creando un Dataframe 'Toronto_venues'

Toronto_venues = getNearbyVenues(names=Tor_d['Neighborhood'],
                                   latitudes=Tor_d['Latitude'],
                                   longitudes=Tor_d['Longitude'])
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# High Park, The Junction South
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
# mostramos Dataframe y revisamos tamaño

print(Toronto_venues.shape)
Toronto_venues.head()
# Out:
# (1172, 7)
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4          Impact Kitchen       43.656369       -79.356980
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4           Restaurant

# %%
# Observemos cuantos sitios se devolvieron por barrio

Toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            50
# Brockton, Parkdale Village, Exhibition Place                           24
# Business reply mail Processing Centre, South Ce...                     16
# CN Tower, King and Spadina, Railway Lands, Harb...                     14
# Central Bay Street                                                     50
# Christie                                                               15
# Church and Wellesley                                                   50
# Commerce Court, Victoria Hotel                                         50
# Davisville                                                             35
# Davisville North                                                       10
# Dufferin, Dovercourt Village                                           15
# First Canadian Place, Underground city                                 50
# Forest Hill North & West, Forest Hill Road Park                         4
# Garden District, Ryerson                                               50
# Harbourfront East, Union Station, Toronto Islands                      50
# High Park, The Junction South                                          26
# India Bazaar, The Beaches West                                         19
# Kensington Market, Chinatown, Grange Park                              50
# Lawrence Park                                                           3
# Little Portugal, Trinity                                               42
# Moore Park, Summerhill East                                             4
# North Toronto West, Lawrence Park                                      18
# Parkdale, Roncesvalles                                                 14
# Queen's Park, Ontario Provincial Government                            30
# Regent Park, Harbourfront                                              47
# Richmond, Adelaide, King                                               50
# Rosedale                                                                4
# Roselawn                                                                3
# Runnymede, Swansea                                                     35
# St. James Town                                                         50
# St. James Town, Cabbagetown                                            45
# Stn A PO Boxes                                                         50
# Studio District                                                        36
# Summerhill West, Rathnelly, South Hill, Forest ...                     13
# The Annex, North Midtown, Yorkville                                    21
# The Beaches                                                             4
# The Danforth West, Riverdale                                           42
# Toronto Dominion Centre, Design Exchange                               50
# University of Toronto, Harbord                                         33
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             50
# Brockton, Parkdale Village, Exhibition Place                            24
# Business reply mail Processing Centre, South Ce...                      16
# CN Tower, King and Spadina, Railway Lands, Harb...                      14
# Central Bay Street                                                      50
# Christie                                                                15
# Church and Wellesley                                                    50
# Commerce Court, Victoria Hotel                                          50
# Davisville                                                              35
# Davisville North                                                        10
# Dufferin, Dovercourt Village                                            15
# First Canadian Place, Underground city                                  50
# Forest Hill North & West, Forest Hill Road Park                          4
# Garden District, Ryerson                                                50
# Harbourfront East, Union Station, Toronto Islands                       50
# High Park, The Junction South                                           26
# India Bazaar, The Beaches West                                          19
# Kensington Market, Chinatown, Grange Park                               50
# Lawrence Park                                                            3
# Little Portugal, Trinity                                                42
# Moore Park, Summerhill East                                              4
# North Toronto West, Lawrence Park                                       18
# Parkdale, Roncesvalles                                                  14
# Queen's Park, Ontario Provincial Government                             30
# Regent Park, Harbourfront                                               47
# Richmond, Adelaide, King                                                50
# Rosedale                                                                 4
# Roselawn                                                                 3
# Runnymede, Swansea                                                      35
# St. James Town                                                          50
# St. James Town, Cabbagetown                                             45
# Stn A PO Boxes                                                          50
# Studio District                                                         36
# Summerhill West, Rathnelly, South Hill, Forest ...                      13
# The Annex, North Midtown, Yorkville                                     21
# The Beaches                                                              4
# The Danforth West, Riverdale                                            42
# Toronto Dominion Centre, Design Exchange                                50
# University of Toronto, Harbord                                          33
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            50              50
# Brockton, Parkdale Village, Exhibition Place           24              24
# Business reply mail Processing Centre, South Ce...     16              16
# CN Tower, King and Spadina, Railway Lands, Harb...     14              14
# Central Bay Street                                     50              50
# Christie                                               15              15
# Church and Wellesley                                   50              50
# Commerce Court, Victoria Hotel                         50              50
# Davisville                                             35              35
# Davisville North                                       10              10
# Dufferin, Dovercourt Village                           15              15
# First Canadian Place, Underground city                 50              50
# Forest Hill North & West, Forest Hill Road Park         4               4
# Garden District, Ryerson                               50              50
# Harbourfront East, Union Station, Toronto Islands      50              50
# High Park, The Junction South                          26              26
# India Bazaar, The Beaches West                         19              19
# Kensington Market, Chinatown, Grange Park              50              50
# Lawrence Park                                           3               3
# Little Portugal, Trinity                               42              42
# Moore Park, Summerhill East                             4               4
# North Toronto West, Lawrence Park                      18              18
# Parkdale, Roncesvalles                                 14              14
# Queen's Park, Ontario Provincial Government            30              30
# Regent Park, Harbourfront                              47              47
# Richmond, Adelaide, King                               50              50
# Rosedale                                                4               4
# Roselawn                                                3               3
# Runnymede, Swansea                                     35              35
# St. James Town                                         50              50
# St. James Town, Cabbagetown                            45              45
# Stn A PO Boxes                                         50              50
# Studio District                                        36              36
# Summerhill West, Rathnelly, South Hill, Forest ...     13              13
# The Annex, North Midtown, Yorkville                    21              21
# The Beaches                                             4               4
# The Danforth West, Riverdale                           42              42
# Toronto Dominion Centre, Design Exchange               50              50
# University of Toronto, Harbord                         33              33
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      50
# Brockton, Parkdale Village, Exhibition Place                     24
# Business reply mail Processing Centre, South Ce...               16
# CN Tower, King and Spadina, Railway Lands, Harb...               14
# Central Bay Street                                               50
# Christie                                                         15
# Church and Wellesley                                             50
# Commerce Court, Victoria Hotel                                   50
# Davisville                                                       35
# Davisville North                                                 10
# Dufferin, Dovercourt Village                                     15
# First Canadian Place, Underground city                           50
# Forest Hill North & West, Forest Hill Road Park                   4
# Garden District, Ryerson                                         50
# Harbourfront East, Union Station, Toronto Islands                50
# High Park, The Junction South                                    26
# India Bazaar, The Beaches West                                   19
# Kensington Market, Chinatown, Grange Park                        50
# Lawrence Park                                                     3
# Little Portugal, Trinity                                         42
# Moore Park, Summerhill East                                       4
# North Toronto West, Lawrence Park                                18
# Parkdale, Roncesvalles                                           14
# Queen's Park, Ontario Provincial Government                      30
# Regent Park, Harbourfront                                        47
# Richmond, Adelaide, King                                         50
# Rosedale                                                          4
# Roselawn                                                          3
# Runnymede, Swansea                                               35
# St. James Town                                                   50
# St. James Town, Cabbagetown                                      45
# Stn A PO Boxes                                                   50
# Studio District                                                  36
# Summerhill West, Rathnelly, South Hill, Forest ...               13
# The Annex, North Midtown, Yorkville                              21
# The Beaches                                                       4
# The Danforth West, Riverdale                                     42
# Toronto Dominion Centre, Design Exchange                         50
# University of Toronto, Harbord                                   33
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     50
# Brockton, Parkdale Village, Exhibition Place                    24
# Business reply mail Processing Centre, South Ce...              16
# CN Tower, King and Spadina, Railway Lands, Harb...              14
# Central Bay Street                                              50
# Christie                                                        15
# Church and Wellesley                                            50
# Commerce Court, Victoria Hotel                                  50
# Davisville                                                      35
# Davisville North                                                10
# Dufferin, Dovercourt Village                                    15
# First Canadian Place, Underground city                          50
# Forest Hill North & West, Forest Hill Road Park                  4
# Garden District, Ryerson                                        50
# Harbourfront East, Union Station, Toronto Islands               50
# High Park, The Junction South                                   26
# India Bazaar, The Beaches West                                  19
# Kensington Market, Chinatown, Grange Park                       50
# Lawrence Park                                                    3
# Little Portugal, Trinity                                        42
# Moore Park, Summerhill East                                      4
# North Toronto West, Lawrence Park                               18
# Parkdale, Roncesvalles                                          14
# Queen's Park, Ontario Provincial Government                     30
# Regent Park, Harbourfront                                       47
# Richmond, Adelaide, King                                        50
# Rosedale                                                         4
# Roselawn                                                         3
# Runnymede, Swansea                                              35
# St. James Town                                                  50
# St. James Town, Cabbagetown                                     45
# Stn A PO Boxes                                                  50
# Studio District                                                 36
# Summerhill West, Rathnelly, South Hill, Forest ...              13
# The Annex, North Midtown, Yorkville                             21
# The Beaches                                                      4
# The Danforth West, Riverdale                                    42
# Toronto Dominion Centre, Design Exchange                        50
# University of Toronto, Harbord                                  33

# %%
# Vemos cuantas categorias unicas hay por barrio

print('There are {} uniques categories.'.format(len(Toronto_venues['Venue Category'].unique())))
# Out:
# There are 217 uniques categories.

# %%
#Analizamos cada barrio



# codificación
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# añadir la columna de barrio de regreso al dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood'] 

# mover la columna de barrio a la primer columna
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_onehot.shape
# Out:
# (1172, 217)

# %%
# Agrupamos las filas por barrios tomando el parametro de promedio de ocurrencia de cada categoria


Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()
Toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio  \
# 0                                         Berczy Park     0.000000
# 1        Brockton, Parkdale Village, Exhibition Place     0.000000
# 2   Business reply mail Processing Centre, South C...     0.000000
# 3   CN Tower, King and Spadina, Railway Lands, Har...     0.000000
# 4                                  Central Bay Street     0.020000
# 5                                            Christie     0.000000
# 6                                Church and Wellesley     0.040000
# 7                      Commerce Court, Victoria Hotel     0.000000
# 8                                          Davisville     0.000000
# 9                                    Davisville North     0.000000
# 10                       Dufferin, Dovercourt Village     0.000000
# 11             First Canadian Place, Underground city     0.000000
# 12    Forest Hill North & West, Forest Hill Road Park     0.000000
# 13                           Garden District, Ryerson     0.000000
# 14  Harbourfront East, Union Station, Toronto Islands     0.000000
# 15                      High Park, The Junction South     0.000000
# 16                     India Bazaar, The Beaches West     0.000000
# 17          Kensington Market, Chinatown, Grange Park     0.000000
# 18                                      Lawrence Park     0.000000
# 19                           Little Portugal, Trinity     0.023810
# 20                        Moore Park, Summerhill East     0.000000
# 21                  North Toronto West, Lawrence Park     0.055556
# 22                             Parkdale, Roncesvalles     0.000000
# 23        Queen's Park, Ontario Provincial Government     0.033333
# 24                          Regent Park, Harbourfront     0.021277
# 25                           Richmond, Adelaide, King     0.000000
# 26                                           Rosedale     0.000000
# 27                                           Roselawn     0.000000
# 28                                 Runnymede, Swansea     0.028571
# 29                                     St. James Town     0.000000
# 30                        St. James Town, Cabbagetown     0.000000
# 31                                     Stn A PO Boxes     0.000000
# 32                                    Studio District     0.027778
# 33  Summerhill West, Rathnelly, South Hill, Forest...     0.000000
# 34                The Annex, North Midtown, Yorkville     0.000000
# 35                                        The Beaches     0.000000
# 36                       The Danforth West, Riverdale     0.023810
# 37           Toronto Dominion Centre, Design Exchange     0.000000
# 38                     University of Toronto, Harbord     0.030303
#
#     Adult Boutique   Airport  Airport Food Court  Airport Lounge  \
# 0             0.00  0.000000            0.000000        0.000000
# 1             0.00  0.000000            0.000000        0.000000
# 2             0.00  0.000000            0.000000        0.000000
# 3             0.00  0.071429            0.071429        0.142857
# 4             0.00  0.000000            0.000000        0.000000
# 5             0.00  0.000000            0.000000        0.000000
# 6             0.02  0.000000            0.000000        0.000000
# 7             0.00  0.000000            0.000000        0.000000
# 8             0.00  0.000000            0.000000        0.000000
# 9             0.00  0.000000            0.000000        0.000000
# 10            0.00  0.000000            0.000000        0.000000
# 11            0.00  0.000000            0.000000        0.000000
# 12            0.00  0.000000            0.000000        0.000000
# 13            0.00  0.000000            0.000000        0.000000
# 14            0.00  0.000000            0.000000        0.000000
# 15            0.00  0.000000            0.000000        0.000000
# 16            0.00  0.000000            0.000000        0.000000
# 17            0.00  0.000000            0.000000        0.000000
# 18            0.00  0.000000            0.000000        0.000000
# 19            0.00  0.000000            0.000000        0.000000
# 20            0.00  0.000000            0.000000        0.000000
# 21            0.00  0.000000            0.000000        0.000000
# 22            0.00  0.000000            0.000000        0.000000
# 23            0.00  0.000000            0.000000        0.000000
# 24            0.00  0.000000            0.000000        0.000000
# 25            0.00  0.000000            0.000000        0.000000
# 26            0.00  0.000000            0.000000        0.000000
# 27            0.00  0.000000            0.000000        0.000000
# 28            0.00  0.000000            0.000000        0.000000
# 29            0.00  0.000000            0.000000        0.000000
# 30            0.00  0.000000            0.000000        0.000000
# 31            0.00  0.000000            0.000000        0.000000
# 32            0.00  0.000000            0.000000        0.000000
# 33            0.00  0.000000            0.000000        0.000000
# 34            0.00  0.000000            0.000000        0.000000
# 35            0.00  0.000000            0.000000        0.000000
# 36            0.00  0.000000            0.000000        0.000000
# 37            0.00  0.000000            0.000000        0.000000
# 38            0.00  0.000000            0.000000        0.000000
#
#     Airport Service  Airport Terminal  American Restaurant  Antique Shop  ...  \
# 0          0.000000          0.000000             0.000000      0.000000  ...
# 1          0.000000          0.000000             0.000000      0.000000  ...
# 2          0.000000          0.000000             0.000000      0.000000  ...
# 3          0.071429          0.142857             0.000000      0.000000  ...
# 4          0.000000          0.000000             0.000000      0.000000  ...
# 5          0.000000          0.000000             0.000000      0.000000  ...
# 6          0.000000          0.000000             0.000000      0.000000  ...
# 7          0.000000          0.000000             0.040000      0.000000  ...
# 8          0.000000          0.000000             0.000000      0.000000  ...
# 9          0.000000          0.000000             0.000000      0.000000  ...
# 10         0.000000          0.000000             0.000000      0.000000  ...
# 11         0.000000          0.000000             0.040000      0.000000  ...
# 12         0.000000          0.000000             0.000000      0.000000  ...
# 13         0.000000          0.000000             0.000000      0.000000  ...
# 14         0.000000          0.000000             0.000000      0.000000  ...
# 15         0.000000          0.000000             0.000000      0.038462  ...
# 16         0.000000          0.000000             0.000000      0.000000  ...
# 17         0.000000          0.000000             0.000000      0.000000  ...
# 18         0.000000          0.000000             0.000000      0.000000  ...
# 19         0.000000          0.000000             0.000000      0.000000  ...
# 20         0.000000          0.000000             0.000000      0.000000  ...
# 21         0.000000          0.000000             0.000000      0.000000  ...
# 22         0.000000          0.000000             0.000000      0.000000  ...
# 23         0.000000          0.000000             0.000000      0.000000  ...
# 24         0.000000          0.000000             0.000000      0.021277  ...
# 25         0.000000          0.000000             0.040000      0.000000  ...
# 26         0.000000          0.000000             0.000000      0.000000  ...
# 27         0.000000          0.000000             0.000000      0.000000  ...
# 28         0.000000          0.000000             0.000000      0.000000  ...
# 29         0.000000          0.000000             0.020000      0.000000  ...
# 30         0.000000          0.000000             0.000000      0.000000  ...
# 31         0.000000          0.000000             0.000000      0.000000  ...
# 32         0.000000          0.000000             0.055556      0.000000  ...
# 33         0.000000          0.000000             0.076923      0.000000  ...
# 34         0.000000          0.000000             0.000000      0.000000  ...
# 35         0.000000          0.000000             0.000000      0.000000  ...
# 36         0.000000          0.000000             0.023810      0.000000  ...
# 37         0.000000          0.000000             0.020000      0.000000  ...
# 38         0.000000          0.000000             0.000000      0.000000  ...
#
#      Theater  Theme Restaurant  Tibetan Restaurant  Toy / Game Store    Trail  \
# 0   0.000000              0.00             0.00000          0.000000  0.00000
# 1   0.000000              0.00             0.00000          0.000000  0.00000
# 2   0.000000              0.00             0.00000          0.000000  0.00000
# 3   0.000000              0.00             0.00000          0.000000  0.00000
# 4   0.000000              0.00             0.00000          0.000000  0.00000
# 5   0.000000              0.00             0.00000          0.000000  0.00000
# 6   0.000000              0.02             0.00000          0.000000  0.00000
# 7   0.000000              0.00             0.00000          0.000000  0.00000
# 8   0.000000              0.00             0.00000          0.057143  0.00000
# 9   0.000000              0.00             0.00000          0.000000  0.00000
# 10  0.000000              0.00             0.00000          0.000000  0.00000
# 11  0.000000              0.00             0.00000          0.000000  0.00000
# 12  0.000000              0.00             0.00000          0.000000  0.25000
# 13  0.040000              0.00             0.00000          0.000000  0.00000
# 14  0.020000              0.00             0.00000          0.000000  0.00000
# 15  0.000000              0.00             0.00000          0.000000  0.00000
# 16  0.000000              0.00             0.00000          0.000000  0.00000
# 17  0.000000              0.00             0.00000          0.000000  0.00000
# 18  0.000000              0.00             0.00000          0.000000  0.00000
# 19  0.023810              0.00             0.00000          0.000000  0.00000
# 20  0.000000              0.00             0.00000          0.000000  0.25000
# 21  0.000000              0.00             0.00000          0.000000  0.00000
# 22  0.000000              0.00             0.00000          0.000000  0.00000
# 23  0.033333              0.00             0.00000          0.000000  0.00000
# 24  0.042553              0.00             0.00000          0.000000  0.00000
# 25  0.000000              0.00             0.00000          0.000000  0.00000
# 26  0.000000              0.00             0.00000          0.000000  0.25000
# 27  0.000000              0.00             0.00000          0.000000  0.00000
# 28  0.000000              0.00             0.00000          0.000000  0.00000
# 29  0.020000              0.00             0.00000          0.000000  0.00000
# 30  0.000000              0.00             0.00000          0.000000  0.00000
# 31  0.000000              0.00             0.00000          0.000000  0.00000
# 32  0.000000              0.00             0.00000          0.000000  0.00000
# 33  0.000000              0.00             0.00000          0.000000  0.00000
# 34  0.000000              0.00             0.00000          0.000000  0.00000
# 35  0.000000              0.00             0.00000          0.000000  0.25000
# 36  0.000000              0.00             0.02381          0.000000  0.02381
# 37  0.000000              0.00             0.00000          0.000000  0.00000
# 38  0.030303              0.00             0.00000          0.000000  0.00000
#
#     Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0            0.00                       0.020000          0.000000
# 1            0.00                       0.000000          0.000000
# 2            0.00                       0.000000          0.000000
# 3            0.00                       0.000000          0.000000
# 4            0.00                       0.020000          0.000000
# 5            0.00                       0.000000          0.000000
# 6            0.00                       0.000000          0.000000
# 7            0.00                       0.020000          0.000000
# 8            0.00                       0.000000          0.000000
# 9            0.00                       0.000000          0.000000
# 10           0.00                       0.000000          0.000000
# 11           0.00                       0.020000          0.000000
# 12           0.00                       0.000000          0.000000
# 13           0.00                       0.000000          0.000000
# 14           0.02                       0.000000          0.000000
# 15           0.00                       0.000000          0.000000
# 16           0.00                       0.000000          0.000000
# 17           0.00                       0.060000          0.000000
# 18           0.00                       0.000000          0.000000
# 19           0.00                       0.023810          0.000000
# 20           0.00                       0.000000          0.000000
# 21           0.00                       0.000000          0.000000
# 22           0.00                       0.000000          0.000000
# 23           0.00                       0.000000          0.000000
# 24           0.00                       0.000000          0.000000
# 25           0.00                       0.020000          0.000000
# 26           0.00                       0.000000          0.000000
# 27           0.00                       0.000000          0.000000
# 28           0.00                       0.028571          0.000000
# 29           0.00                       0.020000          0.000000
# 30           0.00                       0.000000          0.000000
# 31           0.00                       0.020000          0.000000
# 32           0.00                       0.000000          0.000000
# 33           0.00                       0.000000          0.000000
# 34           0.00                       0.000000          0.000000
# 35           0.00                       0.000000          0.000000
# 36           0.00                       0.000000          0.000000
# 37           0.02                       0.020000          0.000000
# 38           0.00                       0.000000          0.030303
#
#     Vietnamese Restaurant  Wine Bar
# 0                0.000000   0.00000
# 1                0.000000   0.00000
# 2                0.000000   0.00000
# 3                0.000000   0.00000
# 4                0.000000   0.00000
# 5                0.000000   0.00000
# 6                0.000000   0.00000
# 7                0.000000   0.00000
# 8                0.000000   0.00000
# 9                0.000000   0.00000
# 10               0.000000   0.00000
# 11               0.000000   0.00000
# 12               0.000000   0.00000
# 13               0.000000   0.00000
# 14               0.000000   0.00000
# 15               0.000000   0.00000
# 16               0.000000   0.00000
# 17               0.040000   0.02000
# 18               0.000000   0.00000
# 19               0.047619   0.02381
# 20               0.000000   0.00000
# 21               0.000000   0.00000
# 22               0.000000   0.00000
# 23               0.000000   0.00000
# 24               0.000000   0.00000
# 25               0.000000   0.00000
# 26               0.000000   0.00000
# 27               0.000000   0.00000
# 28               0.000000   0.00000
# 29               0.000000   0.00000
# 30               0.000000   0.00000
# 31               0.000000   0.00000
# 32               0.000000   0.00000
# 33               0.076923   0.00000
# 34               0.000000   0.00000
# 35               0.000000   0.00000
# 36               0.000000   0.00000
# 37               0.000000   0.00000
# 38               0.000000   0.00000
#
# [39 rows x 217 columns]

# %%
#Observamos tamaño Dataframe

Toronto_grouped.shape
# Out:
# (39, 217)

# %%
# Visualizamos cada barrio con los 12 lugares mas comunes

num_top_venues = 12

for hood in Toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                   venue  freq
# 0           Coffee Shop  0.06
# 1              Beer Bar  0.04
# 2            Restaurant  0.04
# 3                Bakery  0.04
# 4          Cocktail Bar  0.04
# 5        Farmers Market  0.04
# 6    Seafood Restaurant  0.04
# 7           Cheese Shop  0.04
# 8   Moroccan Restaurant  0.02
# 9                 Hotel  0.02
# 10           Steakhouse  0.02
# 11               Bistro  0.02
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#                     venue  freq
# 0                    Café  0.12
# 1             Coffee Shop  0.08
# 2          Breakfast Spot  0.08
# 3                  Bakery  0.08
# 4           Grocery Store  0.04
# 5      Italian Restaurant  0.04
# 6       Convenience Store  0.04
# 7   Performing Arts Venue  0.04
# 8                     Gym  0.04
# 9               Nightclub  0.04
# 10             Restaurant  0.04
# 11           Climbing Gym  0.04
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                    venue  freq
# 0     Light Rail Station  0.12
# 1            Pizza Place  0.06
# 2                 Garden  0.06
# 3                   Park  0.06
# 4             Restaurant  0.06
# 5          Burrito Place  0.06
# 6                Brewery  0.06
# 7             Skate Park  0.06
# 8         Farmers Market  0.06
# 9   Fast Food Restaurant  0.06
# 10                   Spa  0.06
# 11         Auto Workshop  0.06
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                   venue  freq
# 0        Airport Lounge  0.14
# 1      Airport Terminal  0.14
# 2              Boutique  0.07
# 3       Harbor / Marina  0.07
# 4   Rental Car Location  0.07
# 5           Coffee Shop  0.07
# 6      Sculpture Garden  0.07
# 7         Boat or Ferry  0.07
# 8                 Plane  0.07
# 9       Airport Service  0.07
# 10              Airport  0.07
# 11   Airport Food Court  0.07
#
#
# ----Central Bay Street----
#                       venue  freq
# 0               Coffee Shop  0.16
# 1            Sandwich Place  0.06
# 2                      Café  0.04
# 3        Italian Restaurant  0.04
# 4           Bubble Tea Shop  0.04
# 5               Yoga Studio  0.02
# 6   New American Restaurant  0.02
# 7               Salad Place  0.02
# 8     Portuguese Restaurant  0.02
# 9                Poke Place  0.02
# 10                     Park  0.02
# 11                   Office  0.02
#
#
# ----Christie----
#                         venue  freq
# 0               Grocery Store  0.27
# 1                        Café  0.20
# 2                        Park  0.13
# 3                   Nightclub  0.07
# 4                 Coffee Shop  0.07
# 5                 Candy Store  0.07
# 6                  Baby Store  0.07
# 7                  Restaurant  0.07
# 8          Italian Restaurant  0.07
# 9         Monument / Landmark  0.00
# 10  Middle Eastern Restaurant  0.00
# 11         Miscellaneous Shop  0.00
#
#
# ----Church and Wellesley----
#                   venue  freq
# 0           Coffee Shop  0.06
# 1           Yoga Studio  0.04
# 2               Gay Bar  0.04
# 3           Men's Store  0.04
# 4      Sushi Restaurant  0.04
# 5            Restaurant  0.04
# 6   Japanese Restaurant  0.04
# 7            Smoke Shop  0.02
# 8       Bubble Tea Shop  0.02
# 9                 Diner  0.02
# 10        Burrito Place  0.02
# 11  Martial Arts School  0.02
#
#
# ----Commerce Court, Victoria Hotel----
#                   venue  freq
# 0                  Café  0.10
# 1           Coffee Shop  0.08
# 2                 Hotel  0.08
# 3            Restaurant  0.08
# 4                   Gym  0.06
# 5    Seafood Restaurant  0.06
# 6         Deli / Bodega  0.04
# 7                Bakery  0.04
# 8             Gastropub  0.04
# 9   Japanese Restaurant  0.04
# 10  American Restaurant  0.04
# 11                  Pub  0.02
#
#
# ----Davisville----
#                  venue  freq
# 0          Pizza Place  0.09
# 1       Sandwich Place  0.09
# 2         Dessert Shop  0.09
# 3                  Gym  0.06
# 4          Coffee Shop  0.06
# 5   Italian Restaurant  0.06
# 6     Sushi Restaurant  0.06
# 7                 Café  0.06
# 8     Toy / Game Store  0.06
# 9     Greek Restaurant  0.03
# 10               Diner  0.03
# 11            Pharmacy  0.03
#
#
# ----Davisville North----
#                        venue  freq
# 0                Pizza Place   0.1
# 1                 Playground   0.1
# 2           Department Store   0.1
# 3             Sandwich Place   0.1
# 4                      Hotel   0.1
# 5          Food & Drink Shop   0.1
# 6             Breakfast Spot   0.1
# 7       Gym / Fitness Center   0.1
# 8                        Gym   0.1
# 9                       Park   0.1
# 10  Mediterranean Restaurant   0.0
# 11               Men's Store   0.0
#
#
# ----Dufferin, Dovercourt Village----
#                         venue  freq
# 0                      Bakery  0.13
# 1                    Pharmacy  0.13
# 2               Grocery Store  0.07
# 3                        Park  0.07
# 4       Portuguese Restaurant  0.07
# 5                 Music Venue  0.07
# 6   Middle Eastern Restaurant  0.07
# 7                        Café  0.07
# 8                     Brewery  0.07
# 9                 Supermarket  0.07
# 10                        Bar  0.07
# 11                       Bank  0.07
#
#
# ----First Canadian Place, Underground city----
#                   venue  freq
# 0                  Café  0.12
# 1           Coffee Shop  0.10
# 2            Restaurant  0.06
# 3         Deli / Bodega  0.04
# 4                   Gym  0.04
# 5          Concert Hall  0.04
# 6   American Restaurant  0.04
# 7   Japanese Restaurant  0.04
# 8                 Hotel  0.04
# 9    Seafood Restaurant  0.04
# 10            Bookstore  0.02
# 11            Speakeasy  0.02
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#                        venue  freq
# 0                       Park  0.25
# 1                      Trail  0.25
# 2              Jewelry Store  0.25
# 3           Sushi Restaurant  0.25
# 4                Yoga Studio  0.00
# 5         Miscellaneous Shop  0.00
# 6                     Lounge  0.00
# 7           Malay Restaurant  0.00
# 8                     Market  0.00
# 9        Martial Arts School  0.00
# 10  Mediterranean Restaurant  0.00
# 11               Men's Store  0.00
#
#
# ----Garden District, Ryerson----
#                    venue  freq
# 0            Coffee Shop  0.08
# 1                   Café  0.06
# 2   Fast Food Restaurant  0.04
# 3              Bookstore  0.04
# 4         Cosmetics Shop  0.04
# 5       Ramen Restaurant  0.04
# 6                Theater  0.04
# 7         Clothing Store  0.04
# 8             Restaurant  0.02
# 9                   Lake  0.02
# 10                 Diner  0.02
# 11         Burrito Place  0.02
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                   venue  freq
# 0              Aquarium  0.06
# 1                  Park  0.04
# 2           Coffee Shop  0.04
# 3        Scenic Lookout  0.04
# 4                 Hotel  0.04
# 5                  Café  0.04
# 6                 Plaza  0.04
# 7               Brewery  0.04
# 8           Pizza Place  0.04
# 9   Fried Chicken Joint  0.02
# 10                 Lake  0.02
# 11               Bistro  0.02
#
#
# ----High Park, The Junction South----
#                         venue  freq
# 0                        Café  0.08
# 1          Mexican Restaurant  0.08
# 2         Arts & Crafts Store  0.08
# 3             Thai Restaurant  0.08
# 4                   Gastropub  0.04
# 5   Cajun / Creole Restaurant  0.04
# 6                 Flea Market  0.04
# 7                   Speakeasy  0.04
# 8                   Bookstore  0.04
# 9         Fried Chicken Joint  0.04
# 10     Furniture / Home Store  0.04
# 11                 Restaurant  0.04
#
#
# ----India Bazaar, The Beaches West----
#                    venue  freq
# 0           Liquor Store  0.05
# 1     Italian Restaurant  0.05
# 2              Pet Store  0.05
# 3            Pizza Place  0.05
# 4          Movie Theater  0.05
# 5            Coffee Shop  0.05
# 6                    Pub  0.05
# 7             Restaurant  0.05
# 8         Sandwich Place  0.05
# 9          Burrito Place  0.05
# 10               Brewery  0.05
# 11  Fast Food Restaurant  0.05
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                             venue  freq
# 0                            Café  0.10
# 1   Vegetarian / Vegan Restaurant  0.06
# 2                             Bar  0.06
# 3           Vietnamese Restaurant  0.04
# 4                    Burger Joint  0.04
# 5              Mexican Restaurant  0.04
# 6                          Bakery  0.04
# 7                     Coffee Shop  0.04
# 8            Caribbean Restaurant  0.04
# 9                        Wine Bar  0.02
# 10                    Cheese Shop  0.02
# 11                     Food Truck  0.02
#
#
# ----Lawrence Park----
#                          venue  freq
# 0                         Park  0.33
# 1                     Bus Line  0.33
# 2                  Swim School  0.33
# 3                  Yoga Studio  0.00
# 4   Modern European Restaurant  0.00
# 5             Malay Restaurant  0.00
# 6                       Market  0.00
# 7          Martial Arts School  0.00
# 8     Mediterranean Restaurant  0.00
# 9                  Men's Store  0.00
# 10               Metro Station  0.00
# 11          Mexican Restaurant  0.00
#
#
# ----Little Portugal, Trinity----
#                     venue  freq
# 0                     Bar  0.12
# 1        Asian Restaurant  0.05
# 2              Restaurant  0.05
# 3             Coffee Shop  0.05
# 4             Men's Store  0.05
# 5                    Café  0.05
# 6   Vietnamese Restaurant  0.05
# 7             Record Shop  0.02
# 8          Ice Cream Shop  0.02
# 9            Cocktail Bar  0.02
# 10       Cuban Restaurant  0.02
# 11           Cupcake Shop  0.02
#
#
# ----Moore Park, Summerhill East----
#                        venue  freq
# 0                       Park  0.25
# 1                 Playground  0.25
# 2                      Trail  0.25
# 3                 Restaurant  0.25
# 4                     Office  0.00
# 5               Noodle House  0.00
# 6                     Lounge  0.00
# 7           Malay Restaurant  0.00
# 8                     Market  0.00
# 9        Martial Arts School  0.00
# 10  Mediterranean Restaurant  0.00
# 11               Men's Store  0.00
#
#
# ----North Toronto West, Lawrence Park----
#                  venue  freq
# 0          Coffee Shop  0.11
# 1       Clothing Store  0.11
# 2          Yoga Studio  0.06
# 3           Bagel Shop  0.06
# 4                 Park  0.06
# 5                Diner  0.06
# 6   Chinese Restaurant  0.06
# 7           Restaurant  0.06
# 8   Salon / Barbershop  0.06
# 9                 Café  0.06
# 10  Mexican Restaurant  0.06
# 11          Shoe Store  0.06
#
#
# ----Parkdale, Roncesvalles----
#                           venue  freq
# 0                     Gift Shop  0.14
# 1                Breakfast Spot  0.14
# 2            Italian Restaurant  0.07
# 3              Cuban Restaurant  0.07
# 4                   Coffee Shop  0.07
# 5                  Dessert Shop  0.07
# 6                    Restaurant  0.07
# 7                 Movie Theater  0.07
# 8                       Dog Run  0.07
# 9   Eastern European Restaurant  0.07
# 10                          Bar  0.07
# 11                    Bookstore  0.07
#
#
# ----Queen's Park, Ontario Provincial Government----
#                  venue  freq
# 0          Coffee Shop  0.20
# 1     Sushi Restaurant  0.07
# 2          Yoga Studio  0.03
# 3             Beer Bar  0.03
# 4        Smoothie Shop  0.03
# 5        Burrito Place  0.03
# 6                 Café  0.03
# 7       Sandwich Place  0.03
# 8   College Auditorium  0.03
# 9    College Cafeteria  0.03
# 10            Creperie  0.03
# 11                Park  0.03
#
#
# ----Regent Park, Harbourfront----
#                 venue  freq
# 0         Coffee Shop  0.17
# 1              Bakery  0.06
# 2                 Pub  0.06
# 3                Park  0.06
# 4             Theater  0.04
# 5      Breakfast Spot  0.04
# 6                Café  0.04
# 7          Restaurant  0.04
# 8      Cosmetics Shop  0.02
# 9          Shoe Store  0.02
# 10     Chocolate Shop  0.02
# 11  Health Food Store  0.02
#
#
# ----Richmond, Adelaide, King----
#                        venue  freq
# 0                Coffee Shop  0.10
# 1                       Café  0.08
# 2            Thai Restaurant  0.04
# 3                 Steakhouse  0.04
# 4                Pizza Place  0.04
# 5        American Restaurant  0.04
# 6               Concert Hall  0.04
# 7                 Restaurant  0.04
# 8   Mediterranean Restaurant  0.02
# 9                  Bookstore  0.02
# 10      Brazilian Restaurant  0.02
# 11                    Lounge  0.02
#
#
# ----Rosedale----
#                          venue  freq
# 0                         Park  0.50
# 1                   Playground  0.25
# 2                        Trail  0.25
# 3                  Yoga Studio  0.00
# 4   Modern European Restaurant  0.00
# 5                       Lounge  0.00
# 6             Malay Restaurant  0.00
# 7                       Market  0.00
# 8          Martial Arts School  0.00
# 9     Mediterranean Restaurant  0.00
# 10                 Men's Store  0.00
# 11               Metro Station  0.00
#
#
# ----Roselawn----
#                               venue  freq
# 0           Health & Beauty Service  0.33
# 1                            Garden  0.33
# 2                       Music Venue  0.33
# 3                       Yoga Studio  0.00
# 4   Molecular Gastronomy Restaurant  0.00
# 5                  Malay Restaurant  0.00
# 6                            Market  0.00
# 7               Martial Arts School  0.00
# 8          Mediterranean Restaurant  0.00
# 9                       Men's Store  0.00
# 10                    Metro Station  0.00
# 11               Mexican Restaurant  0.00
#
#
# ----Runnymede, Swansea----
#                  venue  freq
# 0                 Café  0.09
# 1          Coffee Shop  0.09
# 2     Sushi Restaurant  0.06
# 3                  Pub  0.06
# 4   Italian Restaurant  0.06
# 5          Pizza Place  0.06
# 6        Smoothie Shop  0.03
# 7           Restaurant  0.03
# 8            Bookstore  0.03
# 9   Falafel Restaurant  0.03
# 10                 Spa  0.03
# 11   Electronics Store  0.03
#
#
# ----St. James Town----
#                   venue  freq
# 0                  Café  0.10
# 1             Gastropub  0.06
# 2           Coffee Shop  0.06
# 3        Cosmetics Shop  0.06
# 4    Seafood Restaurant  0.04
# 5                  Park  0.04
# 6                Bakery  0.04
# 7        Farmers Market  0.04
# 8   Japanese Restaurant  0.04
# 9              Creperie  0.04
# 10     Department Store  0.02
# 11            Bookstore  0.02
#
#
# ----St. James Town, Cabbagetown----
#                  venue  freq
# 0           Restaurant  0.07
# 1          Coffee Shop  0.07
# 2                 Café  0.07
# 3                 Park  0.04
# 4            Pet Store  0.04
# 5          Pizza Place  0.04
# 6               Bakery  0.04
# 7   Italian Restaurant  0.04
# 8                  Pub  0.04
# 9   Chinese Restaurant  0.04
# 10      Sandwich Place  0.02
# 11         Snack Place  0.02
#
#
# ----Stn A PO Boxes----
#                   venue  freq
# 0                  Café  0.06
# 1           Coffee Shop  0.04
# 2            Restaurant  0.04
# 3    Seafood Restaurant  0.04
# 4                Bakery  0.04
# 5           Cheese Shop  0.04
# 6          Cocktail Bar  0.04
# 7   Japanese Restaurant  0.04
# 8        Farmers Market  0.04
# 9              Beer Bar  0.04
# 10                  Pub  0.04
# 11             Creperie  0.04
#
#
# ----Studio District----
#                         venue  freq
# 0                 Coffee Shop  0.08
# 1                     Brewery  0.06
# 2                      Bakery  0.06
# 3                   Gastropub  0.06
# 4         American Restaurant  0.06
# 5                        Café  0.06
# 6   Middle Eastern Restaurant  0.03
# 7   Latin American Restaurant  0.03
# 8                   Bookstore  0.03
# 9                 Fish Market  0.03
# 10         Seafood Restaurant  0.03
# 11                Cheese Shop  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                     venue  freq
# 0             Coffee Shop  0.15
# 1            Liquor Store  0.08
# 2             Supermarket  0.08
# 3                    Bank  0.08
# 4              Restaurant  0.08
# 5     Fried Chicken Joint  0.08
# 6                     Pub  0.08
# 7        Sushi Restaurant  0.08
# 8     American Restaurant  0.08
# 9             Pizza Place  0.08
# 10     Light Rail Station  0.08
# 11  Vietnamese Restaurant  0.08
#
#
# ----The Annex, North Midtown, Yorkville----
#                         venue  freq
# 0              Sandwich Place  0.14
# 1                        Café  0.14
# 2                 Coffee Shop  0.10
# 3                    Pharmacy  0.05
# 4                 Flower Shop  0.05
# 5                   BBQ Joint  0.05
# 6           Indian Restaurant  0.05
# 7                  Donut Shop  0.05
# 8                         Pub  0.05
# 9   Middle Eastern Restaurant  0.05
# 10             History Museum  0.05
# 11               Liquor Store  0.05
#
#
# ----The Beaches----
#                               venue  freq
# 0                             Trail  0.25
# 1                 Health Food Store  0.25
# 2                               Pub  0.25
# 3                       Yoga Studio  0.00
# 4   Molecular Gastronomy Restaurant  0.00
# 5                  Malay Restaurant  0.00
# 6                            Market  0.00
# 7               Martial Arts School  0.00
# 8          Mediterranean Restaurant  0.00
# 9                       Men's Store  0.00
# 10                    Metro Station  0.00
# 11               Mexican Restaurant  0.00
#
#
# ----The Danforth West, Riverdale----
#                      venue  freq
# 0         Greek Restaurant  0.17
# 1              Coffee Shop  0.10
# 2       Italian Restaurant  0.07
# 3           Ice Cream Shop  0.05
# 4   Furniture / Home Store  0.05
# 5              Yoga Studio  0.02
# 6       Frozen Yogurt Shop  0.02
# 7                Juice Bar  0.02
# 8                      Spa  0.02
# 9                Bookstore  0.02
# 10                 Brewery  0.02
# 11         Bubble Tea Shop  0.02
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                   venue  freq
# 0                  Café  0.12
# 1           Coffee Shop  0.12
# 2    Seafood Restaurant  0.06
# 3            Restaurant  0.06
# 4                 Hotel  0.06
# 5                Bakery  0.04
# 6             Gastropub  0.04
# 7   Japanese Restaurant  0.04
# 8            Steakhouse  0.02
# 9          Concert Hall  0.02
# 10       Sandwich Place  0.02
# 11             Beer Bar  0.02
#
#
# ----University of Toronto, Harbord----
#                     venue  freq
# 0                    Café  0.15
# 1                  Bakery  0.06
# 2     Japanese Restaurant  0.06
# 3               Bookstore  0.06
# 4          Sandwich Place  0.06
# 5                     Bar  0.06
# 6             Yoga Studio  0.03
# 7   College Arts Building  0.03
# 8                Beer Bar  0.03
# 9              Beer Store  0.03
# 10             Restaurant  0.03
# 11            College Gym  0.03

# %%
# Creamos una funcion para ordenar en forma descendente los lugares

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# mostramos los primeros 12 lugares de cada barrio en un Dataframe nuevo

num_top_venues = 12

indicators = ['st', 'nd', 'rd']

# crear las columnas acorde al numero de sitios populares
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# crear un nuevo dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  Business reply mail Processing Centre, South C...    Light Rail Station
# 3  CN Tower, King and Spadina, Railway Lands, Har...        Airport Lounge
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0              Beer Bar        Farmers Market                Bakery
# 1        Breakfast Spot           Coffee Shop                Bakery
# 2  Gym / Fitness Center           Pizza Place            Restaurant
# 3      Airport Terminal         Boat or Ferry                 Plane
# 4        Sandwich Place       Bubble Tea Shop                  Café
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0          Cocktail Bar    Seafood Restaurant           Cheese Shop
# 1  Gym / Fitness Center                   Gym          Climbing Gym
# 2         Auto Workshop                   Spa         Burrito Place
# 3   Rental Car Location               Airport    Airport Food Court
# 4    Italian Restaurant            Comic Shop           Salad Place
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue  \
# 0            Restaurant         Clothing Store                    Pub
# 1            Restaurant           Intersection                Stadium
# 2  Fast Food Restaurant         Farmers Market             Comic Shop
# 3       Airport Service               Boutique       Sculpture Garden
# 4          Burger Joint  Portuguese Restaurant             Poke Place
#
#   11th Most Common Venue 12th Most Common Venue
# 0                 Bistro           Concert Hall
# 1              Pet Store          Grocery Store
# 2             Skate Park                   Park
# 3            Coffee Shop        Harbor / Marina
# 4                   Park                 Office

# %%
# establecer el número de agrupaciones en 5
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# ejecutar k-means
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# revisar las etiquetas de las agrupaciones generadas para cada fila del dataframe
kmeans.labels_[0:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int32)

# %%
# añadir etiquetas
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Toronto_merged = Tor_d

# juntar Toronto_grouped con Toronto_data 
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
Toronto_merged['Cluster Labels'] = Toronto_merged['Cluster Labels'].fillna("0").astype(int)


Toronto_merged.head() # revisar las ultimas columnas
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260 -79.360636               0           Coffee Shop
# 1  43.662301 -79.389494               0           Coffee Shop
# 2  43.657162 -79.378937               0           Coffee Shop
# 3  43.651494 -79.375418               0                  Café
# 4  43.676357 -79.293031               0                 Trail
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                Bakery                   Pub                  Park
# 1      Sushi Restaurant           Yoga Studio                  Bank
# 2                  Café             Bookstore        Clothing Store
# 3        Cosmetics Shop             Gastropub           Coffee Shop
# 4                   Pub     Health Food Store              Wine Bar
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Breakfast Spot                  Café               Theater
# 1                   Spa         Smoothie Shop              Beer Bar
# 2      Ramen Restaurant               Theater        Cosmetics Shop
# 3    Seafood Restaurant                Bakery        Farmers Market
# 4          Dance Studio   Dumpling Restaurant            Donut Shop
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 0            Restaurant        Cosmetics Shop    Distribution Center
# 1        Sandwich Place         Burrito Place                   Café
# 2  Fast Food Restaurant         Burrito Place                  Hotel
# 3                  Park   Japanese Restaurant               Creperie
# 4      Doner Restaurant               Dog Run    Distribution Center
#
#   11th Most Common Venue 12th Most Common Venue
# 0           Dessert Shop      Electronics Store
# 1     College Auditorium      College Cafeteria
# 2                  Diner             Restaurant
# 3              Bookstore             Restaurant
# 4         Discount Store                  Diner

# %%
# creamos mapa de agrupacion
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# establecer el esquema de color para las agrupaciones
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# añadir marcadores al mapa
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dcdd2185af324e92bae52a9a082412c6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dcdd2185af324e92bae52a9a082412c6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dcdd2185af324e92bae52a9a082412c6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dcdd2185af324e92bae52a9a082412c6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Examinamos las agrupaciones pudiendo observar que categorias distinguen a cada agrupacion

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 0                           Regent Park, Harbourfront               0
# 1         Queen's Park, Ontario Provincial Government               0
# 2                            Garden District, Ryerson               0
# 3                                      St. James Town               0
# 4                                         The Beaches               0
# 5                                         Berczy Park               0
# 6                                  Central Bay Street               0
# 7                                            Christie               0
# 8                            Richmond, Adelaide, King               0
# 9                        Dufferin, Dovercourt Village               0
# 10  Harbourfront East, Union Station, Toronto Islands               0
# 11                           Little Portugal, Trinity               0
# 12                       The Danforth West, Riverdale               0
# 13           Toronto Dominion Centre, Design Exchange               0
# 14       Brockton, Parkdale Village, Exhibition Place               0
# 15                     India Bazaar, The Beaches West               0
# 16                     Commerce Court, Victoria Hotel               0
# 17                                    Studio District               0
# 20                                   Davisville North               0
# 22                      High Park, The Junction South               0
# 23                  North Toronto West, Lawrence Park               0
# 24                The Annex, North Midtown, Yorkville               0
# 25                             Parkdale, Roncesvalles               0
# 26                                         Davisville               0
# 27                     University of Toronto, Harbord               0
# 28                                 Runnymede, Swansea               0
# 30          Kensington Market, Chinatown, Grange Park               0
# 31  Summerhill West, Rathnelly, South Hill, Forest...               0
# 32  CN Tower, King and Spadina, Railway Lands, Har...               0
# 34                                     Stn A PO Boxes               0
# 35                        St. James Town, Cabbagetown               0
# 36             First Canadian Place, Underground city               0
# 37                               Church and Wellesley               0
# 38  Business reply mail Processing Centre, South C...               0
#
#    1st Most Common Venue          2nd Most Common Venue 3rd Most Common Venue  \
# 0            Coffee Shop                         Bakery                   Pub
# 1            Coffee Shop               Sushi Restaurant           Yoga Studio
# 2            Coffee Shop                           Café             Bookstore
# 3                   Café                 Cosmetics Shop             Gastropub
# 4                  Trail                            Pub     Health Food Store
# 5            Coffee Shop                       Beer Bar        Farmers Market
# 6            Coffee Shop                 Sandwich Place       Bubble Tea Shop
# 7          Grocery Store                           Café                  Park
# 8            Coffee Shop                           Café          Concert Hall
# 9               Pharmacy                         Bakery                  Park
# 10              Aquarium                           Café        Scenic Lookout
# 11                   Bar                           Café           Coffee Shop
# 12      Greek Restaurant                    Coffee Shop    Italian Restaurant
# 13           Coffee Shop                           Café            Restaurant
# 14                  Café                 Breakfast Spot           Coffee Shop
# 15         Movie Theater                            Gym               Brewery
# 16                  Café                     Restaurant                 Hotel
# 17           Coffee Shop                           Café             Gastropub
# 20     Food & Drink Shop                    Pizza Place      Department Store
# 22       Thai Restaurant             Mexican Restaurant   Arts & Crafts Store
# 23           Coffee Shop                 Clothing Store           Yoga Studio
# 24                  Café                 Sandwich Place           Coffee Shop
# 25             Gift Shop                 Breakfast Spot            Restaurant
# 26        Sandwich Place                   Dessert Shop           Pizza Place
# 27                  Café                 Sandwich Place                   Bar
# 28           Coffee Shop                           Café           Pizza Place
# 30                  Café  Vegetarian / Vegan Restaurant                   Bar
# 31           Coffee Shop            American Restaurant      Sushi Restaurant
# 32        Airport Lounge               Airport Terminal         Boat or Ferry
# 34                  Café                    Coffee Shop           Cheese Shop
# 35            Restaurant                           Café           Coffee Shop
# 36                  Café                    Coffee Shop            Restaurant
# 37           Coffee Shop                    Yoga Studio            Restaurant
# 38    Light Rail Station           Gym / Fitness Center           Pizza Place
#
#      4th Most Common Venue        5th Most Common Venue  \
# 0                     Park               Breakfast Spot
# 1                     Bank                          Spa
# 2           Clothing Store             Ramen Restaurant
# 3              Coffee Shop           Seafood Restaurant
# 4                 Wine Bar                 Dance Studio
# 5                   Bakery                 Cocktail Bar
# 6                     Café           Italian Restaurant
# 7              Candy Store           Italian Restaurant
# 8               Steakhouse          American Restaurant
# 9              Supermarket                    Pet Store
# 10             Coffee Shop                  Pizza Place
# 11   Vietnamese Restaurant             Asian Restaurant
# 12  Furniture / Home Store               Ice Cream Shop
# 13                   Hotel           Seafood Restaurant
# 14                  Bakery         Gym / Fitness Center
# 15            Liquor Store                Burrito Place
# 16             Coffee Shop                          Gym
# 17     American Restaurant                      Brewery
# 20    Gym / Fitness Center                   Playground
# 22                    Café                         Park
# 23              Bagel Shop         Fast Food Restaurant
# 24                    Park                    BBQ Joint
# 25                     Bar  Eastern European Restaurant
# 26      Italian Restaurant             Sushi Restaurant
# 27               Bookstore          Japanese Restaurant
# 28        Sushi Restaurant                          Pub
# 30      Mexican Restaurant        Vietnamese Restaurant
# 31                    Bank                   Restaurant
# 32                   Plane          Rental Car Location
# 34          Farmers Market                       Bakery
# 35      Chinese Restaurant           Italian Restaurant
# 36                   Hotel          American Restaurant
# 37             Men's Store                      Gay Bar
# 38              Restaurant                Auto Workshop
#
#         6th Most Common Venue  7th Most Common Venue  \
# 0                        Café                Theater
# 1               Smoothie Shop               Beer Bar
# 2                     Theater         Cosmetics Shop
# 3                      Bakery         Farmers Market
# 4         Dumpling Restaurant             Donut Shop
# 5          Seafood Restaurant            Cheese Shop
# 6                  Comic Shop            Salad Place
# 7                   Nightclub             Restaurant
# 8             Thai Restaurant            Pizza Place
# 9   Middle Eastern Restaurant  Portuguese Restaurant
# 10                      Plaza                  Hotel
# 11                 Restaurant            Men's Store
# 12             Cosmetics Shop                Brewery
# 13                     Bakery    Japanese Restaurant
# 14                        Gym           Climbing Gym
# 15                 Restaurant     Italian Restaurant
# 16         Seafood Restaurant                 Bakery
# 17                     Bakery            Yoga Studio
# 20             Sandwich Place                    Gym
# 22                        Bar              Speakeasy
# 23                      Diner     Mexican Restaurant
# 24                   Pharmacy            Pizza Place
# 25               Dessert Shop            Coffee Shop
# 26                Coffee Shop       Toy / Game Store
# 27                     Bakery            Yoga Studio
# 28         Italian Restaurant            Yoga Studio
# 30       Caribbean Restaurant                 Bakery
# 31        Fried Chicken Joint                    Pub
# 32                    Airport     Airport Food Court
# 34         Seafood Restaurant    Japanese Restaurant
# 35                        Pub            Pizza Place
# 36         Seafood Restaurant          Deli / Bodega
# 37           Sushi Restaurant    Japanese Restaurant
# 38                        Spa          Burrito Place
#
#         8th Most Common Venue  9th Most Common Venue 10th Most Common Venue  \
# 0                  Restaurant         Cosmetics Shop    Distribution Center
# 1              Sandwich Place          Burrito Place                   Café
# 2        Fast Food Restaurant          Burrito Place                  Hotel
# 3                        Park    Japanese Restaurant               Creperie
# 4            Doner Restaurant                Dog Run    Distribution Center
# 5                  Restaurant         Clothing Store                    Pub
# 6                Burger Joint  Portuguese Restaurant             Poke Place
# 7                 Coffee Shop             Baby Store       Department Store
# 8                  Restaurant           Noodle House    Japanese Restaurant
# 9                        Café                Brewery                    Bar
# 10                    Brewery                   Park        Bubble Tea Shop
# 11        Japanese Restaurant              Juice Bar      Korean Restaurant
# 12            Bubble Tea Shop             Restaurant                    Pub
# 13                  Gastropub               Beer Bar              Speakeasy
# 14                 Restaurant           Intersection                Stadium
# 15             Ice Cream Shop                    Pub             Steakhouse
# 16              Deli / Bodega    Japanese Restaurant              Gastropub
# 17                        Bar         Ice Cream Shop     Seafood Restaurant
# 20             Breakfast Spot                   Park                  Hotel
# 22       Fast Food Restaurant            Music Venue             Restaurant
# 23                  Pet Store     Chinese Restaurant                   Café
# 24  Middle Eastern Restaurant          Metro Station                    Pub
# 25                  Bookstore          Movie Theater     Italian Restaurant
# 26                       Café                    Gym             Restaurant
# 27                   Beer Bar             Beer Store     Italian Restaurant
# 28                  Bookstore                    Spa     Falafel Restaurant
# 30                Coffee Shop           Burger Joint            Record Shop
# 31                Pizza Place           Liquor Store  Vietnamese Restaurant
# 32            Airport Service               Boutique       Sculpture Garden
# 34                 Restaurant                    Pub               Beer Bar
# 35                  Pet Store                   Park                 Bakery
# 36                        Gym    Japanese Restaurant           Concert Hall
# 37           Ramen Restaurant        Bubble Tea Shop      Indian Restaurant
# 38       Fast Food Restaurant         Farmers Market             Comic Shop
#
#    11th Most Common Venue     12th Most Common Venue
# 0            Dessert Shop          Electronics Store
# 1      College Auditorium          College Cafeteria
# 2                   Diner                 Restaurant
# 3               Bookstore                 Restaurant
# 4          Discount Store                      Diner
# 5                  Bistro               Concert Hall
# 6                    Park                     Office
# 7            Dessert Shop        Distribution Center
# 8      Seafood Restaurant         Salon / Barbershop
# 9                    Bank                Music Venue
# 10           Dessert Shop         Chinese Restaurant
# 11               Wine Bar           Malay Restaurant
# 12                   Café       Caribbean Restaurant
# 13   Gym / Fitness Center                        Bar
# 14              Pet Store              Grocery Store
# 15   Fast Food Restaurant          Fish & Chips Shop
# 16    American Restaurant                 Steakhouse
# 17     Italian Restaurant  Latin American Restaurant
# 20    Distribution Center                    Dog Run
# 22              Bookstore                Flea Market
# 23             Restaurant         Salon / Barbershop
# 24           Burger Joint               Liquor Store
# 25       Cuban Restaurant                    Dog Run
# 26     Seafood Restaurant                      Diner
# 27                    Pub                 Restaurant
# 28          Smoothie Shop        Indie Movie Theater
# 30       Ramen Restaurant                Cheese Shop
# 31     Light Rail Station                Supermarket
# 32            Coffee Shop            Harbor / Marina
# 34           Cocktail Bar                   Creperie
# 35        Thai Restaurant                   Pharmacy
# 36                 Lounge                 Food Court
# 37               Sake Bar             Breakfast Spot
# 38             Skate Park                       Park

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#      Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 18  Lawrence Park               1                  Park              Bus Line
#
#    3rd Most Common Venue 4th Most Common Venue        5th Most Common Venue  \
# 18           Swim School     Electronics Store  Eastern European Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18   Dumpling Restaurant            Donut Shop      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 18               Dog Run    Distribution Center         Discount Store
#
#    12th Most Common Venue
# 18                  Diner

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                    Neighborhood  Cluster Labels 1st Most Common Venue  \
# 29  Moore Park, Summerhill East               2                  Park
# 33                     Rosedale               2                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 29                 Trail            Playground            Restaurant
# 33                 Trail            Playground          Cupcake Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 29          Cupcake Shop            Donut Shop      Doner Restaurant
# 33   Dumpling Restaurant            Donut Shop      Doner Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 29               Dog Run   Distribution Center         Discount Store
# 33               Dog Run   Distribution Center         Discount Store
#
#    11th Most Common Venue 12th Most Common Venue
# 29                  Diner           Dessert Shop
# 33                  Diner           Dessert Shop

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                        Neighborhood  Cluster Labels  \
# 21  Forest Hill North & West, Forest Hill Road Park               3
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 21                  Park         Jewelry Store                 Trail
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 21      Sushi Restaurant              Wine Bar         Deli / Bodega
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 21   Dumpling Restaurant            Donut Shop      Doner Restaurant
#
#    10th Most Common Venue 11th Most Common Venue 12th Most Common Venue
# 21                Dog Run    Distribution Center         Discount Store

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 19     Roselawn               4                Garden           Music Venue
#
#       3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 19  Health & Beauty Service              Wine Bar         Deli / Bodega
#
#           6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 19  Eastern European Restaurant   Dumpling Restaurant            Donut Shop
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 19      Doner Restaurant                Dog Run    Distribution Center
#
#    12th Most Common Venue
# 19         Discount Store
