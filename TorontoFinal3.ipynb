# %% [markdown]
# ## Agrupacion y Segmentacion de Vecindarios de Toronto

# %% [markdown]
# #### Parte 1

# %%
# Importacion de Librerias necesarias

# %%
pip install BeautifulSoup4
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: BeautifulSoup4 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from BeautifulSoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: lxml in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (4.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup  
import requests 
import pandas as pd
import lxml

# %%
#Importacion , Scraping y Creacion de Dataframe

# %%
url =requests.get ("https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=958430791").text

# %%
soup = BeautifulSoup(url,'lxml')

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
df = pd.read_html(str(My_table))[0]
df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned                        NaN
# 1         M2A      Not assigned                        NaN
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Eliminamos Municipios 'Not assigned'

# %%
drop_Not=df[df['Borough']=='Not assigned'].index
df.drop (drop_Not, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Asignamos Vecindarios 'Not assigned' a Municipio

# %%
df[df['Neighborhood']=='Not assigned']=df['Borough'].reset_index()
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Requerimiento filas-columnas

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# #### Parte 2

# %%
# Importacion de archivo csv con coordenadas

# %%
from io import StringIO

url = requests.get(' http://cocl.us/Geospatial_data')
csv_raw = StringIO(url.text)
datos_geo = pd.read_csv(csv_raw)

# %%
datos_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Relacionamos Dataframes

# %%
df=pd.merge(df,datos_geo,how='left')

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# #### Parte 3

# %%
# Importacion Librerias Necesarias

# %%
import numpy as np
import json
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !pip install folium
import folium
print('Librerias importadas')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 4.0 MB/s  eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.11.3)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (1.19.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1
# Librerias importadas

# %%
# Filtramos a Municipios que sean ' Toronto '


Tor_d = df[df['Borough'].str.contains('Toronto')].reset_index(drop=True)
Tor_d.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %%
# Obtenemos nro filas 

Tor_d.shape
# Out:
# (39, 5)

# %%
# Obtenemos coordenadas para Toronto

address = 'Toronto, ON'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Coordenadas Toronto {}, {}.'.format(latitude, longitude))
# Out:
# Coordenadas Toronto 43.6534817, -79.3839347.

# %%
# Creamos mapa de Toronto y añadimos los marcadores

map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(Tor_d['Latitude'], Tor_d['Longitude'], Tor_d['Borough'], Tor_d['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=2,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4df38d4dbfbd4a4daf86afd62f450567%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4df38d4dbfbd4a4daf86afd62f450567%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4df38d4dbfbd4a4daf86afd62f450567%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4df38d4dbfbd4a4daf86afd62f450567%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Definimos version y credenciales para la API de Foursquare con un limite de 50 devoluciones

CLIENT_ID = 'DBBPKNBZNEC2JFO4JL13AJOJLMHLHOCOYWGTY5ZXJFXRJXYD' 
CLIENT_SECRET = 'YA51Q1Y4XHBRUZE1025SHVN3AKMX20MJHBBELS0BANSJWKMA' 
VERSION = '20180605' 
LIMIT = 50

# %%
# Definimos funcion para obtener los 100 sitios en un radio de 500 mts para cada barrio

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # crear la URL de solicitud de API
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
                # solicitud GET
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # regresa solo información relevante de cada sitio cercano
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Corremos la funcion getNearbyVenues para cada barrio creando un Dataframe 'Toronto_venues'

Toronto_venues = getNearbyVenues(names=Tor_d['Neighborhood'],
                                   latitudes=Tor_d['Latitude'],
                                   longitudes=Tor_d['Longitude'])
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# High Park, The Junction South
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
# mostramos Dataframe y revisamos tamaño

print(Toronto_venues.shape)
Toronto_venues.head()
# Out:
# (1170, 7)
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4          Impact Kitchen       43.656369       -79.356980
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4           Restaurant

# %%
# Observemos cuantos sitios se devolvieron por barrio

Toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            50
# Brockton, Parkdale Village, Exhibition Place                           23
# Business reply mail Processing Centre, South Ce...                     17
# CN Tower, King and Spadina, Railway Lands, Harb...                     18
# Central Bay Street                                                     50
# Christie                                                               15
# Church and Wellesley                                                   50
# Commerce Court, Victoria Hotel                                         50
# Davisville                                                             37
# Davisville North                                                        9
# Dufferin, Dovercourt Village                                           15
# First Canadian Place, Underground city                                 50
# Forest Hill North & West, Forest Hill Road Park                         4
# Garden District, Ryerson                                               50
# Harbourfront East, Union Station, Toronto Islands                      50
# High Park, The Junction South                                          24
# India Bazaar, The Beaches West                                         20
# Kensington Market, Chinatown, Grange Park                              50
# Lawrence Park                                                           3
# Little Portugal, Trinity                                               42
# North Toronto West, Lawrence Park                                      18
# Parkdale, Roncesvalles                                                 14
# Queen's Park, Ontario Provincial Government                            30
# Regent Park, Harbourfront                                              46
# Richmond, Adelaide, King                                               50
# Rosedale                                                                4
# Roselawn                                                                3
# Runnymede, Swansea                                                     34
# St. James Town                                                         50
# St. James Town, Cabbagetown                                            43
# Stn A PO Boxes                                                         50
# Studio District                                                        36
# Summerhill West, Rathnelly, South Hill, Forest ...                     14
# The Annex, North Midtown, Yorkville                                    20
# The Beaches                                                             5
# The Danforth West, Riverdale                                           42
# Toronto Dominion Centre, Design Exchange                               50
# University of Toronto, Harbord                                         34
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             50
# Brockton, Parkdale Village, Exhibition Place                            23
# Business reply mail Processing Centre, South Ce...                      17
# CN Tower, King and Spadina, Railway Lands, Harb...                      18
# Central Bay Street                                                      50
# Christie                                                                15
# Church and Wellesley                                                    50
# Commerce Court, Victoria Hotel                                          50
# Davisville                                                              37
# Davisville North                                                         9
# Dufferin, Dovercourt Village                                            15
# First Canadian Place, Underground city                                  50
# Forest Hill North & West, Forest Hill Road Park                          4
# Garden District, Ryerson                                                50
# Harbourfront East, Union Station, Toronto Islands                       50
# High Park, The Junction South                                           24
# India Bazaar, The Beaches West                                          20
# Kensington Market, Chinatown, Grange Park                               50
# Lawrence Park                                                            3
# Little Portugal, Trinity                                                42
# North Toronto West, Lawrence Park                                       18
# Parkdale, Roncesvalles                                                  14
# Queen's Park, Ontario Provincial Government                             30
# Regent Park, Harbourfront                                               46
# Richmond, Adelaide, King                                                50
# Rosedale                                                                 4
# Roselawn                                                                 3
# Runnymede, Swansea                                                      34
# St. James Town                                                          50
# St. James Town, Cabbagetown                                             43
# Stn A PO Boxes                                                          50
# Studio District                                                         36
# Summerhill West, Rathnelly, South Hill, Forest ...                      14
# The Annex, North Midtown, Yorkville                                     20
# The Beaches                                                              5
# The Danforth West, Riverdale                                            42
# Toronto Dominion Centre, Design Exchange                                50
# University of Toronto, Harbord                                          34
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            50              50
# Brockton, Parkdale Village, Exhibition Place           23              23
# Business reply mail Processing Centre, South Ce...     17              17
# CN Tower, King and Spadina, Railway Lands, Harb...     18              18
# Central Bay Street                                     50              50
# Christie                                               15              15
# Church and Wellesley                                   50              50
# Commerce Court, Victoria Hotel                         50              50
# Davisville                                             37              37
# Davisville North                                        9               9
# Dufferin, Dovercourt Village                           15              15
# First Canadian Place, Underground city                 50              50
# Forest Hill North & West, Forest Hill Road Park         4               4
# Garden District, Ryerson                               50              50
# Harbourfront East, Union Station, Toronto Islands      50              50
# High Park, The Junction South                          24              24
# India Bazaar, The Beaches West                         20              20
# Kensington Market, Chinatown, Grange Park              50              50
# Lawrence Park                                           3               3
# Little Portugal, Trinity                               42              42
# North Toronto West, Lawrence Park                      18              18
# Parkdale, Roncesvalles                                 14              14
# Queen's Park, Ontario Provincial Government            30              30
# Regent Park, Harbourfront                              46              46
# Richmond, Adelaide, King                               50              50
# Rosedale                                                4               4
# Roselawn                                                3               3
# Runnymede, Swansea                                     34              34
# St. James Town                                         50              50
# St. James Town, Cabbagetown                            43              43
# Stn A PO Boxes                                         50              50
# Studio District                                        36              36
# Summerhill West, Rathnelly, South Hill, Forest ...     14              14
# The Annex, North Midtown, Yorkville                    20              20
# The Beaches                                             5               5
# The Danforth West, Riverdale                           42              42
# Toronto Dominion Centre, Design Exchange               50              50
# University of Toronto, Harbord                         34              34
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      50
# Brockton, Parkdale Village, Exhibition Place                     23
# Business reply mail Processing Centre, South Ce...               17
# CN Tower, King and Spadina, Railway Lands, Harb...               18
# Central Bay Street                                               50
# Christie                                                         15
# Church and Wellesley                                             50
# Commerce Court, Victoria Hotel                                   50
# Davisville                                                       37
# Davisville North                                                  9
# Dufferin, Dovercourt Village                                     15
# First Canadian Place, Underground city                           50
# Forest Hill North & West, Forest Hill Road Park                   4
# Garden District, Ryerson                                         50
# Harbourfront East, Union Station, Toronto Islands                50
# High Park, The Junction South                                    24
# India Bazaar, The Beaches West                                   20
# Kensington Market, Chinatown, Grange Park                        50
# Lawrence Park                                                     3
# Little Portugal, Trinity                                         42
# North Toronto West, Lawrence Park                                18
# Parkdale, Roncesvalles                                           14
# Queen's Park, Ontario Provincial Government                      30
# Regent Park, Harbourfront                                        46
# Richmond, Adelaide, King                                         50
# Rosedale                                                          4
# Roselawn                                                          3
# Runnymede, Swansea                                               34
# St. James Town                                                   50
# St. James Town, Cabbagetown                                      43
# Stn A PO Boxes                                                   50
# Studio District                                                  36
# Summerhill West, Rathnelly, South Hill, Forest ...               14
# The Annex, North Midtown, Yorkville                              20
# The Beaches                                                       5
# The Danforth West, Riverdale                                     42
# Toronto Dominion Centre, Design Exchange                         50
# University of Toronto, Harbord                                   34
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     50
# Brockton, Parkdale Village, Exhibition Place                    23
# Business reply mail Processing Centre, South Ce...              17
# CN Tower, King and Spadina, Railway Lands, Harb...              18
# Central Bay Street                                              50
# Christie                                                        15
# Church and Wellesley                                            50
# Commerce Court, Victoria Hotel                                  50
# Davisville                                                      37
# Davisville North                                                 9
# Dufferin, Dovercourt Village                                    15
# First Canadian Place, Underground city                          50
# Forest Hill North & West, Forest Hill Road Park                  4
# Garden District, Ryerson                                        50
# Harbourfront East, Union Station, Toronto Islands               50
# High Park, The Junction South                                   24
# India Bazaar, The Beaches West                                  20
# Kensington Market, Chinatown, Grange Park                       50
# Lawrence Park                                                    3
# Little Portugal, Trinity                                        42
# North Toronto West, Lawrence Park                               18
# Parkdale, Roncesvalles                                          14
# Queen's Park, Ontario Provincial Government                     30
# Regent Park, Harbourfront                                       46
# Richmond, Adelaide, King                                        50
# Rosedale                                                         4
# Roselawn                                                         3
# Runnymede, Swansea                                              34
# St. James Town                                                  50
# St. James Town, Cabbagetown                                     43
# Stn A PO Boxes                                                  50
# Studio District                                                 36
# Summerhill West, Rathnelly, South Hill, Forest ...              14
# The Annex, North Midtown, Yorkville                             20
# The Beaches                                                      5
# The Danforth West, Riverdale                                    42
# Toronto Dominion Centre, Design Exchange                        50
# University of Toronto, Harbord                                  34

# %%
# Vemos cuantas categorias unicas hay por barrio

print('There are {} uniques categories.'.format(len(Toronto_venues['Venue Category'].unique())))
# Out:
# There are 220 uniques categories.

# %%
#Analizamos cada barrio



# codificación
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# añadir la columna de barrio de regreso al dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood'] 

# mover la columna de barrio a la primer columna
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_onehot.shape
# Out:
# (1170, 220)

# %%
# Agrupamos las filas por barrios tomando el parametro de promedio de ocurrencia de cada categoria


Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()
Toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio  \
# 0                                         Berczy Park     0.000000
# 1        Brockton, Parkdale Village, Exhibition Place     0.000000
# 2   Business reply mail Processing Centre, South C...     0.058824
# 3   CN Tower, King and Spadina, Railway Lands, Har...     0.000000
# 4                                  Central Bay Street     0.020000
# 5                                            Christie     0.000000
# 6                                Church and Wellesley     0.040000
# 7                      Commerce Court, Victoria Hotel     0.000000
# 8                                          Davisville     0.000000
# 9                                    Davisville North     0.000000
# 10                       Dufferin, Dovercourt Village     0.000000
# 11             First Canadian Place, Underground city     0.000000
# 12    Forest Hill North & West, Forest Hill Road Park     0.000000
# 13                           Garden District, Ryerson     0.000000
# 14  Harbourfront East, Union Station, Toronto Islands     0.000000
# 15                      High Park, The Junction South     0.000000
# 16                     India Bazaar, The Beaches West     0.000000
# 17          Kensington Market, Chinatown, Grange Park     0.000000
# 18                                      Lawrence Park     0.000000
# 19                           Little Portugal, Trinity     0.023810
# 20                  North Toronto West, Lawrence Park     0.055556
# 21                             Parkdale, Roncesvalles     0.000000
# 22        Queen's Park, Ontario Provincial Government     0.033333
# 23                          Regent Park, Harbourfront     0.021739
# 24                           Richmond, Adelaide, King     0.000000
# 25                                           Rosedale     0.000000
# 26                                           Roselawn     0.000000
# 27                                 Runnymede, Swansea     0.029412
# 28                                     St. James Town     0.000000
# 29                        St. James Town, Cabbagetown     0.000000
# 30                                     Stn A PO Boxes     0.000000
# 31                                    Studio District     0.027778
# 32  Summerhill West, Rathnelly, South Hill, Forest...     0.000000
# 33                The Annex, North Midtown, Yorkville     0.000000
# 34                                        The Beaches     0.000000
# 35                       The Danforth West, Riverdale     0.023810
# 36           Toronto Dominion Centre, Design Exchange     0.000000
# 37                     University of Toronto, Harbord     0.029412
#
#     Adult Boutique   Airport  Airport Food Court  Airport Gate  \
# 0             0.00  0.000000            0.000000      0.000000
# 1             0.00  0.000000            0.000000      0.000000
# 2             0.00  0.000000            0.000000      0.000000
# 3             0.00  0.055556            0.055556      0.055556
# 4             0.00  0.000000            0.000000      0.000000
# 5             0.00  0.000000            0.000000      0.000000
# 6             0.02  0.000000            0.000000      0.000000
# 7             0.00  0.000000            0.000000      0.000000
# 8             0.00  0.000000            0.000000      0.000000
# 9             0.00  0.000000            0.000000      0.000000
# 10            0.00  0.000000            0.000000      0.000000
# 11            0.00  0.000000            0.000000      0.000000
# 12            0.00  0.000000            0.000000      0.000000
# 13            0.00  0.000000            0.000000      0.000000
# 14            0.00  0.000000            0.000000      0.000000
# 15            0.00  0.000000            0.000000      0.000000
# 16            0.00  0.000000            0.000000      0.000000
# 17            0.00  0.000000            0.000000      0.000000
# 18            0.00  0.000000            0.000000      0.000000
# 19            0.00  0.000000            0.000000      0.000000
# 20            0.00  0.000000            0.000000      0.000000
# 21            0.00  0.000000            0.000000      0.000000
# 22            0.00  0.000000            0.000000      0.000000
# 23            0.00  0.000000            0.000000      0.000000
# 24            0.00  0.000000            0.000000      0.000000
# 25            0.00  0.000000            0.000000      0.000000
# 26            0.00  0.000000            0.000000      0.000000
# 27            0.00  0.000000            0.000000      0.000000
# 28            0.00  0.000000            0.000000      0.000000
# 29            0.00  0.000000            0.000000      0.000000
# 30            0.00  0.000000            0.000000      0.000000
# 31            0.00  0.000000            0.000000      0.000000
# 32            0.00  0.000000            0.000000      0.000000
# 33            0.00  0.000000            0.000000      0.000000
# 34            0.00  0.000000            0.000000      0.000000
# 35            0.00  0.000000            0.000000      0.000000
# 36            0.00  0.000000            0.000000      0.000000
# 37            0.00  0.000000            0.000000      0.000000
#
#     Airport Lounge  Airport Service  Airport Terminal  American Restaurant  \
# 0         0.000000         0.000000          0.000000             0.000000
# 1         0.000000         0.000000          0.000000             0.000000
# 2         0.000000         0.000000          0.000000             0.000000
# 3         0.111111         0.166667          0.111111             0.000000
# 4         0.000000         0.000000          0.000000             0.000000
# 5         0.000000         0.000000          0.000000             0.000000
# 6         0.000000         0.000000          0.000000             0.000000
# 7         0.000000         0.000000          0.000000             0.040000
# 8         0.000000         0.000000          0.000000             0.000000
# 9         0.000000         0.000000          0.000000             0.000000
# 10        0.000000         0.000000          0.000000             0.000000
# 11        0.000000         0.000000          0.000000             0.040000
# 12        0.000000         0.000000          0.000000             0.000000
# 13        0.000000         0.000000          0.000000             0.000000
# 14        0.000000         0.000000          0.000000             0.000000
# 15        0.000000         0.000000          0.000000             0.000000
# 16        0.000000         0.000000          0.000000             0.000000
# 17        0.000000         0.000000          0.000000             0.000000
# 18        0.000000         0.000000          0.000000             0.000000
# 19        0.000000         0.000000          0.000000             0.000000
# 20        0.000000         0.000000          0.000000             0.000000
# 21        0.000000         0.000000          0.000000             0.000000
# 22        0.000000         0.000000          0.000000             0.000000
# 23        0.000000         0.000000          0.000000             0.000000
# 24        0.000000         0.000000          0.000000             0.040000
# 25        0.000000         0.000000          0.000000             0.000000
# 26        0.000000         0.000000          0.000000             0.000000
# 27        0.000000         0.000000          0.000000             0.000000
# 28        0.000000         0.000000          0.000000             0.020000
# 29        0.000000         0.000000          0.000000             0.000000
# 30        0.000000         0.000000          0.000000             0.000000
# 31        0.000000         0.000000          0.000000             0.055556
# 32        0.000000         0.000000          0.000000             0.071429
# 33        0.000000         0.000000          0.000000             0.000000
# 34        0.000000         0.000000          0.000000             0.000000
# 35        0.000000         0.000000          0.000000             0.023810
# 36        0.000000         0.000000          0.000000             0.020000
# 37        0.000000         0.000000          0.000000             0.000000
#
#     ...   Theater  Theme Restaurant  Tibetan Restaurant  Toy / Game Store  \
# 0   ...  0.000000              0.00             0.00000          0.000000
# 1   ...  0.000000              0.00             0.00000          0.000000
# 2   ...  0.000000              0.00             0.00000          0.000000
# 3   ...  0.000000              0.00             0.00000          0.000000
# 4   ...  0.000000              0.00             0.00000          0.000000
# 5   ...  0.000000              0.00             0.00000          0.000000
# 6   ...  0.000000              0.02             0.00000          0.000000
# 7   ...  0.000000              0.00             0.00000          0.000000
# 8   ...  0.000000              0.00             0.00000          0.027027
# 9   ...  0.000000              0.00             0.00000          0.000000
# 10  ...  0.000000              0.00             0.00000          0.000000
# 11  ...  0.000000              0.00             0.00000          0.000000
# 12  ...  0.000000              0.00             0.00000          0.000000
# 13  ...  0.040000              0.00             0.00000          0.000000
# 14  ...  0.020000              0.00             0.00000          0.000000
# 15  ...  0.000000              0.00             0.00000          0.000000
# 16  ...  0.000000              0.00             0.00000          0.000000
# 17  ...  0.000000              0.00             0.00000          0.000000
# 18  ...  0.000000              0.00             0.00000          0.000000
# 19  ...  0.023810              0.00             0.00000          0.000000
# 20  ...  0.000000              0.00             0.00000          0.000000
# 21  ...  0.000000              0.00             0.00000          0.000000
# 22  ...  0.033333              0.00             0.00000          0.000000
# 23  ...  0.043478              0.00             0.00000          0.000000
# 24  ...  0.000000              0.00             0.00000          0.000000
# 25  ...  0.000000              0.00             0.00000          0.000000
# 26  ...  0.000000              0.00             0.00000          0.000000
# 27  ...  0.000000              0.00             0.00000          0.000000
# 28  ...  0.020000              0.00             0.00000          0.000000
# 29  ...  0.000000              0.00             0.00000          0.000000
# 30  ...  0.000000              0.00             0.00000          0.000000
# 31  ...  0.000000              0.00             0.00000          0.000000
# 32  ...  0.000000              0.00             0.00000          0.000000
# 33  ...  0.000000              0.00             0.00000          0.000000
# 34  ...  0.000000              0.00             0.00000          0.000000
# 35  ...  0.000000              0.00             0.02381          0.000000
# 36  ...  0.000000              0.00             0.00000          0.000000
# 37  ...  0.029412              0.00             0.00000          0.000000
#
#       Trail  Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0   0.00000           0.00                       0.020000          0.000000
# 1   0.00000           0.00                       0.000000          0.000000
# 2   0.00000           0.00                       0.000000          0.000000
# 3   0.00000           0.00                       0.000000          0.000000
# 4   0.00000           0.00                       0.020000          0.000000
# 5   0.00000           0.00                       0.000000          0.000000
# 6   0.00000           0.00                       0.000000          0.000000
# 7   0.00000           0.00                       0.020000          0.000000
# 8   0.00000           0.00                       0.000000          0.000000
# 9   0.00000           0.00                       0.000000          0.000000
# 10  0.00000           0.00                       0.000000          0.000000
# 11  0.00000           0.00                       0.020000          0.000000
# 12  0.25000           0.00                       0.000000          0.000000
# 13  0.00000           0.00                       0.000000          0.000000
# 14  0.00000           0.02                       0.000000          0.000000
# 15  0.00000           0.00                       0.000000          0.000000
# 16  0.00000           0.00                       0.000000          0.000000
# 17  0.00000           0.00                       0.060000          0.000000
# 18  0.00000           0.00                       0.000000          0.000000
# 19  0.00000           0.00                       0.047619          0.000000
# 20  0.00000           0.00                       0.000000          0.000000
# 21  0.00000           0.00                       0.000000          0.000000
# 22  0.00000           0.00                       0.000000          0.000000
# 23  0.00000           0.00                       0.000000          0.000000
# 24  0.00000           0.00                       0.020000          0.000000
# 25  0.25000           0.00                       0.000000          0.000000
# 26  0.00000           0.00                       0.000000          0.000000
# 27  0.00000           0.00                       0.029412          0.000000
# 28  0.00000           0.00                       0.020000          0.000000
# 29  0.00000           0.00                       0.000000          0.000000
# 30  0.00000           0.00                       0.020000          0.000000
# 31  0.00000           0.00                       0.000000          0.000000
# 32  0.00000           0.00                       0.000000          0.000000
# 33  0.00000           0.00                       0.000000          0.000000
# 34  0.20000           0.00                       0.000000          0.000000
# 35  0.02381           0.00                       0.000000          0.000000
# 36  0.00000           0.02                       0.020000          0.000000
# 37  0.00000           0.00                       0.000000          0.029412
#
#     Vietnamese Restaurant  Wine Bar
# 0                0.000000   0.00000
# 1                0.000000   0.00000
# 2                0.000000   0.00000
# 3                0.000000   0.00000
# 4                0.000000   0.00000
# 5                0.000000   0.00000
# 6                0.000000   0.00000
# 7                0.000000   0.00000
# 8                0.000000   0.00000
# 9                0.000000   0.00000
# 10               0.000000   0.00000
# 11               0.000000   0.00000
# 12               0.000000   0.00000
# 13               0.000000   0.00000
# 14               0.000000   0.00000
# 15               0.000000   0.00000
# 16               0.000000   0.00000
# 17               0.040000   0.02000
# 18               0.000000   0.00000
# 19               0.047619   0.02381
# 20               0.000000   0.00000
# 21               0.000000   0.00000
# 22               0.000000   0.00000
# 23               0.000000   0.00000
# 24               0.000000   0.00000
# 25               0.000000   0.00000
# 26               0.000000   0.00000
# 27               0.000000   0.00000
# 28               0.000000   0.00000
# 29               0.000000   0.00000
# 30               0.000000   0.00000
# 31               0.000000   0.00000
# 32               0.071429   0.00000
# 33               0.000000   0.00000
# 34               0.000000   0.00000
# 35               0.000000   0.00000
# 36               0.000000   0.00000
# 37               0.000000   0.00000
#
# [38 rows x 220 columns]

# %%
#Observamos tamaño Dataframe

Toronto_grouped.shape
# Out:
# (38, 220)

# %%
# Visualizamos cada barrio con los 12 lugares mas comunes

num_top_venues = 12

for hood in Toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                       venue  freq
# 0               Coffee Shop  0.06
# 1                  Pharmacy  0.04
# 2               Cheese Shop  0.04
# 3        Seafood Restaurant  0.04
# 4              Cocktail Bar  0.04
# 5                  Beer Bar  0.04
# 6                Restaurant  0.04
# 7                    Bakery  0.04
# 8            Farmers Market  0.04
# 9              Concert Hall  0.02
# 10           Clothing Store  0.02
# 11  Comfort Food Restaurant  0.02
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#                     venue  freq
# 0                    Café  0.13
# 1             Coffee Shop  0.09
# 2          Breakfast Spot  0.09
# 3                  Bakery  0.09
# 4                     Gym  0.04
# 5            Intersection  0.04
# 6               Pet Store  0.04
# 7   Performing Arts Venue  0.04
# 8               Nightclub  0.04
# 9              Restaurant  0.04
# 10           Climbing Gym  0.04
# 11          Burrito Place  0.04
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                    venue  freq
# 0     Light Rail Station  0.12
# 1            Yoga Studio  0.06
# 2          Garden Center  0.06
# 3             Skate Park  0.06
# 4          Burrito Place  0.06
# 5         Farmers Market  0.06
# 6   Fast Food Restaurant  0.06
# 7                    Spa  0.06
# 8                Butcher  0.06
# 9       Recording Studio  0.06
# 10            Restaurant  0.06
# 11               Brewery  0.06
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                   venue  freq
# 0       Airport Service  0.17
# 1        Airport Lounge  0.11
# 2      Airport Terminal  0.11
# 3       Harbor / Marina  0.06
# 4                   Bar  0.06
# 5   Rental Car Location  0.06
# 6           Coffee Shop  0.06
# 7      Sculpture Garden  0.06
# 8              Boutique  0.06
# 9         Boat or Ferry  0.06
# 10                Plane  0.06
# 11         Airport Gate  0.06
#
#
# ----Central Bay Street----
#                          venue  freq
# 0                  Coffee Shop  0.16
# 1               Sandwich Place  0.06
# 2              Bubble Tea Shop  0.04
# 3                         Café  0.04
# 4           Italian Restaurant  0.04
# 5   Modern European Restaurant  0.02
# 6                    Bookstore  0.02
# 7                 Burger Joint  0.02
# 8    Middle Eastern Restaurant  0.02
# 9           Miscellaneous Shop  0.02
# 10          Falafel Restaurant  0.02
# 11                 Salad Place  0.02
#
#
# ----Christie----
#                               venue  freq
# 0                     Grocery Store  0.27
# 1                              Café  0.20
# 2                              Park  0.13
# 3                Italian Restaurant  0.07
# 4                        Baby Store  0.07
# 5                        Restaurant  0.07
# 6                         Nightclub  0.07
# 7                       Candy Store  0.07
# 8                       Coffee Shop  0.07
# 9                Miscellaneous Shop  0.00
# 10        Middle Eastern Restaurant  0.00
# 11  Molecular Gastronomy Restaurant  0.00
#
#
# ----Church and Wellesley----
#                   venue  freq
# 0           Coffee Shop  0.06
# 1           Yoga Studio  0.04
# 2           Men's Store  0.04
# 3      Sushi Restaurant  0.04
# 4   Japanese Restaurant  0.04
# 5            Restaurant  0.04
# 6               Gay Bar  0.04
# 7    Salon / Barbershop  0.02
# 8       Bubble Tea Shop  0.02
# 9         Burrito Place  0.02
# 10           Smoke Shop  0.02
# 11                 Café  0.02
#
#
# ----Commerce Court, Victoria Hotel----
#                   venue  freq
# 0                  Café  0.10
# 1           Coffee Shop  0.08
# 2            Restaurant  0.08
# 3                 Hotel  0.08
# 4    Seafood Restaurant  0.06
# 5                   Gym  0.06
# 6         Deli / Bodega  0.04
# 7   American Restaurant  0.04
# 8             Gastropub  0.04
# 9                Bakery  0.04
# 10  Japanese Restaurant  0.04
# 11          Salad Place  0.02
#
#
# ----Davisville----
#                  venue  freq
# 0          Pizza Place  0.08
# 1       Sandwich Place  0.08
# 2         Dessert Shop  0.08
# 3          Coffee Shop  0.05
# 4                 Café  0.05
# 5      Thai Restaurant  0.05
# 6     Sushi Restaurant  0.05
# 7   Italian Restaurant  0.05
# 8                  Gym  0.05
# 9                Diner  0.03
# 10       Deli / Bodega  0.03
# 11            Pharmacy  0.03
#
#
# ----Davisville North----
#                    venue  freq
# 0            Pizza Place  0.11
# 1                  Hotel  0.11
# 2      Food & Drink Shop  0.11
# 3           Dance Studio  0.11
# 4         Sandwich Place  0.11
# 5       Department Store  0.11
# 6                   Park  0.11
# 7   Gym / Fitness Center  0.11
# 8         Breakfast Spot  0.11
# 9            Men's Store  0.00
# 10    Mexican Restaurant  0.00
# 11   Monument / Landmark  0.00
#
#
# ----Dufferin, Dovercourt Village----
#                         venue  freq
# 0                    Pharmacy  0.13
# 1                      Bakery  0.13
# 2                   Pet Store  0.07
# 3                        Park  0.07
# 4                 Music Venue  0.07
# 5   Middle Eastern Restaurant  0.07
# 6                        Café  0.07
# 7                  Smoke Shop  0.07
# 8                     Brewery  0.07
# 9                 Supermarket  0.07
# 10                        Bar  0.07
# 11                       Bank  0.07
#
#
# ----First Canadian Place, Underground city----
#                   venue  freq
# 0                  Café  0.12
# 1           Coffee Shop  0.10
# 2            Restaurant  0.08
# 3                 Hotel  0.04
# 4                   Gym  0.04
# 5    Seafood Restaurant  0.04
# 6         Deli / Bodega  0.04
# 7          Concert Hall  0.04
# 8   American Restaurant  0.04
# 9   Japanese Restaurant  0.04
# 10           Food Court  0.02
# 11       Sandwich Place  0.02
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#                               venue  freq
# 0                     Jewelry Store  0.25
# 1                             Trail  0.25
# 2                Mexican Restaurant  0.25
# 3                  Sushi Restaurant  0.25
# 4                       Yoga Studio  0.00
# 5   Molecular Gastronomy Restaurant  0.00
# 6                            Lounge  0.00
# 7                  Malay Restaurant  0.00
# 8                            Market  0.00
# 9               Martial Arts School  0.00
# 10         Mediterranean Restaurant  0.00
# 11                      Men's Store  0.00
#
#
# ----Garden District, Ryerson----
#                    venue  freq
# 0            Coffee Shop  0.08
# 1                   Café  0.06
# 2         Clothing Store  0.04
# 3              Bookstore  0.04
# 4         Cosmetics Shop  0.04
# 5                Theater  0.04
# 6       Ramen Restaurant  0.04
# 7   Fast Food Restaurant  0.04
# 8                    Spa  0.02
# 9          Burrito Place  0.02
# 10         Shopping Mall  0.02
# 11        Sandwich Place  0.02
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#               venue  freq
# 0       Coffee Shop  0.06
# 1          Aquarium  0.06
# 2              Park  0.04
# 3             Hotel  0.04
# 4             Plaza  0.04
# 5              Café  0.04
# 6           Brewery  0.04
# 7   Bubble Tea Shop  0.02
# 8        Steakhouse  0.02
# 9            Bistro  0.02
# 10             Lake  0.02
# 11       Sports Bar  0.02
#
#
# ----High Park, The Junction South----
#                         venue  freq
# 0                        Café  0.08
# 1          Mexican Restaurant  0.08
# 2             Thai Restaurant  0.08
# 3              Discount Store  0.04
# 4   Cajun / Creole Restaurant  0.04
# 5                 Flea Market  0.04
# 6                   Bookstore  0.04
# 7         Fried Chicken Joint  0.04
# 8      Furniture / Home Store  0.04
# 9                         Bar  0.04
# 10       Fast Food Restaurant  0.04
# 11         Italian Restaurant  0.04
#
#
# ----India Bazaar, The Beaches West----
#                    venue  freq
# 0                   Park  0.10
# 1             Playground  0.05
# 2     Italian Restaurant  0.05
# 3            Pizza Place  0.05
# 4            Coffee Shop  0.05
# 5                    Pub  0.05
# 6          Movie Theater  0.05
# 7             Restaurant  0.05
# 8         Sandwich Place  0.05
# 9          Burrito Place  0.05
# 10               Brewery  0.05
# 11  Fast Food Restaurant  0.05
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                             venue  freq
# 0                            Café  0.10
# 1   Vegetarian / Vegan Restaurant  0.06
# 2                             Bar  0.06
# 3           Vietnamese Restaurant  0.04
# 4                    Burger Joint  0.04
# 5              Mexican Restaurant  0.04
# 6                          Bakery  0.04
# 7                     Coffee Shop  0.04
# 8            Caribbean Restaurant  0.04
# 9                        Wine Bar  0.02
# 10                    Fish Market  0.02
# 11                     Food Truck  0.02
#
#
# ----Lawrence Park----
#                               venue  freq
# 0                              Park  0.33
# 1                          Bus Line  0.33
# 2                       Swim School  0.33
# 3                       Yoga Studio  0.00
# 4   Molecular Gastronomy Restaurant  0.00
# 5                  Malay Restaurant  0.00
# 6                            Market  0.00
# 7               Martial Arts School  0.00
# 8          Mediterranean Restaurant  0.00
# 9                       Men's Store  0.00
# 10               Mexican Restaurant  0.00
# 11        Middle Eastern Restaurant  0.00
#
#
# ----Little Portugal, Trinity----
#                             venue  freq
# 0                             Bar  0.10
# 1                            Café  0.05
# 2           Vietnamese Restaurant  0.05
# 3   Vegetarian / Vegan Restaurant  0.05
# 4                      Restaurant  0.05
# 5                     Coffee Shop  0.05
# 6                     Men's Store  0.05
# 7                Asian Restaurant  0.05
# 8              Italian Restaurant  0.02
# 9                    Cocktail Bar  0.02
# 10               Cuban Restaurant  0.02
# 11                   Cupcake Shop  0.02
#
#
# ----North Toronto West, Lawrence Park----
#                    venue  freq
# 0         Clothing Store  0.17
# 1            Coffee Shop  0.11
# 2            Yoga Studio  0.06
# 3     Mexican Restaurant  0.06
# 4   Fast Food Restaurant  0.06
# 5                    Spa  0.06
# 6    Sporting Goods Shop  0.06
# 7                   Café  0.06
# 8     Salon / Barbershop  0.06
# 9             Restaurant  0.06
# 10    Chinese Restaurant  0.06
# 11                 Diner  0.06
#
#
# ----Parkdale, Roncesvalles----
#                           venue  freq
# 0                     Gift Shop  0.14
# 1                Breakfast Spot  0.14
# 2            Italian Restaurant  0.07
# 3              Cuban Restaurant  0.07
# 4                   Coffee Shop  0.07
# 5                    Restaurant  0.07
# 6                  Dessert Shop  0.07
# 7                 Movie Theater  0.07
# 8                       Dog Run  0.07
# 9   Eastern European Restaurant  0.07
# 10                          Bar  0.07
# 11                    Bookstore  0.07
#
#
# ----Queen's Park, Ontario Provincial Government----
#                   venue  freq
# 0           Coffee Shop  0.20
# 1      Sushi Restaurant  0.07
# 2           Yoga Studio  0.03
# 3                  Café  0.03
# 4                   Bar  0.03
# 5   Fried Chicken Joint  0.03
# 6              Beer Bar  0.03
# 7                   Spa  0.03
# 8              Creperie  0.03
# 9         Burrito Place  0.03
# 10   Mexican Restaurant  0.03
# 11       Sandwich Place  0.03
#
#
# ----Regent Park, Harbourfront----
#                    venue  freq
# 0            Coffee Shop  0.17
# 1                   Park  0.07
# 2                 Bakery  0.07
# 3                    Pub  0.07
# 4                Theater  0.04
# 5                   Café  0.04
# 6         Breakfast Spot  0.04
# 7            Event Space  0.02
# 8      Electronics Store  0.02
# 9                    Spa  0.02
# 10  Gym / Fitness Center  0.02
# 11            Shoe Store  0.02
#
#
# ----Richmond, Adelaide, King----
#                       venue  freq
# 0               Coffee Shop  0.10
# 1                      Café  0.08
# 2           Thai Restaurant  0.04
# 3              Concert Hall  0.04
# 4                Restaurant  0.04
# 5       American Restaurant  0.04
# 6                Steakhouse  0.04
# 7               Pizza Place  0.04
# 8   New American Restaurant  0.02
# 9                 Bookstore  0.02
# 10                Speakeasy  0.02
# 11     Brazilian Restaurant  0.02
#
#
# ----Rosedale----
#                               venue  freq
# 0                              Park  0.50
# 1                        Playground  0.25
# 2                             Trail  0.25
# 3                       Yoga Studio  0.00
# 4   Molecular Gastronomy Restaurant  0.00
# 5                            Lounge  0.00
# 6                  Malay Restaurant  0.00
# 7                            Market  0.00
# 8               Martial Arts School  0.00
# 9          Mediterranean Restaurant  0.00
# 10                      Men's Store  0.00
# 11               Mexican Restaurant  0.00
#
#
# ----Roselawn----
#                         venue  freq
# 0                      Garden  0.33
# 1                 Music Venue  0.33
# 2                Home Service  0.33
# 3                 Yoga Studio  0.00
# 4         Monument / Landmark  0.00
# 5            Malay Restaurant  0.00
# 6                      Market  0.00
# 7         Martial Arts School  0.00
# 8    Mediterranean Restaurant  0.00
# 9                 Men's Store  0.00
# 10         Mexican Restaurant  0.00
# 11  Middle Eastern Restaurant  0.00
#
#
# ----Runnymede, Swansea----
#                         venue  freq
# 0                 Coffee Shop  0.12
# 1                        Café  0.09
# 2                 Pizza Place  0.06
# 3          Italian Restaurant  0.06
# 4                         Pub  0.06
# 5            Sushi Restaurant  0.06
# 6   Latin American Restaurant  0.03
# 7             Supplement Shop  0.03
# 8                  Restaurant  0.03
# 9           French Restaurant  0.03
# 10                  Bookstore  0.03
# 11                   Boutique  0.03
#
#
# ----St. James Town----
#                      venue  freq
# 0                     Café  0.10
# 1           Cosmetics Shop  0.06
# 2              Coffee Shop  0.06
# 3                   Bakery  0.04
# 4           Farmers Market  0.04
# 5      Japanese Restaurant  0.04
# 6                Gastropub  0.04
# 7       Seafood Restaurant  0.04
# 8                 Creperie  0.04
# 9                     Park  0.04
# 10  Furniture / Home Store  0.02
# 11       German Restaurant  0.02
#
#
# ----St. James Town, Cabbagetown----
#                    venue  freq
# 0             Restaurant  0.07
# 1            Coffee Shop  0.07
# 2                 Bakery  0.07
# 3                   Café  0.05
# 4     Chinese Restaurant  0.05
# 5     Italian Restaurant  0.05
# 6                    Pub  0.05
# 7            Pizza Place  0.05
# 8              Gift Shop  0.02
# 9              Pet Store  0.02
# 10  Caribbean Restaurant  0.02
# 11        Sandwich Place  0.02
#
#
# ----Stn A PO Boxes----
#                   venue  freq
# 0                  Café  0.06
# 1              Creperie  0.04
# 2    Seafood Restaurant  0.04
# 3   Japanese Restaurant  0.04
# 4           Cheese Shop  0.04
# 5              Beer Bar  0.04
# 6          Cocktail Bar  0.04
# 7           Coffee Shop  0.04
# 8            Restaurant  0.04
# 9        Farmers Market  0.04
# 10               Bakery  0.04
# 11                  Pub  0.04
#
#
# ----Studio District----
#                         venue  freq
# 0                 Coffee Shop  0.08
# 1                     Brewery  0.06
# 2                      Bakery  0.06
# 3                   Gastropub  0.06
# 4                        Café  0.06
# 5         American Restaurant  0.06
# 6                 Cheese Shop  0.03
# 7                   Bookstore  0.03
# 8                 Fish Market  0.03
# 9   Middle Eastern Restaurant  0.03
# 10         Seafood Restaurant  0.03
# 11             Clothing Store  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                     venue  freq
# 0      Light Rail Station  0.14
# 1             Coffee Shop  0.14
# 2        Sushi Restaurant  0.07
# 3   Vietnamese Restaurant  0.07
# 4             Pizza Place  0.07
# 5            Liquor Store  0.07
# 6                    Bank  0.07
# 7              Restaurant  0.07
# 8     American Restaurant  0.07
# 9             Supermarket  0.07
# 10                    Pub  0.07
# 11    Fried Chicken Joint  0.07
#
#
# ----The Annex, North Midtown, Yorkville----
#                 venue  freq
# 0      Sandwich Place  0.15
# 1                Café  0.15
# 2         Coffee Shop  0.10
# 3        Liquor Store  0.05
# 4           BBQ Joint  0.05
# 5   Indian Restaurant  0.05
# 6          Donut Shop  0.05
# 7            Pharmacy  0.05
# 8      History Museum  0.05
# 9                 Pub  0.05
# 10       Burger Joint  0.05
# 11               Park  0.05
#
#
# ----The Beaches----
#                         venue  freq
# 0            Asian Restaurant   0.2
# 1                       Trail   0.2
# 2                         Pub   0.2
# 3           Health Food Store   0.2
# 4         Moroccan Restaurant   0.0
# 5            Malay Restaurant   0.0
# 6                      Market   0.0
# 7         Martial Arts School   0.0
# 8    Mediterranean Restaurant   0.0
# 9                 Men's Store   0.0
# 10         Mexican Restaurant   0.0
# 11  Middle Eastern Restaurant   0.0
#
#
# ----The Danforth West, Riverdale----
#                      venue  freq
# 0         Greek Restaurant  0.17
# 1              Coffee Shop  0.10
# 2       Italian Restaurant  0.07
# 3   Furniture / Home Store  0.05
# 4           Ice Cream Shop  0.05
# 5              Yoga Studio  0.02
# 6             Liquor Store  0.02
# 7       Frozen Yogurt Shop  0.02
# 8                Juice Bar  0.02
# 9                Bookstore  0.02
# 10                     Spa  0.02
# 11         Bubble Tea Shop  0.02
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                   venue  freq
# 0                  Café  0.12
# 1           Coffee Shop  0.12
# 2                 Hotel  0.06
# 3    Seafood Restaurant  0.06
# 4            Restaurant  0.06
# 5                Bakery  0.04
# 6   Japanese Restaurant  0.04
# 7        Sandwich Place  0.02
# 8          Concert Hall  0.02
# 9              Beer Bar  0.02
# 10               Museum  0.02
# 11        Deli / Bodega  0.02
#
#
# ----University of Toronto, Harbord----
#                     venue  freq
# 0                    Café  0.15
# 1                     Bar  0.06
# 2     Japanese Restaurant  0.06
# 3                  Bakery  0.06
# 4               Bookstore  0.06
# 5          Sandwich Place  0.06
# 6             College Gym  0.03
# 7                Beer Bar  0.03
# 8              Beer Store  0.03
# 9              Restaurant  0.03
# 10  College Arts Building  0.03
# 11            Yoga Studio  0.03

# %%
# Creamos una funcion para ordenar en forma descendente los lugares

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# mostramos los primeros 12 lugares de cada barrio en un Dataframe nuevo

num_top_venues = 12

indicators = ['st', 'nd', 'rd']

# crear las columnas acorde al numero de sitios populares
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# crear un nuevo dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  Business reply mail Processing Centre, South C...    Light Rail Station
# 3  CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0              Beer Bar        Farmers Market                Bakery
# 1           Coffee Shop        Breakfast Spot                Bakery
# 2           Yoga Studio                   Spa  Gym / Fitness Center
# 3        Airport Lounge      Airport Terminal           Coffee Shop
# 4        Sandwich Place       Bubble Tea Shop                  Café
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0          Cocktail Bar    Seafood Restaurant              Pharmacy
# 1                   Gym                   Bar            Restaurant
# 2  Fast Food Restaurant        Farmers Market            Comic Shop
# 3                 Plane              Boutique         Boat or Ferry
# 4    Italian Restaurant            Comic Shop           Salad Place
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue  \
# 0           Cheese Shop             Restaurant         Clothing Store
# 1          Intersection     Italian Restaurant           Climbing Gym
# 2                  Park            Pizza Place       Recording Studio
# 3   Rental Car Location                    Bar        Harbor / Marina
# 4          Burger Joint  Portuguese Restaurant             Poke Place
#
#   11th Most Common Venue   12th Most Common Venue
# 0     Italian Restaurant                   Bistro
# 1  Performing Arts Venue            Grocery Store
# 2             Restaurant                  Butcher
# 3       Sculpture Garden                  Airport
# 4                   Park  New American Restaurant

# %%
# establecer el número de agrupaciones en 5
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# ejecutar k-means
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# revisar las etiquetas de las agrupaciones generadas para cada fila del dataframe
kmeans.labels_[0:5]
# Out:
# array([2, 2, 0, 0, 0], dtype=int32)

# %%
# añadir etiquetas
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Toronto_merged = Tor_d

# juntar Toronto_grouped con Toronto_data 
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
Toronto_merged['Cluster Labels'] = Toronto_merged['Cluster Labels'].fillna("0").astype(int)


Toronto_merged.head() # revisar las ultimas columnas
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260 -79.360636               0           Coffee Shop
# 1  43.662301 -79.389494               0           Coffee Shop
# 2  43.657162 -79.378937               0           Coffee Shop
# 3  43.651494 -79.375418               2                  Café
# 4  43.676357 -79.293031               2      Asian Restaurant
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                  Park                Bakery                   Pub
# 1      Sushi Restaurant                  Bank                   Spa
# 2                  Café             Bookstore        Clothing Store
# 3        Cosmetics Shop           Coffee Shop                  Park
# 4                 Trail     Health Food Store                   Pub
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Breakfast Spot                  Café               Theater
# 1         Smoothie Shop              Beer Bar        Sandwich Place
# 2      Ramen Restaurant               Theater        Cosmetics Shop
# 3              Creperie    Seafood Restaurant   Japanese Restaurant
# 4                 Diner          Dance Studio         Deli / Bodega
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 0    Mexican Restaurant            Shoe Store             Restaurant
# 1         Burrito Place                  Café                   Park
# 2  Fast Food Restaurant        Sandwich Place                  Plaza
# 3                Bakery        Farmers Market              Gastropub
# 4      Department Store          Dessert Shop               Wine Bar
#
#   11th Most Common Venue 12th Most Common Venue
# 0         Chocolate Shop  Performing Arts Venue
# 1     College Auditorium      College Cafeteria
# 2                  Diner                  Hotel
# 3           Cocktail Bar       Department Store
# 4           Cupcake Shop    Distribution Center

# %%
# creamos mapa de agrupacion
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# establecer el esquema de color para las agrupaciones
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# añadir marcadores al mapa
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_1a02df6c09524aa7b1f4b176ff273ac2%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1a02df6c09524aa7b1f4b176ff273ac2%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_1a02df6c09524aa7b1f4b176ff273ac2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_1a02df6c09524aa7b1f4b176ff273ac2%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Examinamos las agrupaciones pudiendo observar que categorias distinguen a cada agrupacion

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 0                           Regent Park, Harbourfront               0
# 1         Queen's Park, Ontario Provincial Government               0
# 2                            Garden District, Ryerson               0
# 6                                  Central Bay Street               0
# 12                       The Danforth West, Riverdale               0
# 15                     India Bazaar, The Beaches West               0
# 17                                    Studio District               0
# 20                                   Davisville North               0
# 23                  North Toronto West, Lawrence Park               0
# 24                The Annex, North Midtown, Yorkville               0
# 25                             Parkdale, Roncesvalles               0
# 26                                         Davisville               0
# 28                                 Runnymede, Swansea               0
# 29                        Moore Park, Summerhill East               0
# 31  Summerhill West, Rathnelly, South Hill, Forest...               0
# 32  CN Tower, King and Spadina, Railway Lands, Har...               0
# 37                               Church and Wellesley               0
# 38  Business reply mail Processing Centre, South C...               0
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0            Coffee Shop                  Park                Bakery
# 1            Coffee Shop      Sushi Restaurant                  Bank
# 2            Coffee Shop                  Café             Bookstore
# 6            Coffee Shop        Sandwich Place       Bubble Tea Shop
# 12      Greek Restaurant           Coffee Shop    Italian Restaurant
# 15                  Park                   Gym        Sandwich Place
# 17           Coffee Shop                Bakery             Gastropub
# 20     Food & Drink Shop                  Park           Pizza Place
# 23        Clothing Store           Coffee Shop   Sporting Goods Shop
# 24        Sandwich Place                  Café           Coffee Shop
# 25             Gift Shop        Breakfast Spot      Cuban Restaurant
# 26          Dessert Shop        Sandwich Place           Pizza Place
# 28           Coffee Shop                  Café    Italian Restaurant
# 29                   NaN                   NaN                   NaN
# 31           Coffee Shop    Light Rail Station                   Pub
# 32       Airport Service        Airport Lounge      Airport Terminal
# 37           Coffee Shop           Yoga Studio   Japanese Restaurant
# 38    Light Rail Station           Yoga Studio                   Spa
#
#      4th Most Common Venue    5th Most Common Venue 6th Most Common Venue  \
# 0                      Pub           Breakfast Spot                  Café
# 1                      Spa            Smoothie Shop              Beer Bar
# 2           Clothing Store         Ramen Restaurant               Theater
# 6                     Café       Italian Restaurant            Comic Shop
# 12  Furniture / Home Store           Ice Cream Shop        Cosmetics Shop
# 15           Burrito Place       Italian Restaurant          Liquor Store
# 17                 Brewery      American Restaurant                  Café
# 20          Breakfast Spot           Sandwich Place  Gym / Fitness Center
# 23    Gym / Fitness Center  Health & Beauty Service  Fast Food Restaurant
# 24               BBQ Joint                      Pub          Liquor Store
# 25                 Dog Run       Italian Restaurant                   Bar
# 26      Italian Restaurant                      Gym       Thai Restaurant
# 28             Pizza Place         Sushi Restaurant                   Pub
# 29                     NaN                      NaN                   NaN
# 31     Fried Chicken Joint         Sushi Restaurant                  Bank
# 32             Coffee Shop                    Plane              Boutique
# 37             Men's Store                  Gay Bar      Sushi Restaurant
# 38    Gym / Fitness Center     Fast Food Restaurant        Farmers Market
#
#    7th Most Common Venue 8th Most Common Venue  9th Most Common Venue  \
# 0                Theater    Mexican Restaurant             Shoe Store
# 1         Sandwich Place         Burrito Place                   Café
# 2         Cosmetics Shop  Fast Food Restaurant         Sandwich Place
# 6            Salad Place          Burger Joint  Portuguese Restaurant
# 12               Brewery       Bubble Tea Shop             Restaurant
# 15            Restaurant        Ice Cream Shop                    Pub
# 17                 Diner                   Bar         Ice Cream Shop
# 20      Department Store          Dance Studio                  Hotel
# 23                 Diner    Mexican Restaurant                   Park
# 24            Donut Shop                  Park           Burger Joint
# 25          Dessert Shop            Restaurant              Bookstore
# 26      Sushi Restaurant                  Café            Coffee Shop
# 28              Boutique                   Bar          Smoothie Shop
# 29                   NaN                   NaN                    NaN
# 31            Restaurant   American Restaurant            Supermarket
# 32         Boat or Ferry   Rental Car Location                    Bar
# 37            Restaurant         Burrito Place           Burger Joint
# 38            Comic Shop                  Park            Pizza Place
#
#          10th Most Common Venue 11th Most Common Venue  \
# 0                    Restaurant         Chocolate Shop
# 1                          Park     College Auditorium
# 2                         Plaza                  Diner
# 6                    Poke Place                   Park
# 12                         Café                    Pub
# 15                   Steakhouse   Fast Food Restaurant
# 17           Italian Restaurant     Seafood Restaurant
# 20                 Cupcake Shop                Dog Run
# 23           Chinese Restaurant                   Café
# 24                     Pharmacy            Pizza Place
# 25  Eastern European Restaurant            Coffee Shop
# 26                Deli / Bodega         Farmers Market
# 28          Indie Movie Theater              Bookstore
# 29                          NaN                    NaN
# 31                  Pizza Place           Liquor Store
# 32              Harbor / Marina       Sculpture Garden
# 37              Bubble Tea Shop               Sake Bar
# 38             Recording Studio             Restaurant
#
#        12th Most Common Venue
# 0       Performing Arts Venue
# 1           College Cafeteria
# 2                       Hotel
# 6     New American Restaurant
# 12       Caribbean Restaurant
# 15          Fish & Chips Shop
# 17  Latin American Restaurant
# 20        Distribution Center
# 23                 Restaurant
# 24                Cheese Shop
# 25              Movie Theater
# 26               Costume Shop
# 28              Burrito Place
# 29                        NaN
# 31      Vietnamese Restaurant
# 32                    Airport
# 37             Ice Cream Shop
# 38                    Butcher

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#      Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 18  Lawrence Park               1                  Park              Bus Line
# 33       Rosedale               1                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 18           Swim School              Wine Bar          Dance Studio
# 33                 Trail      Cuban Restaurant            Donut Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18            Donut Shop      Doner Restaurant               Dog Run
# 33      Doner Restaurant               Dog Run   Distribution Center
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 18   Distribution Center         Discount Store                  Diner
# 33        Discount Store                  Diner           Dessert Shop
#
#    12th Most Common Venue
# 18           Dessert Shop
# 33       Department Store

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 3                                      St. James Town               2
# 4                                         The Beaches               2
# 5                                         Berczy Park               2
# 7                                            Christie               2
# 8                            Richmond, Adelaide, King               2
# 9                        Dufferin, Dovercourt Village               2
# 10  Harbourfront East, Union Station, Toronto Islands               2
# 11                           Little Portugal, Trinity               2
# 13           Toronto Dominion Centre, Design Exchange               2
# 14       Brockton, Parkdale Village, Exhibition Place               2
# 16                     Commerce Court, Victoria Hotel               2
# 22                      High Park, The Junction South               2
# 27                     University of Toronto, Harbord               2
# 30          Kensington Market, Chinatown, Grange Park               2
# 34                                     Stn A PO Boxes               2
# 35                        St. James Town, Cabbagetown               2
# 36             First Canadian Place, Underground city               2
#
#    1st Most Common Venue          2nd Most Common Venue 3rd Most Common Venue  \
# 3                   Café                 Cosmetics Shop           Coffee Shop
# 4       Asian Restaurant                          Trail     Health Food Store
# 5            Coffee Shop                       Beer Bar        Farmers Market
# 7          Grocery Store                           Café                  Park
# 8            Coffee Shop                           Café   American Restaurant
# 9                 Bakery                       Pharmacy         Grocery Store
# 10           Coffee Shop                       Aquarium                 Hotel
# 11                   Bar                           Café           Coffee Shop
# 13           Coffee Shop                           Café                 Hotel
# 14                  Café                    Coffee Shop        Breakfast Spot
# 16                  Café                     Restaurant           Coffee Shop
# 22                  Café             Mexican Restaurant       Thai Restaurant
# 27                  Café                         Bakery                   Bar
# 30                  Café  Vegetarian / Vegan Restaurant                   Bar
# 34                  Café             Seafood Restaurant           Cheese Shop
# 35           Coffee Shop                         Bakery            Restaurant
# 36                  Café                    Coffee Shop            Restaurant
#
#     4th Most Common Venue          5th Most Common Venue  \
# 3                    Park                       Creperie
# 4                     Pub                          Diner
# 5                  Bakery                   Cocktail Bar
# 7             Candy Store                     Restaurant
# 8              Restaurant                     Steakhouse
# 9                    Bank                            Bar
# 10                Brewery                          Plaza
# 11  Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 13     Seafood Restaurant                     Restaurant
# 14                 Bakery                            Gym
# 16                  Hotel                            Gym
# 22              Speakeasy                            Bar
# 27    Japanese Restaurant                 Sandwich Place
# 30           Burger Joint          Vietnamese Restaurant
# 34               Beer Bar                         Bakery
# 35                   Café             Italian Restaurant
# 36     Seafood Restaurant                  Deli / Bodega
#
#         6th Most Common Venue 7th Most Common Venue    8th Most Common Venue  \
# 3          Seafood Restaurant   Japanese Restaurant                   Bakery
# 4                Dance Studio         Deli / Bodega         Department Store
# 5          Seafood Restaurant              Pharmacy              Cheese Shop
# 7          Italian Restaurant            Baby Store              Coffee Shop
# 8                Concert Hall           Pizza Place          Thai Restaurant
# 9   Middle Eastern Restaurant                  Café              Supermarket
# 10                       Café                  Park  New American Restaurant
# 11           Asian Restaurant            Restaurant              Men's Store
# 13                     Bakery   Japanese Restaurant              Salad Place
# 14                        Bar            Restaurant             Intersection
# 16         Seafood Restaurant             Gastropub      Japanese Restaurant
# 22                     Bakery           Flea Market                    Diner
# 27                  Bookstore         Poutine Place                      Pub
# 30       Caribbean Restaurant                Bakery              Coffee Shop
# 34        Japanese Restaurant            Restaurant                      Pub
# 35                Pizza Place    Chinese Restaurant                      Pub
# 36                      Hotel                   Gym      American Restaurant
#
#    9th Most Common Venue 10th Most Common Venue     11th Most Common Venue  \
# 3         Farmers Market              Gastropub               Cocktail Bar
# 4           Dessert Shop               Wine Bar               Cupcake Shop
# 5             Restaurant         Clothing Store         Italian Restaurant
# 7              Nightclub         Discount Store               Dance Studio
# 8                  Hotel   Gym / Fitness Center                 Smoke Shop
# 9              Pet Store             Smoke Shop                Music Venue
# 10        Scenic Lookout            Salad Place                  Roof Deck
# 11   Japanese Restaurant              Juice Bar          Korean Restaurant
# 13           IT Services         Sandwich Place                      Plaza
# 14    Italian Restaurant           Climbing Gym      Performing Arts Venue
# 16   American Restaurant          Deli / Bodega                     Bakery
# 22    Italian Restaurant    Arts & Crafts Store  Cajun / Creole Restaurant
# 27          Dessert Shop  College Arts Building                 Restaurant
# 30    Mexican Restaurant           Dessert Shop                Record Shop
# 34        Farmers Market           Cocktail Bar                Coffee Shop
# 35             Gift Shop         Sandwich Place        Japanese Restaurant
# 36          Concert Hall    Japanese Restaurant             Sandwich Place
#
#    12th Most Common Venue
# 3        Department Store
# 4     Distribution Center
# 5                  Bistro
# 7     Distribution Center
# 8               Juice Bar
# 9                    Park
# 10             Restaurant
# 11               Wine Bar
# 13                    Gym
# 14          Grocery Store
# 16             Steakhouse
# 22              Bookstore
# 27           Noodle House
# 30            Cheese Shop
# 34               Creperie
# 35                  Diner
# 36              Bookstore

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                        Neighborhood  Cluster Labels  \
# 21  Forest Hill North & West, Forest Hill Road Park               3
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 21         Jewelry Store                 Trail    Mexican Restaurant
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 21      Sushi Restaurant              Wine Bar          Dance Studio
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 21            Donut Shop      Doner Restaurant               Dog Run
#
#    10th Most Common Venue 11th Most Common Venue 12th Most Common Venue
# 21    Distribution Center         Discount Store                  Diner

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 19     Roselawn               4          Home Service                Garden
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 19           Music Venue      Cuban Restaurant            Donut Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 19      Doner Restaurant               Dog Run   Distribution Center
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 19        Discount Store                  Diner           Dessert Shop
#
#    12th Most Common Venue
# 19       Department Store
