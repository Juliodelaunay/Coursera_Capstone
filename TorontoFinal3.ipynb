# %% [markdown]
# ## Agrupacion y Segmentacion de Vecindarios de Toronto

# %% [markdown]
# #### Parte 1

# %%
# Importacion de Librerias necesarias

# %%
pip install BeautifulSoup4
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: BeautifulSoup4 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (4.9.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from BeautifulSoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: lxml in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (4.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup  
import requests 
import pandas as pd
import lxml

# %%
#Importacion , Scraping y Creacion de Dataframe

# %%
url =requests.get ("https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=958430791").text

# %%
soup = BeautifulSoup(url,'lxml')

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
df = pd.read_html(str(My_table))[0]
df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned                        NaN
# 1         M2A      Not assigned                        NaN
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Eliminamos Municipios 'Not assigned'

# %%
drop_Not=df[df['Borough']=='Not assigned'].index
df.drop (drop_Not, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Asignamos Vecindarios 'Not assigned' a Municipio

# %%
df[df['Neighborhood']=='Not assigned']=df['Borough'].reset_index()
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Requerimiento filas-columnas

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# #### Parte 2

# %%
# Importacion de archivo csv con coordenadas

# %%
from io import StringIO

url = requests.get(' http://cocl.us/Geospatial_data')
csv_raw = StringIO(url.text)
datos_geo = pd.read_csv(csv_raw)

# %%
datos_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Relacionamos Dataframes

# %%
df=pd.merge(df,datos_geo,how='left')

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# #### Parte 3

# %%
# Importacion Librerias Necesarias

# %%
# !pip install folium
import numpy as np
import json
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
print('Librerias importadas')
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Requirement already satisfied: folium in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (0.12.1)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (0.4.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (2.22.0)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from folium) (1.19.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
# Librerias importadas

# %%
# Filtramos a Municipios que sean ' Toronto '


Tor_d = df[df['Borough'].str.contains('Toronto')].reset_index(drop=True)
Tor_d.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %%
# Obtenemos nro filas 

Tor_d.shape
# Out:
# (39, 5)

# %%
# Obtenemos coordenadas para Toronto

address = 'Toronto, ON'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Coordenadas Toronto {}, {}.'.format(latitude, longitude))
# Out:
# Coordenadas Toronto 43.6534817, -79.3839347.

# %%
# Creamos mapa de Toronto y añadimos los marcadores

map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(Tor_d['Latitude'], Tor_d['Longitude'], Tor_d['Borough'], Tor_d['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=2,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_77dff60314ec460c9479f51eeb058b21%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_77dff60314ec460c9479f51eeb058b21%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_77dff60314ec460c9479f51eeb058b21%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_77dff60314ec460c9479f51eeb058b21%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Definimos version y credenciales para la API de Foursquare con un limite de 50 devoluciones

CLIENT_ID = 'DBBPKNBZNEC2JFO4JL13AJOJLMHLHOCOYWGTY5ZXJFXRJXYD' 
CLIENT_SECRET = 'YA51Q1Y4XHBRUZE1025SHVN3AKMX20MJHBBELS0BANSJWKMA' 
VERSION = '20180605' 
LIMIT = 50

# %%
# Definimos funcion para obtener los 100 sitios en un radio de 500 mts para cada barrio

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # crear la URL de solicitud de API
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
                # solicitud GET
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # regresa solo información relevante de cada sitio cercano
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Corremos la funcion getNearbyVenues para cada barrio creando un Dataframe 'Toronto_venues'

Toronto_venues = getNearbyVenues(names=Tor_d['Neighborhood'],
                                   latitudes=Tor_d['Latitude'],
                                   longitudes=Tor_d['Longitude'])
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# High Park, The Junction South
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
# mostramos Dataframe y revisamos tamaño

print(Toronto_venues.shape)
Toronto_venues.head()
# Out:
# (1181, 7)
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4          Impact Kitchen       43.656369       -79.356980
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4           Restaurant

# %%
# Observemos cuantos sitios se devolvieron por barrio

Toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            50
# Brockton, Parkdale Village, Exhibition Place                           23
# Business reply mail Processing Centre, South Ce...                     17
# CN Tower, King and Spadina, Railway Lands, Harb...                     14
# Central Bay Street                                                     50
# Christie                                                               16
# Church and Wellesley                                                   50
# Commerce Court, Victoria Hotel                                         50
# Davisville                                                             37
# Davisville North                                                        7
# Dufferin, Dovercourt Village                                           15
# First Canadian Place, Underground city                                 50
# Forest Hill North & West, Forest Hill Road Park                         4
# Garden District, Ryerson                                               50
# Harbourfront East, Union Station, Toronto Islands                      50
# High Park, The Junction South                                          25
# India Bazaar, The Beaches West                                         21
# Kensington Market, Chinatown, Grange Park                              50
# Lawrence Park                                                           4
# Little Portugal, Trinity                                               42
# Moore Park, Summerhill East                                             3
# North Toronto West, Lawrence Park                                      22
# Parkdale, Roncesvalles                                                 14
# Queen's Park, Ontario Provincial Government                            30
# Regent Park, Harbourfront                                              44
# Richmond, Adelaide, King                                               50
# Rosedale                                                                4
# Roselawn                                                                2
# Runnymede, Swansea                                                     40
# St. James Town                                                         50
# St. James Town, Cabbagetown                                            45
# Stn A PO Boxes                                                         50
# Studio District                                                        36
# Summerhill West, Rathnelly, South Hill, Forest ...                     14
# The Annex, North Midtown, Yorkville                                    22
# The Beaches                                                             4
# The Danforth West, Riverdale                                           42
# Toronto Dominion Centre, Design Exchange                               50
# University of Toronto, Harbord                                         34
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             50
# Brockton, Parkdale Village, Exhibition Place                            23
# Business reply mail Processing Centre, South Ce...                      17
# CN Tower, King and Spadina, Railway Lands, Harb...                      14
# Central Bay Street                                                      50
# Christie                                                                16
# Church and Wellesley                                                    50
# Commerce Court, Victoria Hotel                                          50
# Davisville                                                              37
# Davisville North                                                         7
# Dufferin, Dovercourt Village                                            15
# First Canadian Place, Underground city                                  50
# Forest Hill North & West, Forest Hill Road Park                          4
# Garden District, Ryerson                                                50
# Harbourfront East, Union Station, Toronto Islands                       50
# High Park, The Junction South                                           25
# India Bazaar, The Beaches West                                          21
# Kensington Market, Chinatown, Grange Park                               50
# Lawrence Park                                                            4
# Little Portugal, Trinity                                                42
# Moore Park, Summerhill East                                              3
# North Toronto West, Lawrence Park                                       22
# Parkdale, Roncesvalles                                                  14
# Queen's Park, Ontario Provincial Government                             30
# Regent Park, Harbourfront                                               44
# Richmond, Adelaide, King                                                50
# Rosedale                                                                 4
# Roselawn                                                                 2
# Runnymede, Swansea                                                      40
# St. James Town                                                          50
# St. James Town, Cabbagetown                                             45
# Stn A PO Boxes                                                          50
# Studio District                                                         36
# Summerhill West, Rathnelly, South Hill, Forest ...                      14
# The Annex, North Midtown, Yorkville                                     22
# The Beaches                                                              4
# The Danforth West, Riverdale                                            42
# Toronto Dominion Centre, Design Exchange                                50
# University of Toronto, Harbord                                          34
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            50              50
# Brockton, Parkdale Village, Exhibition Place           23              23
# Business reply mail Processing Centre, South Ce...     17              17
# CN Tower, King and Spadina, Railway Lands, Harb...     14              14
# Central Bay Street                                     50              50
# Christie                                               16              16
# Church and Wellesley                                   50              50
# Commerce Court, Victoria Hotel                         50              50
# Davisville                                             37              37
# Davisville North                                        7               7
# Dufferin, Dovercourt Village                           15              15
# First Canadian Place, Underground city                 50              50
# Forest Hill North & West, Forest Hill Road Park         4               4
# Garden District, Ryerson                               50              50
# Harbourfront East, Union Station, Toronto Islands      50              50
# High Park, The Junction South                          25              25
# India Bazaar, The Beaches West                         21              21
# Kensington Market, Chinatown, Grange Park              50              50
# Lawrence Park                                           4               4
# Little Portugal, Trinity                               42              42
# Moore Park, Summerhill East                             3               3
# North Toronto West, Lawrence Park                      22              22
# Parkdale, Roncesvalles                                 14              14
# Queen's Park, Ontario Provincial Government            30              30
# Regent Park, Harbourfront                              44              44
# Richmond, Adelaide, King                               50              50
# Rosedale                                                4               4
# Roselawn                                                2               2
# Runnymede, Swansea                                     40              40
# St. James Town                                         50              50
# St. James Town, Cabbagetown                            45              45
# Stn A PO Boxes                                         50              50
# Studio District                                        36              36
# Summerhill West, Rathnelly, South Hill, Forest ...     14              14
# The Annex, North Midtown, Yorkville                    22              22
# The Beaches                                             4               4
# The Danforth West, Riverdale                           42              42
# Toronto Dominion Centre, Design Exchange               50              50
# University of Toronto, Harbord                         34              34
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      50
# Brockton, Parkdale Village, Exhibition Place                     23
# Business reply mail Processing Centre, South Ce...               17
# CN Tower, King and Spadina, Railway Lands, Harb...               14
# Central Bay Street                                               50
# Christie                                                         16
# Church and Wellesley                                             50
# Commerce Court, Victoria Hotel                                   50
# Davisville                                                       37
# Davisville North                                                  7
# Dufferin, Dovercourt Village                                     15
# First Canadian Place, Underground city                           50
# Forest Hill North & West, Forest Hill Road Park                   4
# Garden District, Ryerson                                         50
# Harbourfront East, Union Station, Toronto Islands                50
# High Park, The Junction South                                    25
# India Bazaar, The Beaches West                                   21
# Kensington Market, Chinatown, Grange Park                        50
# Lawrence Park                                                     4
# Little Portugal, Trinity                                         42
# Moore Park, Summerhill East                                       3
# North Toronto West, Lawrence Park                                22
# Parkdale, Roncesvalles                                           14
# Queen's Park, Ontario Provincial Government                      30
# Regent Park, Harbourfront                                        44
# Richmond, Adelaide, King                                         50
# Rosedale                                                          4
# Roselawn                                                          2
# Runnymede, Swansea                                               40
# St. James Town                                                   50
# St. James Town, Cabbagetown                                      45
# Stn A PO Boxes                                                   50
# Studio District                                                  36
# Summerhill West, Rathnelly, South Hill, Forest ...               14
# The Annex, North Midtown, Yorkville                              22
# The Beaches                                                       4
# The Danforth West, Riverdale                                     42
# Toronto Dominion Centre, Design Exchange                         50
# University of Toronto, Harbord                                   34
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     50
# Brockton, Parkdale Village, Exhibition Place                    23
# Business reply mail Processing Centre, South Ce...              17
# CN Tower, King and Spadina, Railway Lands, Harb...              14
# Central Bay Street                                              50
# Christie                                                        16
# Church and Wellesley                                            50
# Commerce Court, Victoria Hotel                                  50
# Davisville                                                      37
# Davisville North                                                 7
# Dufferin, Dovercourt Village                                    15
# First Canadian Place, Underground city                          50
# Forest Hill North & West, Forest Hill Road Park                  4
# Garden District, Ryerson                                        50
# Harbourfront East, Union Station, Toronto Islands               50
# High Park, The Junction South                                   25
# India Bazaar, The Beaches West                                  21
# Kensington Market, Chinatown, Grange Park                       50
# Lawrence Park                                                    4
# Little Portugal, Trinity                                        42
# Moore Park, Summerhill East                                      3
# North Toronto West, Lawrence Park                               22
# Parkdale, Roncesvalles                                          14
# Queen's Park, Ontario Provincial Government                     30
# Regent Park, Harbourfront                                       44
# Richmond, Adelaide, King                                        50
# Rosedale                                                         4
# Roselawn                                                         2
# Runnymede, Swansea                                              40
# St. James Town                                                  50
# St. James Town, Cabbagetown                                     45
# Stn A PO Boxes                                                  50
# Studio District                                                 36
# Summerhill West, Rathnelly, South Hill, Forest ...              14
# The Annex, North Midtown, Yorkville                             22
# The Beaches                                                      4
# The Danforth West, Riverdale                                    42
# Toronto Dominion Centre, Design Exchange                        50
# University of Toronto, Harbord                                  34

# %%
# Vemos cuantas categorias unicas hay por barrio

print('There are {} uniques categories.'.format(len(Toronto_venues['Venue Category'].unique())))
# Out:
# There are 223 uniques categories.

# %%
#Analizamos cada barrio



# codificación
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# añadir la columna de barrio de regreso al dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood'] 

# mover la columna de barrio a la primer columna
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_onehot.shape
# Out:
# (1181, 223)

# %%
# Agrupamos las filas por barrios tomando el parametro de promedio de ocurrencia de cada categoria


Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()
Toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio  \
# 0                                         Berczy Park     0.000000
# 1        Brockton, Parkdale Village, Exhibition Place     0.000000
# 2   Business reply mail Processing Centre, South C...     0.058824
# 3   CN Tower, King and Spadina, Railway Lands, Har...     0.000000
# 4                                  Central Bay Street     0.020000
# 5                                            Christie     0.000000
# 6                                Church and Wellesley     0.040000
# 7                      Commerce Court, Victoria Hotel     0.000000
# 8                                          Davisville     0.000000
# 9                                    Davisville North     0.000000
# 10                       Dufferin, Dovercourt Village     0.000000
# 11             First Canadian Place, Underground city     0.000000
# 12    Forest Hill North & West, Forest Hill Road Park     0.000000
# 13                           Garden District, Ryerson     0.000000
# 14  Harbourfront East, Union Station, Toronto Islands     0.000000
# 15                      High Park, The Junction South     0.000000
# 16                     India Bazaar, The Beaches West     0.000000
# 17          Kensington Market, Chinatown, Grange Park     0.000000
# 18                                      Lawrence Park     0.000000
# 19                           Little Portugal, Trinity     0.023810
# 20                        Moore Park, Summerhill East     0.000000
# 21                  North Toronto West, Lawrence Park     0.045455
# 22                             Parkdale, Roncesvalles     0.000000
# 23        Queen's Park, Ontario Provincial Government     0.033333
# 24                          Regent Park, Harbourfront     0.022727
# 25                           Richmond, Adelaide, King     0.000000
# 26                                           Rosedale     0.000000
# 27                                           Roselawn     0.000000
# 28                                 Runnymede, Swansea     0.025000
# 29                                     St. James Town     0.000000
# 30                        St. James Town, Cabbagetown     0.000000
# 31                                     Stn A PO Boxes     0.000000
# 32                                    Studio District     0.027778
# 33  Summerhill West, Rathnelly, South Hill, Forest...     0.000000
# 34                The Annex, North Midtown, Yorkville     0.000000
# 35                                        The Beaches     0.000000
# 36                       The Danforth West, Riverdale     0.023810
# 37           Toronto Dominion Centre, Design Exchange     0.000000
# 38                     University of Toronto, Harbord     0.029412
#
#     Adult Boutique   Airport  Airport Food Court  Airport Gate  \
# 0             0.00  0.000000            0.000000      0.000000
# 1             0.00  0.000000            0.000000      0.000000
# 2             0.00  0.000000            0.000000      0.000000
# 3             0.00  0.071429            0.071429      0.071429
# 4             0.00  0.000000            0.000000      0.000000
# 5             0.00  0.000000            0.000000      0.000000
# 6             0.02  0.000000            0.000000      0.000000
# 7             0.00  0.000000            0.000000      0.000000
# 8             0.00  0.000000            0.000000      0.000000
# 9             0.00  0.000000            0.000000      0.000000
# 10            0.00  0.000000            0.000000      0.000000
# 11            0.00  0.000000            0.000000      0.000000
# 12            0.00  0.000000            0.000000      0.000000
# 13            0.00  0.000000            0.000000      0.000000
# 14            0.00  0.000000            0.000000      0.000000
# 15            0.00  0.000000            0.000000      0.000000
# 16            0.00  0.000000            0.000000      0.000000
# 17            0.00  0.000000            0.000000      0.000000
# 18            0.00  0.000000            0.000000      0.000000
# 19            0.00  0.000000            0.000000      0.000000
# 20            0.00  0.000000            0.000000      0.000000
# 21            0.00  0.000000            0.000000      0.000000
# 22            0.00  0.000000            0.000000      0.000000
# 23            0.00  0.000000            0.000000      0.000000
# 24            0.00  0.000000            0.000000      0.000000
# 25            0.00  0.000000            0.000000      0.000000
# 26            0.00  0.000000            0.000000      0.000000
# 27            0.00  0.000000            0.000000      0.000000
# 28            0.00  0.000000            0.000000      0.000000
# 29            0.00  0.000000            0.000000      0.000000
# 30            0.00  0.000000            0.000000      0.000000
# 31            0.00  0.000000            0.000000      0.000000
# 32            0.00  0.000000            0.000000      0.000000
# 33            0.00  0.000000            0.000000      0.000000
# 34            0.00  0.000000            0.000000      0.000000
# 35            0.00  0.000000            0.000000      0.000000
# 36            0.00  0.000000            0.000000      0.000000
# 37            0.00  0.000000            0.000000      0.000000
# 38            0.00  0.000000            0.000000      0.000000
#
#     Airport Lounge  Airport Service  Airport Terminal  American Restaurant  \
# 0         0.000000         0.000000          0.000000             0.000000
# 1         0.000000         0.000000          0.000000             0.000000
# 2         0.000000         0.000000          0.000000             0.000000
# 3         0.142857         0.071429          0.071429             0.000000
# 4         0.000000         0.000000          0.000000             0.000000
# 5         0.000000         0.000000          0.000000             0.000000
# 6         0.000000         0.000000          0.000000             0.000000
# 7         0.000000         0.000000          0.000000             0.040000
# 8         0.000000         0.000000          0.000000             0.000000
# 9         0.000000         0.000000          0.000000             0.000000
# 10        0.000000         0.000000          0.000000             0.000000
# 11        0.000000         0.000000          0.000000             0.040000
# 12        0.000000         0.000000          0.000000             0.000000
# 13        0.000000         0.000000          0.000000             0.000000
# 14        0.000000         0.000000          0.000000             0.000000
# 15        0.000000         0.000000          0.000000             0.000000
# 16        0.000000         0.000000          0.000000             0.000000
# 17        0.000000         0.000000          0.000000             0.000000
# 18        0.000000         0.000000          0.000000             0.000000
# 19        0.000000         0.000000          0.000000             0.000000
# 20        0.000000         0.000000          0.000000             0.000000
# 21        0.000000         0.000000          0.000000             0.000000
# 22        0.000000         0.000000          0.000000             0.000000
# 23        0.000000         0.000000          0.000000             0.000000
# 24        0.000000         0.000000          0.000000             0.000000
# 25        0.000000         0.000000          0.000000             0.040000
# 26        0.000000         0.000000          0.000000             0.000000
# 27        0.000000         0.000000          0.000000             0.000000
# 28        0.000000         0.000000          0.000000             0.000000
# 29        0.000000         0.000000          0.000000             0.020000
# 30        0.000000         0.000000          0.000000             0.000000
# 31        0.000000         0.000000          0.000000             0.000000
# 32        0.000000         0.000000          0.000000             0.055556
# 33        0.000000         0.000000          0.000000             0.071429
# 34        0.000000         0.000000          0.000000             0.000000
# 35        0.000000         0.000000          0.000000             0.000000
# 36        0.000000         0.000000          0.000000             0.023810
# 37        0.000000         0.000000          0.000000             0.020000
# 38        0.000000         0.000000          0.000000             0.000000
#
#     ...  Theme Restaurant  Tibetan Restaurant  Toy / Game Store    Trail  \
# 0   ...              0.00             0.00000          0.000000  0.00000
# 1   ...              0.00             0.00000          0.000000  0.00000
# 2   ...              0.00             0.00000          0.000000  0.00000
# 3   ...              0.00             0.00000          0.000000  0.00000
# 4   ...              0.00             0.00000          0.000000  0.00000
# 5   ...              0.00             0.00000          0.000000  0.00000
# 6   ...              0.02             0.00000          0.000000  0.00000
# 7   ...              0.00             0.00000          0.000000  0.00000
# 8   ...              0.00             0.00000          0.027027  0.00000
# 9   ...              0.00             0.00000          0.000000  0.00000
# 10  ...              0.00             0.00000          0.000000  0.00000
# 11  ...              0.00             0.00000          0.000000  0.00000
# 12  ...              0.00             0.00000          0.000000  0.25000
# 13  ...              0.00             0.00000          0.000000  0.00000
# 14  ...              0.00             0.00000          0.000000  0.00000
# 15  ...              0.00             0.00000          0.000000  0.00000
# 16  ...              0.00             0.00000          0.000000  0.00000
# 17  ...              0.00             0.00000          0.000000  0.00000
# 18  ...              0.00             0.00000          0.000000  0.00000
# 19  ...              0.00             0.00000          0.000000  0.00000
# 20  ...              0.00             0.00000          0.000000  0.00000
# 21  ...              0.00             0.00000          0.000000  0.00000
# 22  ...              0.00             0.00000          0.000000  0.00000
# 23  ...              0.00             0.00000          0.000000  0.00000
# 24  ...              0.00             0.00000          0.000000  0.00000
# 25  ...              0.00             0.00000          0.000000  0.00000
# 26  ...              0.00             0.00000          0.000000  0.25000
# 27  ...              0.00             0.00000          0.000000  0.00000
# 28  ...              0.00             0.00000          0.000000  0.00000
# 29  ...              0.00             0.00000          0.000000  0.00000
# 30  ...              0.00             0.00000          0.000000  0.00000
# 31  ...              0.00             0.00000          0.000000  0.00000
# 32  ...              0.00             0.00000          0.000000  0.00000
# 33  ...              0.00             0.00000          0.000000  0.00000
# 34  ...              0.00             0.00000          0.000000  0.00000
# 35  ...              0.00             0.00000          0.000000  0.25000
# 36  ...              0.00             0.02381          0.000000  0.02381
# 37  ...              0.00             0.00000          0.000000  0.00000
# 38  ...              0.00             0.00000          0.000000  0.00000
#
#     Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0            0.00                        0.02000          0.000000
# 1            0.00                        0.00000          0.000000
# 2            0.00                        0.00000          0.000000
# 3            0.00                        0.00000          0.000000
# 4            0.00                        0.02000          0.000000
# 5            0.00                        0.00000          0.000000
# 6            0.00                        0.00000          0.000000
# 7            0.00                        0.02000          0.000000
# 8            0.00                        0.00000          0.000000
# 9            0.00                        0.00000          0.000000
# 10           0.00                        0.00000          0.000000
# 11           0.00                        0.02000          0.000000
# 12           0.00                        0.00000          0.000000
# 13           0.00                        0.00000          0.000000
# 14           0.02                        0.00000          0.000000
# 15           0.00                        0.00000          0.000000
# 16           0.00                        0.00000          0.000000
# 17           0.00                        0.06000          0.000000
# 18           0.00                        0.00000          0.000000
# 19           0.00                        0.02381          0.000000
# 20           0.00                        0.00000          0.000000
# 21           0.00                        0.00000          0.000000
# 22           0.00                        0.00000          0.000000
# 23           0.00                        0.00000          0.000000
# 24           0.00                        0.00000          0.000000
# 25           0.00                        0.02000          0.000000
# 26           0.00                        0.00000          0.000000
# 27           0.00                        0.00000          0.000000
# 28           0.00                        0.02500          0.000000
# 29           0.00                        0.02000          0.000000
# 30           0.00                        0.00000          0.000000
# 31           0.00                        0.02000          0.000000
# 32           0.00                        0.00000          0.000000
# 33           0.00                        0.00000          0.000000
# 34           0.00                        0.00000          0.000000
# 35           0.00                        0.00000          0.000000
# 36           0.00                        0.00000          0.000000
# 37           0.02                        0.02000          0.000000
# 38           0.00                        0.00000          0.029412
#
#     Vietnamese Restaurant  Wine Bar  Wine Shop
# 0                0.000000   0.00000   0.000000
# 1                0.000000   0.00000   0.000000
# 2                0.000000   0.00000   0.000000
# 3                0.000000   0.00000   0.000000
# 4                0.000000   0.00000   0.000000
# 5                0.000000   0.00000   0.000000
# 6                0.000000   0.00000   0.000000
# 7                0.000000   0.00000   0.000000
# 8                0.000000   0.00000   0.000000
# 9                0.000000   0.00000   0.000000
# 10               0.000000   0.00000   0.066667
# 11               0.000000   0.00000   0.000000
# 12               0.000000   0.00000   0.000000
# 13               0.000000   0.00000   0.000000
# 14               0.000000   0.00000   0.000000
# 15               0.000000   0.00000   0.000000
# 16               0.000000   0.00000   0.000000
# 17               0.040000   0.02000   0.000000
# 18               0.000000   0.00000   0.000000
# 19               0.047619   0.02381   0.000000
# 20               0.000000   0.00000   0.000000
# 21               0.000000   0.00000   0.000000
# 22               0.000000   0.00000   0.000000
# 23               0.000000   0.00000   0.000000
# 24               0.000000   0.00000   0.000000
# 25               0.000000   0.00000   0.000000
# 26               0.000000   0.00000   0.000000
# 27               0.000000   0.00000   0.000000
# 28               0.000000   0.00000   0.000000
# 29               0.000000   0.00000   0.000000
# 30               0.000000   0.00000   0.000000
# 31               0.000000   0.00000   0.000000
# 32               0.000000   0.00000   0.000000
# 33               0.071429   0.00000   0.000000
# 34               0.000000   0.00000   0.000000
# 35               0.000000   0.00000   0.000000
# 36               0.000000   0.00000   0.000000
# 37               0.000000   0.00000   0.000000
# 38               0.000000   0.00000   0.000000
#
# [39 rows x 223 columns]

# %%
#Observamos tamaño Dataframe

Toronto_grouped.shape
# Out:
# (39, 223)

# %%
# Visualizamos cada barrio con los 12 lugares mas comunes

num_top_venues = 12

for hood in Toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                       venue  freq
# 0               Coffee Shop  0.06
# 1                Restaurant  0.04
# 2                    Bakery  0.04
# 3               Cheese Shop  0.04
# 4        Seafood Restaurant  0.04
# 5              Cocktail Bar  0.04
# 6            Farmers Market  0.04
# 7                  Beer Bar  0.04
# 8   Comfort Food Restaurant  0.02
# 9          Department Store  0.02
# 10                   Bistro  0.02
# 11             Liquor Store  0.02
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#                     venue  freq
# 0                    Café  0.13
# 1             Coffee Shop  0.09
# 2          Breakfast Spot  0.09
# 3                  Bakery  0.09
# 4           Grocery Store  0.04
# 5      Italian Restaurant  0.04
# 6               Pet Store  0.04
# 7   Performing Arts Venue  0.04
# 8                     Gym  0.04
# 9               Nightclub  0.04
# 10             Restaurant  0.04
# 11           Climbing Gym  0.04
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                    venue  freq
# 0            Yoga Studio  0.06
# 1          Auto Workshop  0.06
# 2             Comic Shop  0.06
# 3            Pizza Place  0.06
# 4                   Park  0.06
# 5       Recording Studio  0.06
# 6             Restaurant  0.06
# 7          Burrito Place  0.06
# 8                Brewery  0.06
# 9             Skate Park  0.06
# 10  Fast Food Restaurant  0.06
# 11                   Spa  0.06
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                   venue  freq
# 0        Airport Lounge  0.14
# 1              Boutique  0.07
# 2       Harbor / Marina  0.07
# 3      Sculpture Garden  0.07
# 4           Coffee Shop  0.07
# 5   Rental Car Location  0.07
# 6         Boat or Ferry  0.07
# 7                   Bar  0.07
# 8      Airport Terminal  0.07
# 9       Airport Service  0.07
# 10         Airport Gate  0.07
# 11   Airport Food Court  0.07
#
#
# ----Central Bay Street----
#                     venue  freq
# 0             Coffee Shop  0.16
# 1                    Café  0.06
# 2          Sandwich Place  0.06
# 3         Bubble Tea Shop  0.04
# 4      Italian Restaurant  0.04
# 5          Discount Store  0.02
# 6            Burger Joint  0.02
# 7             Salad Place  0.02
# 8   Portuguese Restaurant  0.02
# 9              Comic Shop  0.02
# 10                   Park  0.02
# 11                 Office  0.02
#
#
# ----Christie----
#                  venue  freq
# 0        Grocery Store  0.25
# 1                 Café  0.19
# 2                 Park  0.12
# 3           Restaurant  0.06
# 4           Baby Store  0.06
# 5   Italian Restaurant  0.06
# 6          Candy Store  0.06
# 7            Nightclub  0.06
# 8   Athletics & Sports  0.06
# 9          Coffee Shop  0.06
# 10        Noodle House  0.00
# 11            Pharmacy  0.00
#
#
# ----Church and Wellesley----
#                   venue  freq
# 0           Coffee Shop  0.06
# 1           Yoga Studio  0.04
# 2           Men's Store  0.04
# 3            Restaurant  0.04
# 4      Sushi Restaurant  0.04
# 5   Japanese Restaurant  0.04
# 6               Gay Bar  0.04
# 7              Sake Bar  0.02
# 8    Salon / Barbershop  0.02
# 9                  Café  0.02
# 10        Burrito Place  0.02
# 11     Ramen Restaurant  0.02
#
#
# ----Commerce Court, Victoria Hotel----
#                   venue  freq
# 0                  Café  0.10
# 1           Coffee Shop  0.08
# 2                 Hotel  0.08
# 3            Restaurant  0.08
# 4                   Gym  0.06
# 5    Seafood Restaurant  0.06
# 6                Bakery  0.04
# 7             Gastropub  0.04
# 8   Japanese Restaurant  0.04
# 9   American Restaurant  0.04
# 10        Deli / Bodega  0.04
# 11                 Park  0.02
#
#
# ----Davisville----
#                  venue  freq
# 0          Pizza Place  0.11
# 1       Sandwich Place  0.08
# 2         Dessert Shop  0.08
# 3                  Gym  0.05
# 4                 Café  0.05
# 5          Coffee Shop  0.05
# 6   Italian Restaurant  0.05
# 7     Sushi Restaurant  0.05
# 8     Toy / Game Store  0.03
# 9                Diner  0.03
# 10      Farmers Market  0.03
# 11             Brewery  0.03
#
#
# ----Davisville North----
#                        venue  freq
# 0           Department Store  0.14
# 1       Gym / Fitness Center  0.14
# 2                       Park  0.14
# 3             Breakfast Spot  0.14
# 4                      Hotel  0.14
# 5          Food & Drink Shop  0.14
# 6             Sandwich Place  0.14
# 7        Monument / Landmark  0.00
# 8        Martial Arts School  0.00
# 9   Mediterranean Restaurant  0.00
# 10               Men's Store  0.00
# 11        Mexican Restaurant  0.00
#
#
# ----Dufferin, Dovercourt Village----
#                         venue  freq
# 0                      Bakery  0.13
# 1                    Pharmacy  0.13
# 2                   Wine Shop  0.07
# 3   Middle Eastern Restaurant  0.07
# 4                 Music Venue  0.07
# 5                        Park  0.07
# 6                   Pet Store  0.07
# 7                        Café  0.07
# 8                     Brewery  0.07
# 9                 Supermarket  0.07
# 10                        Bar  0.07
# 11                       Bank  0.07
#
#
# ----First Canadian Place, Underground city----
#                   venue  freq
# 0                  Café  0.12
# 1           Coffee Shop  0.10
# 2            Restaurant  0.06
# 3          Concert Hall  0.04
# 4   Japanese Restaurant  0.04
# 5         Deli / Bodega  0.04
# 6                   Gym  0.04
# 7    Seafood Restaurant  0.04
# 8   American Restaurant  0.04
# 9                 Hotel  0.04
# 10     Asian Restaurant  0.04
# 11                  Bar  0.02
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#                               venue  freq
# 0                             Trail  0.25
# 1                     Jewelry Store  0.25
# 2                          Bus Line  0.25
# 3                  Sushi Restaurant  0.25
# 4                       Yoga Studio  0.00
# 5   Molecular Gastronomy Restaurant  0.00
# 6                  Malay Restaurant  0.00
# 7                            Market  0.00
# 8               Martial Arts School  0.00
# 9          Mediterranean Restaurant  0.00
# 10                      Men's Store  0.00
# 11               Mexican Restaurant  0.00
#
#
# ----Garden District, Ryerson----
#                      venue  freq
# 0              Coffee Shop  0.08
# 1                     Café  0.06
# 2     Fast Food Restaurant  0.04
# 3         Ramen Restaurant  0.04
# 4           Clothing Store  0.04
# 5           Cosmetics Shop  0.04
# 6                Bookstore  0.04
# 7                  Theater  0.04
# 8                    Diner  0.02
# 9               Restaurant  0.02
# 10  Furniture / Home Store  0.02
# 11     Sporting Goods Shop  0.02
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#               venue  freq
# 0          Aquarium  0.06
# 1    Scenic Lookout  0.04
# 2             Hotel  0.04
# 3       Pizza Place  0.04
# 4              Park  0.04
# 5             Plaza  0.04
# 6           Brewery  0.04
# 7              Café  0.04
# 8       Coffee Shop  0.04
# 9   Bubble Tea Shop  0.02
# 10           Bistro  0.02
# 11       Sports Bar  0.02
#
#
# ----High Park, The Junction South----
#                      venue  freq
# 0      Arts & Crafts Store  0.08
# 1                     Café  0.08
# 2       Mexican Restaurant  0.08
# 3          Thai Restaurant  0.08
# 4           Discount Store  0.04
# 5                      Bar  0.04
# 6   Furniture / Home Store  0.04
# 7                   Bakery  0.04
# 8     Fast Food Restaurant  0.04
# 9              Music Venue  0.04
# 10      Italian Restaurant  0.04
# 11               Gastropub  0.04
#
#
# ----India Bazaar, The Beaches West----
#                    venue  freq
# 0                   Park  0.10
# 1            Pizza Place  0.10
# 2         Sandwich Place  0.10
# 3              Pet Store  0.05
# 4          Movie Theater  0.05
# 5          Burrito Place  0.05
# 6           Liquor Store  0.05
# 7   Fast Food Restaurant  0.05
# 8      Fish & Chips Shop  0.05
# 9      Food & Drink Shop  0.05
# 10            Steakhouse  0.05
# 11      Sushi Restaurant  0.05
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                             venue  freq
# 0                            Café  0.10
# 1   Vegetarian / Vegan Restaurant  0.06
# 2                             Bar  0.06
# 3           Vietnamese Restaurant  0.04
# 4                    Burger Joint  0.04
# 5                          Bakery  0.04
# 6              Mexican Restaurant  0.04
# 7                     Coffee Shop  0.04
# 8            Caribbean Restaurant  0.04
# 9                Ramen Restaurant  0.02
# 10                    Cheese Shop  0.02
# 11                     Food Truck  0.02
#
#
# ----Lawrence Park----
#                         venue  freq
# 0          Dim Sum Restaurant  0.25
# 1                        Park  0.25
# 2                    Bus Line  0.25
# 3                 Swim School  0.25
# 4                 Yoga Studio  0.00
# 5            Malay Restaurant  0.00
# 6                      Market  0.00
# 7         Martial Arts School  0.00
# 8    Mediterranean Restaurant  0.00
# 9                 Men's Store  0.00
# 10         Mexican Restaurant  0.00
# 11  Middle Eastern Restaurant  0.00
#
#
# ----Little Portugal, Trinity----
#                     venue  freq
# 0                     Bar  0.12
# 1        Asian Restaurant  0.05
# 2                    Café  0.05
# 3   Vietnamese Restaurant  0.05
# 4             Coffee Shop  0.05
# 5              Restaurant  0.05
# 6             Men's Store  0.05
# 7     Japanese Restaurant  0.02
# 8            Cocktail Bar  0.02
# 9        Cuban Restaurant  0.02
# 10           Cupcake Shop  0.02
# 11                  Diner  0.02
#
#
# ----Moore Park, Summerhill East----
#                         venue  freq
# 0                      Lawyer  0.33
# 1                        Park  0.33
# 2                Tennis Court  0.33
# 3         Monument / Landmark  0.00
# 4                      Lounge  0.00
# 5            Malay Restaurant  0.00
# 6                      Market  0.00
# 7         Martial Arts School  0.00
# 8    Mediterranean Restaurant  0.00
# 9                 Men's Store  0.00
# 10         Mexican Restaurant  0.00
# 11  Middle Eastern Restaurant  0.00
#
#
# ----North Toronto West, Lawrence Park----
#                    venue  freq
# 0         Clothing Store  0.14
# 1            Coffee Shop  0.09
# 2            Yoga Studio  0.05
# 3                   Café  0.05
# 4                  Diner  0.05
# 5   Fast Food Restaurant  0.05
# 6   Gym / Fitness Center  0.05
# 7         Ice Cream Shop  0.05
# 8     Italian Restaurant  0.05
# 9     Mexican Restaurant  0.05
# 10                  Park  0.05
# 11             Pet Store  0.05
#
#
# ----Parkdale, Roncesvalles----
#                           venue  freq
# 0                     Gift Shop  0.14
# 1                Breakfast Spot  0.14
# 2                    Restaurant  0.07
# 3   Eastern European Restaurant  0.07
# 4                           Bar  0.07
# 5                       Dog Run  0.07
# 6                 Movie Theater  0.07
# 7                     Bookstore  0.07
# 8                  Dessert Shop  0.07
# 9            Italian Restaurant  0.07
# 10                  Coffee Shop  0.07
# 11             Cuban Restaurant  0.07
#
#
# ----Queen's Park, Ontario Provincial Government----
#                  venue  freq
# 0          Coffee Shop  0.20
# 1     Sushi Restaurant  0.07
# 2          Yoga Studio  0.03
# 3    College Cafeteria  0.03
# 4                  Spa  0.03
# 5        Smoothie Shop  0.03
# 6        Burrito Place  0.03
# 7                 Café  0.03
# 8       Sandwich Place  0.03
# 9   College Auditorium  0.03
# 10            Creperie  0.03
# 11                 Bar  0.03
#
#
# ----Regent Park, Harbourfront----
#              venue  freq
# 0      Coffee Shop  0.18
# 1              Pub  0.07
# 2           Bakery  0.07
# 3             Park  0.07
# 4   Breakfast Spot  0.05
# 5             Café  0.05
# 6       Restaurant  0.05
# 7          Theater  0.05
# 8   Cosmetics Shop  0.02
# 9       Shoe Store  0.02
# 10  Chocolate Shop  0.02
# 11   Historic Site  0.02
#
#
# ----Richmond, Adelaide, King----
#                       venue  freq
# 0               Coffee Shop  0.10
# 1                      Café  0.08
# 2              Concert Hall  0.04
# 3           Thai Restaurant  0.04
# 4                Restaurant  0.04
# 5       American Restaurant  0.04
# 6                Steakhouse  0.04
# 7               Pizza Place  0.04
# 8   New American Restaurant  0.02
# 9             Deli / Bodega  0.02
# 10                Speakeasy  0.02
# 11                Bookstore  0.02
#
#
# ----Rosedale----
#                         venue  freq
# 0                        Park  0.50
# 1                  Playground  0.25
# 2                       Trail  0.25
# 3         Monument / Landmark  0.00
# 4                      Lounge  0.00
# 5            Malay Restaurant  0.00
# 6                      Market  0.00
# 7         Martial Arts School  0.00
# 8    Mediterranean Restaurant  0.00
# 9                 Men's Store  0.00
# 10         Mexican Restaurant  0.00
# 11  Middle Eastern Restaurant  0.00
#
#
# ----Roselawn----
#                         venue  freq
# 0                      Garden   0.5
# 1                Home Service   0.5
# 2                 Yoga Studio   0.0
# 3         Moroccan Restaurant   0.0
# 4            Malay Restaurant   0.0
# 5                      Market   0.0
# 6         Martial Arts School   0.0
# 7    Mediterranean Restaurant   0.0
# 8                 Men's Store   0.0
# 9          Mexican Restaurant   0.0
# 10  Middle Eastern Restaurant   0.0
# 11         Miscellaneous Shop   0.0
#
#
# ----Runnymede, Swansea----
#                         venue  freq
# 0                 Coffee Shop  0.08
# 1                        Café  0.08
# 2            Sushi Restaurant  0.05
# 3          Italian Restaurant  0.05
# 4                 Pizza Place  0.05
# 5                         Pub  0.05
# 6           Fish & Chips Shop  0.02
# 7   Latin American Restaurant  0.02
# 8           French Restaurant  0.02
# 9                   Bookstore  0.02
# 10                        Spa  0.02
# 11              Burrito Place  0.02
#
#
# ----St. James Town----
#                      venue  freq
# 0                     Café  0.10
# 1           Cosmetics Shop  0.06
# 2              Coffee Shop  0.06
# 3                Gastropub  0.04
# 4       Seafood Restaurant  0.04
# 5                   Bakery  0.04
# 6                     Park  0.04
# 7                 Creperie  0.04
# 8           Farmers Market  0.04
# 9      Japanese Restaurant  0.04
# 10  Furniture / Home Store  0.02
# 11                Beer Bar  0.02
#
#
# ----St. James Town, Cabbagetown----
#                  venue  freq
# 0          Pizza Place  0.09
# 1                 Park  0.07
# 2          Coffee Shop  0.07
# 3                 Café  0.04
# 4               Bakery  0.04
# 5   Italian Restaurant  0.04
# 6                  Pub  0.04
# 7           Restaurant  0.04
# 8         Liquor Store  0.02
# 9          Snack Place  0.02
# 10       Deli / Bodega  0.02
# 11              Market  0.02
#
#
# ----Stn A PO Boxes----
#                   venue  freq
# 0                  Café  0.06
# 1    Seafood Restaurant  0.04
# 2   Japanese Restaurant  0.04
# 3              Beer Bar  0.04
# 4           Cheese Shop  0.04
# 5          Cocktail Bar  0.04
# 6           Coffee Shop  0.04
# 7            Restaurant  0.04
# 8                Bakery  0.04
# 9        Farmers Market  0.04
# 10                  Pub  0.04
# 11             Creperie  0.04
#
#
# ----Studio District----
#                         venue  freq
# 0                 Coffee Shop  0.08
# 1                        Café  0.06
# 2                   Gastropub  0.06
# 3                     Brewery  0.06
# 4         American Restaurant  0.06
# 5                      Bakery  0.06
# 6   Middle Eastern Restaurant  0.03
# 7          Seafood Restaurant  0.03
# 8                 Fish Market  0.03
# 9                 Cheese Shop  0.03
# 10                  Bookstore  0.03
# 11             Clothing Store  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                     venue  freq
# 0      Light Rail Station  0.14
# 1             Coffee Shop  0.14
# 2     Fried Chicken Joint  0.07
# 3                     Pub  0.07
# 4             Supermarket  0.07
# 5                    Bank  0.07
# 6        Sushi Restaurant  0.07
# 7              Restaurant  0.07
# 8            Liquor Store  0.07
# 9   Vietnamese Restaurant  0.07
# 10            Pizza Place  0.07
# 11    American Restaurant  0.07
#
#
# ----The Annex, North Midtown, Yorkville----
#                         venue  freq
# 0              Sandwich Place  0.14
# 1                        Café  0.14
# 2                 Coffee Shop  0.09
# 3               Grocery Store  0.05
# 4                   BBQ Joint  0.05
# 5                        Park  0.05
# 6                         Pub  0.05
# 7                  Donut Shop  0.05
# 8                 Shoe Repair  0.05
# 9                Burger Joint  0.05
# 10  Middle Eastern Restaurant  0.05
# 11                   Pharmacy  0.05
#
#
# ----The Beaches----
#                        venue  freq
# 0                        Pub  0.25
# 1                      Trail  0.25
# 2          Health Food Store  0.25
# 3                Yoga Studio  0.00
# 4        Monument / Landmark  0.00
# 5                     Lounge  0.00
# 6           Malay Restaurant  0.00
# 7                     Market  0.00
# 8        Martial Arts School  0.00
# 9   Mediterranean Restaurant  0.00
# 10               Men's Store  0.00
# 11        Mexican Restaurant  0.00
#
#
# ----The Danforth West, Riverdale----
#                      venue  freq
# 0         Greek Restaurant  0.17
# 1              Coffee Shop  0.10
# 2       Italian Restaurant  0.07
# 3           Ice Cream Shop  0.05
# 4   Furniture / Home Store  0.05
# 5              Yoga Studio  0.02
# 6       Frozen Yogurt Shop  0.02
# 7                Juice Bar  0.02
# 8                      Spa  0.02
# 9                Bookstore  0.02
# 10                  Lounge  0.02
# 11                 Brewery  0.02
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                   venue  freq
# 0           Coffee Shop  0.12
# 1                  Café  0.10
# 2            Restaurant  0.06
# 3                 Hotel  0.06
# 4    Seafood Restaurant  0.06
# 5             Gastropub  0.04
# 6   Japanese Restaurant  0.04
# 7                Bakery  0.04
# 8                   Pub  0.02
# 9   Sporting Goods Shop  0.02
# 10            Speakeasy  0.02
# 11       Sandwich Place  0.02
#
#
# ----University of Toronto, Harbord----
#                     venue  freq
# 0                    Café  0.15
# 1     Japanese Restaurant  0.06
# 2          Sandwich Place  0.06
# 3               Bookstore  0.06
# 4                     Bar  0.06
# 5                  Bakery  0.06
# 6       French Restaurant  0.03
# 7              Beer Store  0.03
# 8                Beer Bar  0.03
# 9             Coffee Shop  0.03
# 10                   Bank  0.03
# 11  College Arts Building  0.03

# %%
# Creamos una funcion para ordenar en forma descendente los lugares

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# mostramos los primeros 12 lugares de cada barrio en un Dataframe nuevo

num_top_venues = 12

indicators = ['st', 'nd', 'rd']

# crear las columnas acorde al numero de sitios populares
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# crear un nuevo dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  Business reply mail Processing Centre, South C...           Yoga Studio
# 3  CN Tower, King and Spadina, Railway Lands, Har...        Airport Lounge
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0    Seafood Restaurant                Bakery              Beer Bar
# 1                Bakery        Breakfast Spot           Coffee Shop
# 2  Gym / Fitness Center            Skate Park               Brewery
# 3         Boat or Ferry      Airport Terminal              Boutique
# 4        Sandwich Place                  Café       Bubble Tea Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Farmers Market          Cocktail Bar           Cheese Shop
# 1               Stadium            Restaurant                   Bar
# 2         Burrito Place                   Spa            Restaurant
# 3   Rental Car Location                   Bar       Harbor / Marina
# 4    Italian Restaurant            Comic Shop           Salad Place
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue  \
# 0            Restaurant                   Café                  Hotel
# 1          Intersection     Italian Restaurant           Climbing Gym
# 2        Farmers Market   Fast Food Restaurant       Recording Studio
# 3           Coffee Shop       Sculpture Garden     Airport Food Court
# 4          Burger Joint  Portuguese Restaurant             Poke Place
#
#   11th Most Common Venue   12th Most Common Venue
# 0                 Bistro           Breakfast Spot
# 1              Pet Store                      Gym
# 2          Auto Workshop       Light Rail Station
# 3        Airport Service             Airport Gate
# 4                   Park  New American Restaurant

# %%
# establecer el número de agrupaciones en 5
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# ejecutar k-means
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# revisar las etiquetas de las agrupaciones generadas para cada fila del dataframe
kmeans.labels_[0:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int32)

# %%
# añadir etiquetas
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Toronto_merged = Tor_d

# juntar Toronto_grouped con Toronto_data 
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
Toronto_merged['Cluster Labels'] = Toronto_merged['Cluster Labels'].fillna("0").astype(int)


Toronto_merged.head() # revisar las ultimas columnas
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260 -79.360636               0           Coffee Shop
# 1  43.662301 -79.389494               0           Coffee Shop
# 2  43.657162 -79.378937               0           Coffee Shop
# 3  43.651494 -79.375418               0                  Café
# 4  43.676357 -79.293031               0                 Trail
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                Bakery                   Pub                  Park
# 1      Sushi Restaurant                  Bank                   Spa
# 2                  Café             Bookstore        Clothing Store
# 3           Coffee Shop        Cosmetics Shop                  Park
# 4                   Pub     Health Food Store             Wine Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0        Breakfast Spot            Restaurant                  Café
# 1         Smoothie Shop              Beer Bar        Sandwich Place
# 2               Theater      Ramen Restaurant        Cosmetics Shop
# 3        Farmers Market                Bakery              Creperie
# 4          Cupcake Shop            Donut Shop      Doner Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 0               Theater        Cosmetics Shop             Beer Store
# 1         Burrito Place                  Café                   Park
# 2  Fast Food Restaurant         Burrito Place                  Diner
# 3   Japanese Restaurant    Seafood Restaurant              Gastropub
# 4               Dog Run   Distribution Center         Discount Store
#
#   11th Most Common Venue 12th Most Common Venue
# 0             Shoe Store         Chocolate Shop
# 1     College Auditorium      College Cafeteria
# 2         Sandwich Place             Restaurant
# 3            Fish Market      Electronics Store
# 4                  Diner     Dim Sum Restaurant

# %%
# creamos mapa de agrupacion
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# establecer el esquema de color para las agrupaciones
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# añadir marcadores al mapa
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3aab27d69361425d9da3a054bab9aa83%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3aab27d69361425d9da3a054bab9aa83%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3aab27d69361425d9da3a054bab9aa83%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3aab27d69361425d9da3a054bab9aa83%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.6534817%2C%20-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# Examinamos las agrupaciones pudiendo observar que categorias distinguen a cada agrupacion

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 0                           Regent Park, Harbourfront               0
# 1         Queen's Park, Ontario Provincial Government               0
# 2                            Garden District, Ryerson               0
# 3                                      St. James Town               0
# 4                                         The Beaches               0
# 5                                         Berczy Park               0
# 6                                  Central Bay Street               0
# 7                                            Christie               0
# 8                            Richmond, Adelaide, King               0
# 9                        Dufferin, Dovercourt Village               0
# 10  Harbourfront East, Union Station, Toronto Islands               0
# 11                           Little Portugal, Trinity               0
# 12                       The Danforth West, Riverdale               0
# 13           Toronto Dominion Centre, Design Exchange               0
# 14       Brockton, Parkdale Village, Exhibition Place               0
# 15                     India Bazaar, The Beaches West               0
# 16                     Commerce Court, Victoria Hotel               0
# 17                                    Studio District               0
# 20                                   Davisville North               0
# 22                      High Park, The Junction South               0
# 23                  North Toronto West, Lawrence Park               0
# 24                The Annex, North Midtown, Yorkville               0
# 25                             Parkdale, Roncesvalles               0
# 26                                         Davisville               0
# 27                     University of Toronto, Harbord               0
# 28                                 Runnymede, Swansea               0
# 30          Kensington Market, Chinatown, Grange Park               0
# 31  Summerhill West, Rathnelly, South Hill, Forest...               0
# 32  CN Tower, King and Spadina, Railway Lands, Har...               0
# 34                                     Stn A PO Boxes               0
# 35                        St. James Town, Cabbagetown               0
# 36             First Canadian Place, Underground city               0
# 37                               Church and Wellesley               0
# 38  Business reply mail Processing Centre, South C...               0
#
#    1st Most Common Venue 2nd Most Common Venue          3rd Most Common Venue  \
# 0            Coffee Shop                Bakery                            Pub
# 1            Coffee Shop      Sushi Restaurant                           Bank
# 2            Coffee Shop                  Café                      Bookstore
# 3                   Café           Coffee Shop                 Cosmetics Shop
# 4                  Trail                   Pub              Health Food Store
# 5            Coffee Shop    Seafood Restaurant                         Bakery
# 6            Coffee Shop        Sandwich Place                           Café
# 7          Grocery Store                  Café                           Park
# 8            Coffee Shop                  Café                   Concert Hall
# 9               Pharmacy                Bakery                      Wine Shop
# 10              Aquarium               Brewery                    Pizza Place
# 11                   Bar           Coffee Shop          Vietnamese Restaurant
# 12      Greek Restaurant           Coffee Shop             Italian Restaurant
# 13           Coffee Shop                  Café                          Hotel
# 14                  Café                Bakery                 Breakfast Spot
# 15                  Park        Sandwich Place                    Pizza Place
# 16                  Café                 Hotel                     Restaurant
# 17           Coffee Shop                  Café                      Gastropub
# 20                  Park                 Hotel                 Breakfast Spot
# 22    Mexican Restaurant                  Café            Arts & Crafts Store
# 23        Clothing Store           Coffee Shop                    Yoga Studio
# 24        Sandwich Place                  Café                    Coffee Shop
# 25             Gift Shop        Breakfast Spot                      Bookstore
# 26           Pizza Place          Dessert Shop                 Sandwich Place
# 27                  Café                   Bar            Japanese Restaurant
# 28           Coffee Shop                  Café               Sushi Restaurant
# 30                  Café                   Bar  Vegetarian / Vegan Restaurant
# 31           Coffee Shop    Light Rail Station            American Restaurant
# 32        Airport Lounge         Boat or Ferry               Airport Terminal
# 34                  Café                   Pub                         Bakery
# 35           Pizza Place                  Park                    Coffee Shop
# 36                  Café           Coffee Shop                     Restaurant
# 37           Coffee Shop           Yoga Studio            Japanese Restaurant
# 38           Yoga Studio  Gym / Fitness Center                     Skate Park
#
#      4th Most Common Venue  5th Most Common Venue  \
# 0                     Park         Breakfast Spot
# 1                      Spa          Smoothie Shop
# 2           Clothing Store                Theater
# 3                     Park         Farmers Market
# 4                Wine Shop           Cupcake Shop
# 5                 Beer Bar         Farmers Market
# 6          Bubble Tea Shop     Italian Restaurant
# 7       Italian Restaurant             Baby Store
# 8               Steakhouse            Pizza Place
# 9              Supermarket          Grocery Store
# 10                    Park            Coffee Shop
# 11              Restaurant                   Café
# 12  Furniture / Home Store         Ice Cream Shop
# 13      Seafood Restaurant             Restaurant
# 14             Coffee Shop                Stadium
# 15    Fast Food Restaurant                    Gym
# 16             Coffee Shop                    Gym
# 17     American Restaurant                Brewery
# 20    Gym / Fitness Center         Sandwich Place
# 22         Thai Restaurant         Discount Store
# 23    Gym / Fitness Center     Salon / Barbershop
# 24             Flower Shop           Liquor Store
# 25           Movie Theater             Restaurant
# 26      Italian Restaurant                    Gym
# 27               Bookstore         Sandwich Place
# 28      Italian Restaurant                    Pub
# 30   Vietnamese Restaurant     Mexican Restaurant
# 31                    Bank  Vietnamese Restaurant
# 32                Boutique    Rental Car Location
# 34                Beer Bar         Farmers Market
# 35                  Bakery     Italian Restaurant
# 36     Japanese Restaurant     Seafood Restaurant
# 37              Restaurant                Gay Bar
# 38                 Brewery          Burrito Place
#
#           6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                    Restaurant                  Café               Theater
# 1                      Beer Bar        Sandwich Place         Burrito Place
# 2              Ramen Restaurant        Cosmetics Shop  Fast Food Restaurant
# 3                        Bakery              Creperie   Japanese Restaurant
# 4                    Donut Shop      Doner Restaurant               Dog Run
# 5                  Cocktail Bar           Cheese Shop            Restaurant
# 6                    Comic Shop           Salad Place          Burger Joint
# 7                    Restaurant           Candy Store    Athletics & Sports
# 8           American Restaurant       Thai Restaurant            Restaurant
# 9     Middle Eastern Restaurant           Music Venue                  Park
# 10                        Hotel        Scenic Lookout                 Plaza
# 11             Asian Restaurant           Men's Store      Cuban Restaurant
# 12                    Bookstore               Brewery       Bubble Tea Shop
# 13          Japanese Restaurant                Bakery             Gastropub
# 14                   Restaurant                   Bar          Intersection
# 15                   Steakhouse                   Pub      Sushi Restaurant
# 16           Seafood Restaurant   Japanese Restaurant   American Restaurant
# 17                       Bakery           Yoga Studio                   Bar
# 20             Department Store     Food & Drink Shop            Donut Shop
# 22         Fast Food Restaurant             Speakeasy                Bakery
# 23           Italian Restaurant                   Spa   Sporting Goods Shop
# 24                   Donut Shop          Burger Joint     Indian Restaurant
# 25  Eastern European Restaurant    Italian Restaurant      Cuban Restaurant
# 26             Sushi Restaurant                  Café           Coffee Shop
# 27                       Bakery          Dessert Shop              Beer Bar
# 28                  Pizza Place           Yoga Studio          Dessert Shop
# 30                  Coffee Shop  Caribbean Restaurant                Bakery
# 31                  Supermarket      Sushi Restaurant          Liquor Store
# 32                          Bar       Harbor / Marina           Coffee Shop
# 34                  Coffee Shop              Creperie          Cocktail Bar
# 35                         Café                   Pub            Restaurant
# 36             Asian Restaurant         Deli / Bodega                 Hotel
# 37             Sushi Restaurant           Men's Store             Bookstore
# 38                          Spa            Restaurant        Farmers Market
#
#     9th Most Common Venue     10th Most Common Venue 11th Most Common Venue  \
# 0          Cosmetics Shop                 Beer Store             Shoe Store
# 1                    Café                       Park     College Auditorium
# 2           Burrito Place                      Diner         Sandwich Place
# 3      Seafood Restaurant                  Gastropub            Fish Market
# 4     Distribution Center             Discount Store                  Diner
# 5                    Café                      Hotel                 Bistro
# 6   Portuguese Restaurant                 Poke Place                   Park
# 7             Coffee Shop                  Nightclub           Concert Hall
# 8      Seafood Restaurant           Department Store                  Hotel
# 9                    Café                    Brewery                    Bar
# 10                   Café             History Museum                    Bar
# 11                Brewery                Record Shop            Pizza Place
# 12             Restaurant                       Café                    Pub
# 13     Basketball Stadium        Sporting Goods Shop              Speakeasy
# 14     Italian Restaurant               Climbing Gym              Pet Store
# 15             Restaurant          Fish & Chips Shop     Italian Restaurant
# 16          Deli / Bodega                  Gastropub                 Bakery
# 17         Ice Cream Shop         Italian Restaurant              Bookstore
# 20       Doner Restaurant                    Dog Run    Distribution Center
# 22            Flea Market  Cajun / Creole Restaurant     Italian Restaurant
# 23             Restaurant        Rental Car Location         Ice Cream Shop
# 24              BBQ Joint             History Museum                    Pub
# 25                    Bar               Dessert Shop                Dog Run
# 26           Dance Studio                   Pharmacy                Brewery
# 27             Beer Store                 Restaurant            Yoga Studio
# 28                   Bank                        Spa                    Bar
# 30           Burger Joint         Belgian Restaurant    Dumpling Restaurant
# 31            Pizza Place        Fried Chicken Joint             Restaurant
# 32       Sculpture Garden         Airport Food Court        Airport Service
# 34            Cheese Shop         Seafood Restaurant    Japanese Restaurant
# 35   Caribbean Restaurant      Sri Lankan Restaurant                   Bank
# 36                    Gym        American Restaurant           Concert Hall
# 37      Indian Restaurant               Burger Joint         Breakfast Spot
# 38   Fast Food Restaurant           Recording Studio          Auto Workshop
#
#        12th Most Common Venue
# 0              Chocolate Shop
# 1           College Cafeteria
# 2                  Restaurant
# 3           Electronics Store
# 4          Dim Sum Restaurant
# 5              Breakfast Spot
# 6     New American Restaurant
# 7     Comfort Food Restaurant
# 8                   Bookstore
# 9                        Bank
# 10           Baseball Stadium
# 11               Cocktail Bar
# 12       Caribbean Restaurant
# 13                        Bar
# 14                        Gym
# 15              Burrito Place
# 16                       Park
# 17         Seafood Restaurant
# 20             Discount Store
# 22                      Diner
# 23                       Café
# 24  Middle Eastern Restaurant
# 25                Coffee Shop
# 26                      Diner
# 27                        Pub
# 28              Smoothie Shop
# 30                  Jazz Club
# 31                        Pub
# 32               Airport Gate
# 34                 Restaurant
# 35                 Playground
# 36                  Bookstore
# 37                   Sake Bar
# 38         Light Rail Station

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#      Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 18  Lawrence Park               1                  Park    Dim Sum Restaurant
# 33       Rosedale               1                  Park            Playground
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 18           Swim School              Bus Line             Wine Shop
# 33                 Trail             Wine Shop          Cupcake Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 18         Deli / Bodega   Dumpling Restaurant            Donut Shop
# 33            Donut Shop      Doner Restaurant               Dog Run
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 18      Doner Restaurant                Dog Run    Distribution Center
# 33   Distribution Center         Discount Store                  Diner
#
#    12th Most Common Venue
# 18         Discount Store
# 33     Dim Sum Restaurant

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                    Neighborhood  Cluster Labels 1st Most Common Venue  \
# 29  Moore Park, Summerhill East               2                Lawyer
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 29                  Park          Tennis Court          Dance Studio
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 29   Dumpling Restaurant            Donut Shop      Doner Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 29               Dog Run   Distribution Center         Discount Store
#
#    11th Most Common Venue 12th Most Common Venue
# 29                  Diner     Dim Sum Restaurant

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                        Neighborhood  Cluster Labels  \
# 21  Forest Hill North & West, Forest Hill Road Park               3
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 21              Bus Line         Jewelry Store                 Trail
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 21      Sushi Restaurant             Wine Shop   Dumpling Restaurant
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 21            Donut Shop      Doner Restaurant               Dog Run
#
#    10th Most Common Venue 11th Most Common Venue 12th Most Common Venue
# 21    Distribution Center         Discount Store                  Diner

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 19     Roselawn               4                Garden          Home Service
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 19             Wine Shop          Dance Studio   Dumpling Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 19            Donut Shop      Doner Restaurant               Dog Run
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 19   Distribution Center         Discount Store                  Diner
#
#    12th Most Common Venue
# 19     Dim Sum Restaurant
