# %% [markdown]
# ## Agrupacion y Segmentacion de Vecindarios de Toronto

# %% [markdown]
# #### Parte 1

# %%
 # !jupyter nbconvert --to html TorontoFinal3.ipynb
# Importacion de Librerias necesarias
# Out:
# [NbConvertApp] Converting notebook TorontoFinal3.ipynb to html
# [NbConvertApp] Writing 892800 bytes to TorontoFinal3.html

# %%
pip install BeautifulSoup4
# Out:
# Collecting BeautifulSoup4
#   Downloading https://files.pythonhosted.org/packages/d1/41/e6495bd7d3781cee623ce23ea6ac73282a373088fcd0ddc809a047b18eae/beautifulsoup4-4.9.3-py3-none-any.whl (115kB)
#      |████████████████████████████████| 122kB 25.9MB/s eta 0:00:01
# Collecting soupsieve>1.2; python_version >= "3.0" (from BeautifulSoup4)
#   Downloading https://files.pythonhosted.org/packages/36/69/d82d04022f02733bf9a72bc3b96332d360c0c5307096d76f6bb7489f7e57/soupsieve-2.2.1-py3-none-any.whl
# Installing collected packages: soupsieve, BeautifulSoup4
# Successfully installed BeautifulSoup4-4.9.3 soupsieve-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (4.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup  
import requests 
import pandas as pd
import lxml

# %%
#Importacion , Scraping y Creacion de Dataframe

# %%
url =requests.get ("https://en.wikipedia.org/w/index.php?title=List_of_postal_codes_of_Canada:_M&oldid=958430791").text

# %%
soup = BeautifulSoup(url,'lxml')

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
df = pd.read_html(str(My_table))[0]
df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned                        NaN
# 1         M2A      Not assigned                        NaN
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %%
# Eliminamos Municipios 'Not assigned'

# %%
drop_Not=df[df['Borough']=='Not assigned'].index
df.drop (drop_Not, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Asignamos Vecindarios 'Not assigned' a Municipio

# %%
df[df['Neighborhood']=='Not assigned']=df['Borough'].reset_index()
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
# Requerimiento filas-columnas

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# #### Parte 2

# %%
# Importacion de archivo csv con coordenadas

# %%
from io import StringIO

url = requests.get(' http://cocl.us/Geospatial_data')
csv_raw = StringIO(url.text)
datos_geo = pd.read_csv(csv_raw)

# %%
datos_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
# Relacionamos Dataframes

# %%
df=pd.merge(df,datos_geo,how='left')

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# #### Parte 3

# %%
# Importacion Librerias Necesarias

# %%
import numpy as np
import json
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize 
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
print('Librerias importadas')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.52         |     pyhd8ed1ab_0          35 KB  conda-forge
#     geopy-2.2.0                |     pyhd8ed1ab_0          67 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         102 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.52-pyhd8ed1ab_0
#   geopy              conda-forge/noarch::geopy-2.2.0-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# geographiclib-1.52   | 35 KB     | ##################################### | 100%
# geopy-2.2.0          | 67 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Librerias importadas

# %%
# Filtramos a Municipios que sean ' Toronto '


Tor_d = df[df['Borough'].str.contains('Toronto')].reset_index(drop=True)
Tor_d.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %%
# Obtenemos nro filas 

Tor_d.shape
# Out:
# (39, 5)

# %%
# Obtenemos coordenadas para Toronto

address = 'Toronto, ON'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Coordenadas Toronto {}, {}.'.format(latitude, longitude))
# Out:
# Coordenadas Toronto 43.6534817, -79.3839347.

# %%
# Creamos mapa de Toronto y añadimos los marcadores

map_Toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

for lat, lng, borough, neighborhood in zip(Tor_d['Latitude'], Tor_d['Longitude'], Tor_d['Borough'], Tor_d['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=2,
        parse_html=False).add_to(map_Toronto)  
    
map_Toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_37b7bb595aca40d49a347fdb10c1ffc0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_37b7bb595aca40d49a347fdb10c1ffc0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_37b7bb595aca40d49a347fdb10c1ffc0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_37b7bb595aca40d49a347fdb10c1ffc0%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Definimos version y credenciales para la API de Foursquare con un limite de 50 devoluciones

CLIENT_ID = 'DBBPKNBZNEC2JFO4JL13AJOJLMHLHOCOYWGTY5ZXJFXRJXYD' 
CLIENT_SECRET = 'YA51Q1Y4XHBRUZE1025SHVN3AKMX20MJHBBELS0BANSJWKMA' 
VERSION = '20180605' 
LIMIT = 50

# %%
# Definimos funcion para obtener los 100 sitios en un radio de 500 mts para cada barrio

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # crear la URL de solicitud de API
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
                # solicitud GET
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # regresa solo información relevante de cada sitio cercano
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# Corremos la funcion getNearbyVenues para cada barrio creando un Dataframe 'Toronto_venues'

Toronto_venues = getNearbyVenues(names=Tor_d['Neighborhood'],
                                   latitudes=Tor_d['Latitude'],
                                   longitudes=Tor_d['Longitude'])
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West, Forest Hill Road Park
# High Park, The Junction South
# North Toronto West, Lawrence Park
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Rosedale
# Stn A PO Boxes
# St. James Town, Cabbagetown
# First Canadian Place, Underground city
# Church and Wellesley
# Business reply mail Processing Centre, South Central Letter Processing Plant Toronto

# %%
# mostramos Dataframe y revisamos tamaño

print(Toronto_venues.shape)
Toronto_venues.head()
# Out:
# (1170, 7)
#                 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Regent Park, Harbourfront               43.65426              -79.360636
# 1  Regent Park, Harbourfront               43.65426              -79.360636
# 2  Regent Park, Harbourfront               43.65426              -79.360636
# 3  Regent Park, Harbourfront               43.65426              -79.360636
# 4  Regent Park, Harbourfront               43.65426              -79.360636
#
#                     Venue  Venue Latitude  Venue Longitude  \
# 0        Roselle Desserts       43.653447       -79.362017
# 1           Tandem Coffee       43.653559       -79.361809
# 2  Cooper Koo Family YMCA       43.653249       -79.358008
# 3     Body Blitz Spa East       43.654735       -79.359874
# 4          Impact Kitchen       43.656369       -79.356980
#
#         Venue Category
# 0               Bakery
# 1          Coffee Shop
# 2  Distribution Center
# 3                  Spa
# 4           Restaurant

# %%
# Observemos cuantos sitios se devolvieron por barrio

Toronto_venues.groupby('Neighborhood').count()
# Out:
#                                                     Neighborhood Latitude  \
# Neighborhood
# Berczy Park                                                            50
# Brockton, Parkdale Village, Exhibition Place                           24
# Business reply mail Processing Centre, South Ce...                     17
# CN Tower, King and Spadina, Railway Lands, Harb...                     15
# Central Bay Street                                                     50
# Christie                                                               16
# Church and Wellesley                                                   50
# Commerce Court, Victoria Hotel                                         50
# Davisville                                                             36
# Davisville North                                                        9
# Dufferin, Dovercourt Village                                           14
# First Canadian Place, Underground city                                 50
# Forest Hill North & West, Forest Hill Road Park                         4
# Garden District, Ryerson                                               50
# Harbourfront East, Union Station, Toronto Islands                      50
# High Park, The Junction South                                          26
# India Bazaar, The Beaches West                                         20
# Kensington Market, Chinatown, Grange Park                              50
# Lawrence Park                                                           4
# Little Portugal, Trinity                                               41
# Moore Park, Summerhill East                                             1
# North Toronto West, Lawrence Park                                      18
# Parkdale, Roncesvalles                                                 14
# Queen's Park, Ontario Provincial Government                            33
# Regent Park, Harbourfront                                              43
# Richmond, Adelaide, King                                               50
# Rosedale                                                                4
# Roselawn                                                                3
# Runnymede, Swansea                                                     35
# St. James Town                                                         50
# St. James Town, Cabbagetown                                            43
# Stn A PO Boxes                                                         50
# Studio District                                                        37
# Summerhill West, Rathnelly, South Hill, Forest ...                     14
# The Annex, North Midtown, Yorkville                                    19
# The Beaches                                                             4
# The Danforth West, Riverdale                                           42
# Toronto Dominion Centre, Design Exchange                               50
# University of Toronto, Harbord                                         34
#
#                                                     Neighborhood Longitude  \
# Neighborhood
# Berczy Park                                                             50
# Brockton, Parkdale Village, Exhibition Place                            24
# Business reply mail Processing Centre, South Ce...                      17
# CN Tower, King and Spadina, Railway Lands, Harb...                      15
# Central Bay Street                                                      50
# Christie                                                                16
# Church and Wellesley                                                    50
# Commerce Court, Victoria Hotel                                          50
# Davisville                                                              36
# Davisville North                                                         9
# Dufferin, Dovercourt Village                                            14
# First Canadian Place, Underground city                                  50
# Forest Hill North & West, Forest Hill Road Park                          4
# Garden District, Ryerson                                                50
# Harbourfront East, Union Station, Toronto Islands                       50
# High Park, The Junction South                                           26
# India Bazaar, The Beaches West                                          20
# Kensington Market, Chinatown, Grange Park                               50
# Lawrence Park                                                            4
# Little Portugal, Trinity                                                41
# Moore Park, Summerhill East                                              1
# North Toronto West, Lawrence Park                                       18
# Parkdale, Roncesvalles                                                  14
# Queen's Park, Ontario Provincial Government                             33
# Regent Park, Harbourfront                                               43
# Richmond, Adelaide, King                                                50
# Rosedale                                                                 4
# Roselawn                                                                 3
# Runnymede, Swansea                                                      35
# St. James Town                                                          50
# St. James Town, Cabbagetown                                             43
# Stn A PO Boxes                                                          50
# Studio District                                                         37
# Summerhill West, Rathnelly, South Hill, Forest ...                      14
# The Annex, North Midtown, Yorkville                                     19
# The Beaches                                                              4
# The Danforth West, Riverdale                                            42
# Toronto Dominion Centre, Design Exchange                                50
# University of Toronto, Harbord                                          34
#
#                                                     Venue  Venue Latitude  \
# Neighborhood
# Berczy Park                                            50              50
# Brockton, Parkdale Village, Exhibition Place           24              24
# Business reply mail Processing Centre, South Ce...     17              17
# CN Tower, King and Spadina, Railway Lands, Harb...     15              15
# Central Bay Street                                     50              50
# Christie                                               16              16
# Church and Wellesley                                   50              50
# Commerce Court, Victoria Hotel                         50              50
# Davisville                                             36              36
# Davisville North                                        9               9
# Dufferin, Dovercourt Village                           14              14
# First Canadian Place, Underground city                 50              50
# Forest Hill North & West, Forest Hill Road Park         4               4
# Garden District, Ryerson                               50              50
# Harbourfront East, Union Station, Toronto Islands      50              50
# High Park, The Junction South                          26              26
# India Bazaar, The Beaches West                         20              20
# Kensington Market, Chinatown, Grange Park              50              50
# Lawrence Park                                           4               4
# Little Portugal, Trinity                               41              41
# Moore Park, Summerhill East                             1               1
# North Toronto West, Lawrence Park                      18              18
# Parkdale, Roncesvalles                                 14              14
# Queen's Park, Ontario Provincial Government            33              33
# Regent Park, Harbourfront                              43              43
# Richmond, Adelaide, King                               50              50
# Rosedale                                                4               4
# Roselawn                                                3               3
# Runnymede, Swansea                                     35              35
# St. James Town                                         50              50
# St. James Town, Cabbagetown                            43              43
# Stn A PO Boxes                                         50              50
# Studio District                                        37              37
# Summerhill West, Rathnelly, South Hill, Forest ...     14              14
# The Annex, North Midtown, Yorkville                    19              19
# The Beaches                                             4               4
# The Danforth West, Riverdale                           42              42
# Toronto Dominion Centre, Design Exchange               50              50
# University of Toronto, Harbord                         34              34
#
#                                                     Venue Longitude  \
# Neighborhood
# Berczy Park                                                      50
# Brockton, Parkdale Village, Exhibition Place                     24
# Business reply mail Processing Centre, South Ce...               17
# CN Tower, King and Spadina, Railway Lands, Harb...               15
# Central Bay Street                                               50
# Christie                                                         16
# Church and Wellesley                                             50
# Commerce Court, Victoria Hotel                                   50
# Davisville                                                       36
# Davisville North                                                  9
# Dufferin, Dovercourt Village                                     14
# First Canadian Place, Underground city                           50
# Forest Hill North & West, Forest Hill Road Park                   4
# Garden District, Ryerson                                         50
# Harbourfront East, Union Station, Toronto Islands                50
# High Park, The Junction South                                    26
# India Bazaar, The Beaches West                                   20
# Kensington Market, Chinatown, Grange Park                        50
# Lawrence Park                                                     4
# Little Portugal, Trinity                                         41
# Moore Park, Summerhill East                                       1
# North Toronto West, Lawrence Park                                18
# Parkdale, Roncesvalles                                           14
# Queen's Park, Ontario Provincial Government                      33
# Regent Park, Harbourfront                                        43
# Richmond, Adelaide, King                                         50
# Rosedale                                                          4
# Roselawn                                                          3
# Runnymede, Swansea                                               35
# St. James Town                                                   50
# St. James Town, Cabbagetown                                      43
# Stn A PO Boxes                                                   50
# Studio District                                                  37
# Summerhill West, Rathnelly, South Hill, Forest ...               14
# The Annex, North Midtown, Yorkville                              19
# The Beaches                                                       4
# The Danforth West, Riverdale                                     42
# Toronto Dominion Centre, Design Exchange                         50
# University of Toronto, Harbord                                   34
#
#                                                     Venue Category
# Neighborhood
# Berczy Park                                                     50
# Brockton, Parkdale Village, Exhibition Place                    24
# Business reply mail Processing Centre, South Ce...              17
# CN Tower, King and Spadina, Railway Lands, Harb...              15
# Central Bay Street                                              50
# Christie                                                        16
# Church and Wellesley                                            50
# Commerce Court, Victoria Hotel                                  50
# Davisville                                                      36
# Davisville North                                                 9
# Dufferin, Dovercourt Village                                    14
# First Canadian Place, Underground city                          50
# Forest Hill North & West, Forest Hill Road Park                  4
# Garden District, Ryerson                                        50
# Harbourfront East, Union Station, Toronto Islands               50
# High Park, The Junction South                                   26
# India Bazaar, The Beaches West                                  20
# Kensington Market, Chinatown, Grange Park                       50
# Lawrence Park                                                    4
# Little Portugal, Trinity                                        41
# Moore Park, Summerhill East                                      1
# North Toronto West, Lawrence Park                               18
# Parkdale, Roncesvalles                                          14
# Queen's Park, Ontario Provincial Government                     33
# Regent Park, Harbourfront                                       43
# Richmond, Adelaide, King                                        50
# Rosedale                                                         4
# Roselawn                                                         3
# Runnymede, Swansea                                              35
# St. James Town                                                  50
# St. James Town, Cabbagetown                                     43
# Stn A PO Boxes                                                  50
# Studio District                                                 37
# Summerhill West, Rathnelly, South Hill, Forest ...              14
# The Annex, North Midtown, Yorkville                             19
# The Beaches                                                      4
# The Danforth West, Riverdale                                    42
# Toronto Dominion Centre, Design Exchange                        50
# University of Toronto, Harbord                                  34

# %%
# Vemos cuantas categorias unicas hay por barrio

print('There are {} uniques categories.'.format(len(Toronto_venues['Venue Category'].unique())))
# Out:
# There are 222 uniques categories.

# %%
#Analizamos cada barrio



# codificación
Toronto_onehot = pd.get_dummies(Toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# añadir la columna de barrio de regreso al dataframe
Toronto_onehot['Neighborhood'] = Toronto_venues['Neighborhood'] 

# mover la columna de barrio a la primer columna
fixed_columns = [Toronto_onehot.columns[-1]] + list(Toronto_onehot.columns[:-1])
Toronto_onehot = Toronto_onehot[fixed_columns]

Toronto_onehot.shape
# Out:
# (1170, 222)

# %%
# Agrupamos las filas por barrios tomando el parametro de promedio de ocurrencia de cada categoria


Toronto_grouped = Toronto_onehot.groupby('Neighborhood').mean().reset_index()
Toronto_grouped
# Out:
#                                          Neighborhood  Yoga Studio  \
# 0                                         Berczy Park     0.000000
# 1        Brockton, Parkdale Village, Exhibition Place     0.000000
# 2   Business reply mail Processing Centre, South C...     0.000000
# 3   CN Tower, King and Spadina, Railway Lands, Har...     0.000000
# 4                                  Central Bay Street     0.020000
# 5                                            Christie     0.000000
# 6                                Church and Wellesley     0.040000
# 7                      Commerce Court, Victoria Hotel     0.000000
# 8                                          Davisville     0.000000
# 9                                    Davisville North     0.000000
# 10                       Dufferin, Dovercourt Village     0.000000
# 11             First Canadian Place, Underground city     0.000000
# 12    Forest Hill North & West, Forest Hill Road Park     0.000000
# 13                           Garden District, Ryerson     0.000000
# 14  Harbourfront East, Union Station, Toronto Islands     0.000000
# 15                      High Park, The Junction South     0.000000
# 16                     India Bazaar, The Beaches West     0.000000
# 17          Kensington Market, Chinatown, Grange Park     0.000000
# 18                                      Lawrence Park     0.000000
# 19                           Little Portugal, Trinity     0.024390
# 20                        Moore Park, Summerhill East     0.000000
# 21                  North Toronto West, Lawrence Park     0.055556
# 22                             Parkdale, Roncesvalles     0.000000
# 23        Queen's Park, Ontario Provincial Government     0.030303
# 24                          Regent Park, Harbourfront     0.023256
# 25                           Richmond, Adelaide, King     0.000000
# 26                                           Rosedale     0.000000
# 27                                           Roselawn     0.000000
# 28                                 Runnymede, Swansea     0.028571
# 29                                     St. James Town     0.000000
# 30                        St. James Town, Cabbagetown     0.000000
# 31                                     Stn A PO Boxes     0.000000
# 32                                    Studio District     0.027027
# 33  Summerhill West, Rathnelly, South Hill, Forest...     0.000000
# 34                The Annex, North Midtown, Yorkville     0.000000
# 35                                        The Beaches     0.000000
# 36                       The Danforth West, Riverdale     0.023810
# 37           Toronto Dominion Centre, Design Exchange     0.000000
# 38                     University of Toronto, Harbord     0.029412
#
#     Adult Boutique   Airport  Airport Food Court  Airport Lounge  \
# 0             0.00  0.000000            0.000000        0.000000
# 1             0.00  0.000000            0.000000        0.000000
# 2             0.00  0.000000            0.000000        0.000000
# 3             0.00  0.066667            0.066667        0.066667
# 4             0.00  0.000000            0.000000        0.000000
# 5             0.00  0.000000            0.000000        0.000000
# 6             0.02  0.000000            0.000000        0.000000
# 7             0.00  0.000000            0.000000        0.000000
# 8             0.00  0.000000            0.000000        0.000000
# 9             0.00  0.000000            0.000000        0.000000
# 10            0.00  0.000000            0.000000        0.000000
# 11            0.00  0.000000            0.000000        0.000000
# 12            0.00  0.000000            0.000000        0.000000
# 13            0.00  0.000000            0.000000        0.000000
# 14            0.00  0.000000            0.000000        0.000000
# 15            0.00  0.000000            0.000000        0.000000
# 16            0.00  0.000000            0.000000        0.000000
# 17            0.00  0.000000            0.000000        0.000000
# 18            0.00  0.000000            0.000000        0.000000
# 19            0.00  0.000000            0.000000        0.000000
# 20            0.00  0.000000            0.000000        0.000000
# 21            0.00  0.000000            0.000000        0.000000
# 22            0.00  0.000000            0.000000        0.000000
# 23            0.00  0.000000            0.000000        0.000000
# 24            0.00  0.000000            0.000000        0.000000
# 25            0.00  0.000000            0.000000        0.000000
# 26            0.00  0.000000            0.000000        0.000000
# 27            0.00  0.000000            0.000000        0.000000
# 28            0.00  0.000000            0.000000        0.000000
# 29            0.00  0.000000            0.000000        0.000000
# 30            0.00  0.000000            0.000000        0.000000
# 31            0.00  0.000000            0.000000        0.000000
# 32            0.00  0.000000            0.000000        0.000000
# 33            0.00  0.000000            0.000000        0.000000
# 34            0.00  0.000000            0.000000        0.000000
# 35            0.00  0.000000            0.000000        0.000000
# 36            0.00  0.000000            0.000000        0.000000
# 37            0.00  0.000000            0.000000        0.000000
# 38            0.00  0.000000            0.000000        0.000000
#
#     Airport Service  Airport Terminal  American Restaurant  Antique Shop  ...  \
# 0          0.000000          0.000000             0.000000      0.000000  ...
# 1          0.000000          0.000000             0.000000      0.000000  ...
# 2          0.000000          0.000000             0.000000      0.000000  ...
# 3          0.133333          0.133333             0.000000      0.000000  ...
# 4          0.000000          0.000000             0.000000      0.000000  ...
# 5          0.000000          0.000000             0.000000      0.000000  ...
# 6          0.000000          0.000000             0.000000      0.000000  ...
# 7          0.000000          0.000000             0.040000      0.000000  ...
# 8          0.000000          0.000000             0.000000      0.000000  ...
# 9          0.000000          0.000000             0.000000      0.000000  ...
# 10         0.000000          0.000000             0.000000      0.000000  ...
# 11         0.000000          0.000000             0.040000      0.000000  ...
# 12         0.000000          0.000000             0.000000      0.000000  ...
# 13         0.000000          0.000000             0.000000      0.000000  ...
# 14         0.000000          0.000000             0.000000      0.000000  ...
# 15         0.000000          0.000000             0.000000      0.038462  ...
# 16         0.000000          0.000000             0.000000      0.000000  ...
# 17         0.000000          0.000000             0.000000      0.000000  ...
# 18         0.000000          0.000000             0.000000      0.000000  ...
# 19         0.000000          0.000000             0.000000      0.000000  ...
# 20         0.000000          0.000000             0.000000      0.000000  ...
# 21         0.000000          0.000000             0.000000      0.000000  ...
# 22         0.000000          0.000000             0.000000      0.000000  ...
# 23         0.000000          0.000000             0.000000      0.000000  ...
# 24         0.000000          0.000000             0.000000      0.023256  ...
# 25         0.000000          0.000000             0.040000      0.000000  ...
# 26         0.000000          0.000000             0.000000      0.000000  ...
# 27         0.000000          0.000000             0.000000      0.000000  ...
# 28         0.000000          0.000000             0.000000      0.000000  ...
# 29         0.000000          0.000000             0.020000      0.000000  ...
# 30         0.000000          0.000000             0.000000      0.000000  ...
# 31         0.000000          0.000000             0.000000      0.000000  ...
# 32         0.000000          0.000000             0.054054      0.000000  ...
# 33         0.000000          0.000000             0.071429      0.000000  ...
# 34         0.000000          0.000000             0.000000      0.000000  ...
# 35         0.000000          0.000000             0.000000      0.000000  ...
# 36         0.000000          0.000000             0.023810      0.000000  ...
# 37         0.000000          0.000000             0.020000      0.000000  ...
# 38         0.000000          0.000000             0.000000      0.000000  ...
#
#     Theme Restaurant  Tibetan Restaurant  Toy / Game Store    Trail  \
# 0               0.00             0.00000          0.000000  0.00000
# 1               0.00             0.00000          0.000000  0.00000
# 2               0.00             0.00000          0.000000  0.00000
# 3               0.00             0.00000          0.000000  0.00000
# 4               0.00             0.00000          0.000000  0.00000
# 5               0.00             0.00000          0.000000  0.00000
# 6               0.02             0.00000          0.000000  0.00000
# 7               0.00             0.00000          0.000000  0.00000
# 8               0.00             0.00000          0.027778  0.00000
# 9               0.00             0.00000          0.000000  0.00000
# 10              0.00             0.00000          0.000000  0.00000
# 11              0.00             0.00000          0.000000  0.00000
# 12              0.00             0.00000          0.000000  0.25000
# 13              0.00             0.00000          0.000000  0.00000
# 14              0.00             0.00000          0.000000  0.00000
# 15              0.00             0.00000          0.000000  0.00000
# 16              0.00             0.00000          0.000000  0.00000
# 17              0.00             0.00000          0.000000  0.00000
# 18              0.00             0.00000          0.000000  0.00000
# 19              0.00             0.00000          0.000000  0.00000
# 20              0.00             0.00000          0.000000  0.00000
# 21              0.00             0.00000          0.000000  0.00000
# 22              0.00             0.00000          0.000000  0.00000
# 23              0.00             0.00000          0.000000  0.00000
# 24              0.00             0.00000          0.000000  0.00000
# 25              0.00             0.00000          0.000000  0.00000
# 26              0.00             0.00000          0.000000  0.25000
# 27              0.00             0.00000          0.000000  0.00000
# 28              0.00             0.00000          0.000000  0.00000
# 29              0.00             0.00000          0.000000  0.00000
# 30              0.00             0.00000          0.000000  0.00000
# 31              0.00             0.00000          0.000000  0.00000
# 32              0.00             0.00000          0.000000  0.00000
# 33              0.00             0.00000          0.000000  0.00000
# 34              0.00             0.00000          0.000000  0.00000
# 35              0.00             0.00000          0.000000  0.25000
# 36              0.00             0.02381          0.000000  0.02381
# 37              0.00             0.00000          0.000000  0.00000
# 38              0.00             0.00000          0.000000  0.00000
#
#     Train Station  Vegetarian / Vegan Restaurant  Video Game Store  \
# 0            0.00                       0.020000          0.000000
# 1            0.00                       0.000000          0.000000
# 2            0.00                       0.000000          0.000000
# 3            0.00                       0.000000          0.000000
# 4            0.00                       0.020000          0.000000
# 5            0.00                       0.000000          0.000000
# 6            0.00                       0.000000          0.000000
# 7            0.00                       0.020000          0.000000
# 8            0.00                       0.000000          0.000000
# 9            0.00                       0.000000          0.000000
# 10           0.00                       0.000000          0.000000
# 11           0.00                       0.020000          0.000000
# 12           0.00                       0.000000          0.000000
# 13           0.00                       0.000000          0.000000
# 14           0.02                       0.000000          0.000000
# 15           0.00                       0.000000          0.000000
# 16           0.00                       0.000000          0.000000
# 17           0.00                       0.060000          0.000000
# 18           0.00                       0.000000          0.000000
# 19           0.00                       0.048780          0.000000
# 20           0.00                       0.000000          0.000000
# 21           0.00                       0.000000          0.000000
# 22           0.00                       0.000000          0.000000
# 23           0.00                       0.030303          0.000000
# 24           0.00                       0.000000          0.000000
# 25           0.00                       0.020000          0.000000
# 26           0.00                       0.000000          0.000000
# 27           0.00                       0.000000          0.000000
# 28           0.00                       0.028571          0.000000
# 29           0.00                       0.020000          0.000000
# 30           0.00                       0.000000          0.000000
# 31           0.00                       0.020000          0.000000
# 32           0.00                       0.000000          0.000000
# 33           0.00                       0.000000          0.000000
# 34           0.00                       0.000000          0.000000
# 35           0.00                       0.000000          0.000000
# 36           0.00                       0.000000          0.000000
# 37           0.02                       0.020000          0.000000
# 38           0.00                       0.000000          0.029412
#
#     Vietnamese Restaurant  Wine Bar  Wine Shop
# 0                0.000000   0.00000   0.000000
# 1                0.000000   0.00000   0.000000
# 2                0.000000   0.00000   0.000000
# 3                0.000000   0.00000   0.000000
# 4                0.000000   0.00000   0.000000
# 5                0.000000   0.00000   0.000000
# 6                0.000000   0.00000   0.000000
# 7                0.000000   0.00000   0.000000
# 8                0.000000   0.00000   0.000000
# 9                0.000000   0.00000   0.000000
# 10               0.000000   0.00000   0.000000
# 11               0.000000   0.00000   0.000000
# 12               0.000000   0.00000   0.000000
# 13               0.000000   0.00000   0.000000
# 14               0.000000   0.00000   0.000000
# 15               0.000000   0.00000   0.000000
# 16               0.000000   0.00000   0.000000
# 17               0.040000   0.02000   0.000000
# 18               0.000000   0.00000   0.000000
# 19               0.048780   0.02439   0.000000
# 20               0.000000   0.00000   0.000000
# 21               0.000000   0.00000   0.000000
# 22               0.000000   0.00000   0.000000
# 23               0.000000   0.00000   0.000000
# 24               0.000000   0.00000   0.023256
# 25               0.000000   0.00000   0.000000
# 26               0.000000   0.00000   0.000000
# 27               0.000000   0.00000   0.000000
# 28               0.000000   0.00000   0.000000
# 29               0.000000   0.00000   0.000000
# 30               0.000000   0.00000   0.000000
# 31               0.000000   0.00000   0.000000
# 32               0.000000   0.00000   0.000000
# 33               0.071429   0.00000   0.000000
# 34               0.000000   0.00000   0.000000
# 35               0.000000   0.00000   0.000000
# 36               0.000000   0.00000   0.000000
# 37               0.000000   0.00000   0.000000
# 38               0.000000   0.00000   0.000000
#
# [39 rows x 222 columns]

# %%
#Observamos tamaño Dataframe

Toronto_grouped.shape
# Out:
# (39, 222)

# %%
# Visualizamos cada barrio con los 12 lugares mas comunes

num_top_venues = 12

for hood in Toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = Toronto_grouped[Toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                       venue  freq
# 0               Coffee Shop  0.06
# 1        Seafood Restaurant  0.04
# 2               Cheese Shop  0.04
# 3              Cocktail Bar  0.04
# 4                  Beer Bar  0.04
# 5                Restaurant  0.04
# 6                    Bakery  0.04
# 7            Farmers Market  0.04
# 8              Concert Hall  0.02
# 9                  Pharmacy  0.02
# 10           Clothing Store  0.02
# 11  Comfort Food Restaurant  0.02
#
#
# ----Brockton, Parkdale Village, Exhibition Place----
#                      venue  freq
# 0                     Café  0.12
# 1              Coffee Shop  0.08
# 2           Breakfast Spot  0.08
# 3                   Bakery  0.08
# 4        Convenience Store  0.04
# 5                  Stadium  0.04
# 6               Restaurant  0.04
# 7                      Bar  0.04
# 8             Climbing Gym  0.04
# 9       Italian Restaurant  0.04
# 10  Furniture / Home Store  0.04
# 11            Intersection  0.04
#
#
# ----Business reply mail Processing Centre, South Central Letter Processing Plant Toronto----
#                    venue  freq
# 0     Light Rail Station  0.12
# 1   Fast Food Restaurant  0.06
# 2          Auto Workshop  0.06
# 3             Comic Shop  0.06
# 4            Pizza Place  0.06
# 5   Gym / Fitness Center  0.06
# 6             Restaurant  0.06
# 7                Butcher  0.06
# 8          Burrito Place  0.06
# 9                Brewery  0.06
# 10            Skate Park  0.06
# 11        Farmers Market  0.06
#
#
# ----CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport----
#                   venue  freq
# 0       Airport Service  0.13
# 1      Airport Terminal  0.13
# 2       Harbor / Marina  0.07
# 3                   Bar  0.07
# 4   Rental Car Location  0.07
# 5           Coffee Shop  0.07
# 6      Sculpture Garden  0.07
# 7                 Plane  0.07
# 8         Boat or Ferry  0.07
# 9              Boutique  0.07
# 10       Airport Lounge  0.07
# 11              Airport  0.07
#
#
# ----Central Bay Street----
#                          venue  freq
# 0                  Coffee Shop  0.16
# 1                         Café  0.06
# 2               Sandwich Place  0.06
# 3              Bubble Tea Shop  0.04
# 4           Italian Restaurant  0.04
# 5           Falafel Restaurant  0.02
# 6                    Bookstore  0.02
# 7                 Burger Joint  0.02
# 8    Middle Eastern Restaurant  0.02
# 9           Miscellaneous Shop  0.02
# 10  Modern European Restaurant  0.02
# 11                 Salad Place  0.02
#
#
# ----Christie----
#                   venue  freq
# 0         Grocery Store  0.25
# 1                  Café  0.19
# 2                  Park  0.12
# 3    Italian Restaurant  0.06
# 4           Candy Store  0.06
# 5            Baby Store  0.06
# 6           Coffee Shop  0.06
# 7    Athletics & Sports  0.06
# 8            Restaurant  0.06
# 9             Nightclub  0.06
# 10  Monument / Landmark  0.00
# 11  Moroccan Restaurant  0.00
#
#
# ----Church and Wellesley----
#                   venue  freq
# 0           Coffee Shop  0.06
# 1           Yoga Studio  0.04
# 2   Japanese Restaurant  0.04
# 3           Men's Store  0.04
# 4      Sushi Restaurant  0.04
# 5               Gay Bar  0.04
# 6            Restaurant  0.04
# 7              Sake Bar  0.02
# 8    Salon / Barbershop  0.02
# 9                  Café  0.02
# 10        Burrito Place  0.02
# 11     Ramen Restaurant  0.02
#
#
# ----Commerce Court, Victoria Hotel----
#                   venue  freq
# 0                  Café  0.10
# 1                 Hotel  0.08
# 2           Coffee Shop  0.08
# 3            Restaurant  0.06
# 4    Seafood Restaurant  0.06
# 5                   Gym  0.06
# 6         Deli / Bodega  0.04
# 7                Bakery  0.04
# 8   American Restaurant  0.04
# 9   Japanese Restaurant  0.04
# 10            Gastropub  0.04
# 11             Beer Bar  0.02
#
#
# ----Davisville----
#                  venue  freq
# 0          Pizza Place  0.11
# 1         Dessert Shop  0.08
# 2       Sandwich Place  0.08
# 3                  Gym  0.06
# 4                 Café  0.06
# 5          Coffee Shop  0.06
# 6   Italian Restaurant  0.06
# 7     Sushi Restaurant  0.06
# 8                 Park  0.03
# 9       Farmers Market  0.03
# 10  Seafood Restaurant  0.03
# 11             Brewery  0.03
#
#
# ----Davisville North----
#                        venue  freq
# 0                Pizza Place  0.11
# 1                       Park  0.11
# 2          Food & Drink Shop  0.11
# 3             Sandwich Place  0.11
# 4                      Hotel  0.11
# 5           Department Store  0.11
# 6             Breakfast Spot  0.11
# 7       Gym / Fitness Center  0.11
# 8                        Gym  0.11
# 9   Mediterranean Restaurant  0.00
# 10               Men's Store  0.00
# 11       Monument / Landmark  0.00
#
#
# ----Dufferin, Dovercourt Village----
#                         venue  freq
# 0                    Pharmacy  0.14
# 1                      Bakery  0.14
# 2                 Music Venue  0.07
# 3   Middle Eastern Restaurant  0.07
# 4                        Café  0.07
# 5                 Supermarket  0.07
# 6                         Bar  0.07
# 7                        Bank  0.07
# 8                     Brewery  0.07
# 9                        Park  0.07
# 10              Grocery Store  0.07
# 11       Gym / Fitness Center  0.07
#
#
# ----First Canadian Place, Underground city----
#                   venue  freq
# 0                  Café  0.12
# 1           Coffee Shop  0.10
# 2            Restaurant  0.06
# 3         Deli / Bodega  0.04
# 4                   Gym  0.04
# 5          Concert Hall  0.04
# 6                 Hotel  0.04
# 7   American Restaurant  0.04
# 8   Japanese Restaurant  0.04
# 9    Seafood Restaurant  0.04
# 10     Asian Restaurant  0.04
# 11       Sandwich Place  0.02
#
#
# ----Forest Hill North & West, Forest Hill Road Park----
#                               venue  freq
# 0                              Park  0.25
# 1                     Jewelry Store  0.25
# 2                             Trail  0.25
# 3                  Sushi Restaurant  0.25
# 4                       Yoga Studio  0.00
# 5   Molecular Gastronomy Restaurant  0.00
# 6                  Malay Restaurant  0.00
# 7                            Market  0.00
# 8               Martial Arts School  0.00
# 9          Mediterranean Restaurant  0.00
# 10                      Men's Store  0.00
# 11               Mexican Restaurant  0.00
#
#
# ----Garden District, Ryerson----
#                      venue  freq
# 0              Coffee Shop  0.08
# 1                     Café  0.06
# 2     Fast Food Restaurant  0.04
# 3           Clothing Store  0.04
# 4           Cosmetics Shop  0.04
# 5                Bookstore  0.04
# 6                  Theater  0.04
# 7         Ramen Restaurant  0.04
# 8                    Diner  0.02
# 9            Movie Theater  0.02
# 10  Furniture / Home Store  0.02
# 11     Sporting Goods Shop  0.02
#
#
# ----Harbourfront East, Union Station, Toronto Islands----
#                   venue  freq
# 0              Aquarium  0.06
# 1           Coffee Shop  0.04
# 2        Scenic Lookout  0.04
# 3                 Hotel  0.04
# 4           Pizza Place  0.04
# 5                 Plaza  0.04
# 6                  Park  0.04
# 7                  Café  0.04
# 8            Sports Bar  0.02
# 9   Sporting Goods Shop  0.02
# 10  Fried Chicken Joint  0.02
# 11              Brewery  0.02
#
#
# ----High Park, The Junction South----
#                      venue  freq
# 0          Thai Restaurant  0.08
# 1                     Café  0.08
# 2       Mexican Restaurant  0.08
# 3                   Bakery  0.04
# 4               Restaurant  0.04
# 5   Furniture / Home Store  0.04
# 6                Bookstore  0.04
# 7                      Bar  0.04
# 8                Speakeasy  0.04
# 9     Fast Food Restaurant  0.04
# 10             Music Venue  0.04
# 11      Italian Restaurant  0.04
#
#
# ----India Bazaar, The Beaches West----
#                    venue  freq
# 0   Fast Food Restaurant  0.05
# 1      Fish & Chips Shop  0.05
# 2          Burrito Place  0.05
# 3          Movie Theater  0.05
# 4     Italian Restaurant  0.05
# 5                    Pub  0.05
# 6           Intersection  0.05
# 7             Steakhouse  0.05
# 8             Restaurant  0.05
# 9            Coffee Shop  0.05
# 10        Ice Cream Shop  0.05
# 11          Liquor Store  0.05
#
#
# ----Kensington Market, Chinatown, Grange Park----
#                             venue  freq
# 0                            Café  0.10
# 1                             Bar  0.08
# 2   Vegetarian / Vegan Restaurant  0.06
# 3                          Bakery  0.04
# 4                     Coffee Shop  0.04
# 5              Mexican Restaurant  0.04
# 6                    Burger Joint  0.04
# 7           Vietnamese Restaurant  0.04
# 8                     Fish Market  0.02
# 9                  Farmers Market  0.02
# 10            Filipino Restaurant  0.02
# 11                     Food Court  0.02
#
#
# ----Lawrence Park----
#                         venue  freq
# 0                        Park  0.25
# 1                    Bus Line  0.25
# 2            Business Service  0.25
# 3                 Swim School  0.25
# 4                 Yoga Studio  0.00
# 5         Monument / Landmark  0.00
# 6                      Market  0.00
# 7         Martial Arts School  0.00
# 8    Mediterranean Restaurant  0.00
# 9                 Men's Store  0.00
# 10         Mexican Restaurant  0.00
# 11  Middle Eastern Restaurant  0.00
#
#
# ----Little Portugal, Trinity----
#                             venue  freq
# 0                             Bar  0.12
# 1   Vegetarian / Vegan Restaurant  0.05
# 2                Asian Restaurant  0.05
# 3                     Men's Store  0.05
# 4                      Restaurant  0.05
# 5                            Café  0.05
# 6           Vietnamese Restaurant  0.05
# 7                           Diner  0.02
# 8         New American Restaurant  0.02
# 9                     Coffee Shop  0.02
# 10                   Cocktail Bar  0.02
# 11                           Park  0.02
#
#
# ----Moore Park, Summerhill East----
#                          venue  freq
# 0                   Restaurant   1.0
# 1                  Yoga Studio   0.0
# 2          Moroccan Restaurant   0.0
# 3             Malay Restaurant   0.0
# 4                       Market   0.0
# 5          Martial Arts School   0.0
# 6     Mediterranean Restaurant   0.0
# 7                  Men's Store   0.0
# 8           Mexican Restaurant   0.0
# 9    Middle Eastern Restaurant   0.0
# 10          Miscellaneous Shop   0.0
# 11  Modern European Restaurant   0.0
#
#
# ----North Toronto West, Lawrence Park----
#                    venue  freq
# 0            Coffee Shop  0.11
# 1         Clothing Store  0.11
# 2            Yoga Studio  0.06
# 3    Sporting Goods Shop  0.06
# 4         Ice Cream Shop  0.06
# 5   Fast Food Restaurant  0.06
# 6     Mexican Restaurant  0.06
# 7                  Diner  0.06
# 8                   Park  0.06
# 9     Chinese Restaurant  0.06
# 10            Restaurant  0.06
# 11                  Café  0.06
#
#
# ----Parkdale, Roncesvalles----
#                           venue  freq
# 0                Breakfast Spot  0.14
# 1                     Gift Shop  0.14
# 2                   Coffee Shop  0.07
# 3   Eastern European Restaurant  0.07
# 4                           Bar  0.07
# 5                       Dog Run  0.07
# 6                 Movie Theater  0.07
# 7            Italian Restaurant  0.07
# 8                  Dessert Shop  0.07
# 9                     Bookstore  0.07
# 10                   Restaurant  0.07
# 11             Cuban Restaurant  0.07
#
#
# ----Queen's Park, Ontario Provincial Government----
#                   venue  freq
# 0           Coffee Shop  0.18
# 1      Sushi Restaurant  0.06
# 2           Yoga Studio  0.03
# 3                  Café  0.03
# 4              Beer Bar  0.03
# 5   Fried Chicken Joint  0.03
# 6                   Spa  0.03
# 7         Burrito Place  0.03
# 8    Mexican Restaurant  0.03
# 9        Sandwich Place  0.03
# 10                 Bank  0.03
# 11          Music Venue  0.03
#
#
# ----Regent Park, Harbourfront----
#                   venue  freq
# 0           Coffee Shop  0.16
# 1                   Pub  0.07
# 2                Bakery  0.07
# 3                  Park  0.07
# 4        Breakfast Spot  0.05
# 5               Theater  0.05
# 6                  Café  0.05
# 7            Restaurant  0.05
# 8           Event Space  0.02
# 9        Chocolate Shop  0.02
# 10         Dessert Shop  0.02
# 11  Distribution Center  0.02
#
#
# ----Richmond, Adelaide, King----
#                    venue  freq
# 0            Coffee Shop  0.10
# 1                   Café  0.08
# 2             Steakhouse  0.04
# 3            Pizza Place  0.04
# 4           Concert Hall  0.04
# 5    American Restaurant  0.04
# 6             Restaurant  0.04
# 7        Thai Restaurant  0.04
# 8              Speakeasy  0.02
# 9              Bookstore  0.02
# 10  Brazilian Restaurant  0.02
# 11                Lounge  0.02
#
#
# ----Rosedale----
#                         venue  freq
# 0                        Park  0.50
# 1                  Playground  0.25
# 2                       Trail  0.25
# 3                 Yoga Studio  0.00
# 4         Monument / Landmark  0.00
# 5            Malay Restaurant  0.00
# 6                      Market  0.00
# 7         Martial Arts School  0.00
# 8    Mediterranean Restaurant  0.00
# 9                 Men's Store  0.00
# 10         Mexican Restaurant  0.00
# 11  Middle Eastern Restaurant  0.00
#
#
# ----Roselawn----
#                         venue  freq
# 0                        Pool  0.33
# 1                      Garden  0.33
# 2                Home Service  0.33
# 3                 Yoga Studio  0.00
# 4         Moroccan Restaurant  0.00
# 5            Malay Restaurant  0.00
# 6                      Market  0.00
# 7         Martial Arts School  0.00
# 8    Mediterranean Restaurant  0.00
# 9                 Men's Store  0.00
# 10         Mexican Restaurant  0.00
# 11  Middle Eastern Restaurant  0.00
#
#
# ----Runnymede, Swansea----
#                  venue  freq
# 0                 Café  0.09
# 1          Coffee Shop  0.09
# 2          Pizza Place  0.06
# 3     Sushi Restaurant  0.06
# 4   Italian Restaurant  0.06
# 5                  Pub  0.06
# 6           Comic Shop  0.03
# 7        Burrito Place  0.03
# 8              Butcher  0.03
# 9       Sandwich Place  0.03
# 10          Restaurant  0.03
# 11         Yoga Studio  0.03
#
#
# ----St. James Town----
#                       venue  freq
# 0                      Café  0.10
# 1            Cosmetics Shop  0.06
# 2               Coffee Shop  0.06
# 3                 Gastropub  0.06
# 4                    Bakery  0.04
# 5                      Park  0.04
# 6        Seafood Restaurant  0.04
# 7                  Creperie  0.04
# 8            Farmers Market  0.04
# 9                 Jazz Club  0.02
# 10                 Beer Bar  0.02
# 11  New American Restaurant  0.02
#
#
# ----St. James Town, Cabbagetown----
#                  venue  freq
# 0          Coffee Shop  0.09
# 1           Restaurant  0.05
# 2               Bakery  0.05
# 3          Pizza Place  0.05
# 4    Convenience Store  0.05
# 5   Italian Restaurant  0.05
# 6                  Pub  0.05
# 7                 Café  0.05
# 8       Sandwich Place  0.02
# 9         Liquor Store  0.02
# 10         Snack Place  0.02
# 11       Deli / Bodega  0.02
#
#
# ----Stn A PO Boxes----
#                   venue  freq
# 0                  Café  0.06
# 1           Coffee Shop  0.04
# 2           Cheese Shop  0.04
# 3              Beer Bar  0.04
# 4              Creperie  0.04
# 5    Seafood Restaurant  0.04
# 6                   Pub  0.04
# 7            Restaurant  0.04
# 8                Bakery  0.04
# 9   Japanese Restaurant  0.04
# 10         Cocktail Bar  0.04
# 11       Farmers Market  0.04
#
#
# ----Studio District----
#                         venue  freq
# 0                 Coffee Shop  0.08
# 1                     Brewery  0.05
# 2                      Bakery  0.05
# 3                   Gastropub  0.05
# 4         American Restaurant  0.05
# 5                        Café  0.05
# 6          Seafood Restaurant  0.03
# 7                   Bookstore  0.03
# 8                        Food  0.03
# 9                 Fish Market  0.03
# 10  Middle Eastern Restaurant  0.03
# 11             Clothing Store  0.03
#
#
# ----Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park----
#                     venue  freq
# 0             Coffee Shop  0.14
# 1              Restaurant  0.07
# 2        Sushi Restaurant  0.07
# 3     Fried Chicken Joint  0.07
# 4              Bagel Shop  0.07
# 5             Supermarket  0.07
# 6                     Pub  0.07
# 7                    Bank  0.07
# 8     American Restaurant  0.07
# 9      Light Rail Station  0.07
# 10           Liquor Store  0.07
# 11  Vietnamese Restaurant  0.07
#
#
# ----The Annex, North Midtown, Yorkville----
#                         venue  freq
# 0              Sandwich Place  0.16
# 1                        Café  0.16
# 2                 Coffee Shop  0.11
# 3                 Pizza Place  0.05
# 4                         Pub  0.05
# 5                    Pharmacy  0.05
# 6   Middle Eastern Restaurant  0.05
# 7                Burger Joint  0.05
# 8                Liquor Store  0.05
# 9                  Donut Shop  0.05
# 10          Indian Restaurant  0.05
# 11                  BBQ Joint  0.05
#
#
# ----The Beaches----
#                         venue  freq
# 0           Health Food Store  0.25
# 1                       Trail  0.25
# 2                         Pub  0.25
# 3                 Yoga Studio  0.00
# 4         Moroccan Restaurant  0.00
# 5            Malay Restaurant  0.00
# 6                      Market  0.00
# 7         Martial Arts School  0.00
# 8    Mediterranean Restaurant  0.00
# 9                 Men's Store  0.00
# 10         Mexican Restaurant  0.00
# 11  Middle Eastern Restaurant  0.00
#
#
# ----The Danforth West, Riverdale----
#                      venue  freq
# 0         Greek Restaurant  0.17
# 1       Italian Restaurant  0.07
# 2              Coffee Shop  0.07
# 3   Furniture / Home Store  0.05
# 4           Ice Cream Shop  0.05
# 5              Yoga Studio  0.02
# 6          Bubble Tea Shop  0.02
# 7       Frozen Yogurt Shop  0.02
# 8                Juice Bar  0.02
# 9                      Spa  0.02
# 10               Bookstore  0.02
# 11                 Brewery  0.02
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                   venue  freq
# 0                  Café  0.12
# 1           Coffee Shop  0.12
# 2    Seafood Restaurant  0.06
# 3            Restaurant  0.06
# 4                 Hotel  0.06
# 5                Bakery  0.04
# 6             Gastropub  0.04
# 7   Japanese Restaurant  0.04
# 8              Beer Bar  0.02
# 9                   Bar  0.02
# 10   Mexican Restaurant  0.02
# 11   Basketball Stadium  0.02
#
#
# ----University of Toronto, Harbord----
#                   venue  freq
# 0                  Café  0.15
# 1                Bakery  0.06
# 2        Sandwich Place  0.06
# 3             Bookstore  0.06
# 4                   Bar  0.06
# 5               Theater  0.06
# 6   Japanese Restaurant  0.06
# 7    Italian Restaurant  0.03
# 8     French Restaurant  0.03
# 9            Beer Store  0.03
# 10             Beer Bar  0.03
# 11           Restaurant  0.03

# %%
# Creamos una funcion para ordenar en forma descendente los lugares

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# mostramos los primeros 12 lugares de cada barrio en un Dataframe nuevo

num_top_venues = 12

indicators = ['st', 'nd', 'rd']

# crear las columnas acorde al numero de sitios populares
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# crear un nuevo dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = Toronto_grouped['Neighborhood']

for ind in np.arange(Toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(Toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1       Brockton, Parkdale Village, Exhibition Place                  Café
# 2  Business reply mail Processing Centre, South C...    Light Rail Station
# 3  CN Tower, King and Spadina, Railway Lands, Har...       Airport Service
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0              Beer Bar        Farmers Market                Bakery
# 1        Breakfast Spot                Bakery           Coffee Shop
# 2           Pizza Place  Gym / Fitness Center        Farmers Market
# 3      Airport Terminal           Coffee Shop       Harbor / Marina
# 4        Sandwich Place                  Café    Italian Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0          Cocktail Bar    Seafood Restaurant           Cheese Shop
# 1          Climbing Gym         Burrito Place             Nightclub
# 2         Auto Workshop            Restaurant                   Spa
# 3                 Plane   Rental Car Location      Sculpture Garden
# 4       Bubble Tea Shop           Yoga Studio          Burger Joint
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 0            Restaurant        Clothing Store                    Pub
# 1            Restaurant    Italian Restaurant           Intersection
# 2         Burrito Place               Butcher   Fast Food Restaurant
# 3              Boutique                   Bar          Boat or Ferry
# 4     Indian Restaurant        Discount Store              Bookstore
#
#   11th Most Common Venue 12th Most Common Venue
# 0                  Hotel                 Bistro
# 1                    Bar                Stadium
# 2             Comic Shop             Skate Park
# 3     Airport Food Court         Airport Lounge
# 4                  Diner            Salad Place

# %%
# establecer el número de agrupaciones en 5
kclusters = 5

Toronto_grouped_clustering = Toronto_grouped.drop('Neighborhood', 1)

# ejecutar k-means
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(Toronto_grouped_clustering)

# revisar las etiquetas de las agrupaciones generadas para cada fila del dataframe
kmeans.labels_[0:5]
# Out:
# array([0, 0, 3, 3, 0], dtype=int32)

# %%
# añadir etiquetas
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

Toronto_merged = Tor_d

# juntar Toronto_grouped con Toronto_data 
Toronto_merged = Toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
Toronto_merged['Cluster Labels'] = Toronto_merged['Cluster Labels'].fillna("0").astype(int)


Toronto_merged.head() # revisar las ultimas columnas
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.654260 -79.360636               0           Coffee Shop
# 1  43.662301 -79.389494               0           Coffee Shop
# 2  43.657162 -79.378937               0           Coffee Shop
# 3  43.651494 -79.375418               0                  Café
# 4  43.676357 -79.293031               3                 Trail
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0                   Pub                Bakery                  Park
# 1      Sushi Restaurant           Yoga Studio     College Cafeteria
# 2                  Café        Clothing Store             Bookstore
# 3             Gastropub        Cosmetics Shop           Coffee Shop
# 4     Health Food Store                   Pub             Wine Shop
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Restaurant        Breakfast Spot                  Café
# 1                   Spa         Smoothie Shop              Beer Bar
# 2      Ramen Restaurant               Theater        Cosmetics Shop
# 3    Seafood Restaurant                  Park                Bakery
# 4          Cupcake Shop   Dumpling Restaurant            Donut Shop
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 0               Theater             Wine Shop         Farmers Market
# 1        Sandwich Place         Burrito Place                   Café
# 2  Fast Food Restaurant        Sandwich Place          Burrito Place
# 3              Creperie        Farmers Market           Cocktail Bar
# 4      Doner Restaurant               Dog Run    Distribution Center
#
#   11th Most Common Venue     12th Most Common Venue
# 0  Performing Arts Venue         Mexican Restaurant
# 1     College Auditorium                Music Venue
# 2          Shopping Mall                      Hotel
# 3       Department Store  Middle Eastern Restaurant
# 4         Discount Store                      Diner

# %%
# creamos mapa de agrupacion
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# establecer el esquema de color para las agrupaciones
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# añadir marcadores al mapa
markers_colors = []
for lat, lon, poi, cluster in zip(Toronto_merged['Latitude'], Toronto_merged['Longitude'], Toronto_merged['Neighborhood'], Toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_8ceb7b93207b4249a05d59583d244275%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_8ceb7b93207b4249a05d59583d244275%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_8ceb7b93207b4249a05d59583d244275%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_8ceb7b93207b4249a05d59583d244275%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B43.6534817%2C-79.3839347%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %%
# Examinamos las agrupaciones pudiendo observar que categorias distinguen a cada agrupacion

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 0, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 0                           Regent Park, Harbourfront               0
# 1         Queen's Park, Ontario Provincial Government               0
# 2                            Garden District, Ryerson               0
# 3                                      St. James Town               0
# 5                                         Berczy Park               0
# 6                                  Central Bay Street               0
# 7                                            Christie               0
# 8                            Richmond, Adelaide, King               0
# 13           Toronto Dominion Centre, Design Exchange               0
# 14       Brockton, Parkdale Village, Exhibition Place               0
# 16                     Commerce Court, Victoria Hotel               0
# 17                                    Studio District               0
# 23                  North Toronto West, Lawrence Park               0
# 24                The Annex, North Midtown, Yorkville               0
# 27                     University of Toronto, Harbord               0
# 28                                 Runnymede, Swansea               0
# 30          Kensington Market, Chinatown, Grange Park               0
# 31  Summerhill West, Rathnelly, South Hill, Forest...               0
# 34                                     Stn A PO Boxes               0
# 35                        St. James Town, Cabbagetown               0
# 36             First Canadian Place, Underground city               0
#
#    1st Most Common Venue 2nd Most Common Venue          3rd Most Common Venue  \
# 0            Coffee Shop                   Pub                         Bakery
# 1            Coffee Shop      Sushi Restaurant                    Yoga Studio
# 2            Coffee Shop                  Café                 Clothing Store
# 3                   Café             Gastropub                 Cosmetics Shop
# 5            Coffee Shop              Beer Bar                 Farmers Market
# 6            Coffee Shop        Sandwich Place                           Café
# 7          Grocery Store                  Café                           Park
# 8            Coffee Shop                  Café                   Concert Hall
# 13                  Café           Coffee Shop                          Hotel
# 14                  Café        Breakfast Spot                         Bakery
# 16                  Café                 Hotel                    Coffee Shop
# 17           Coffee Shop             Gastropub                         Bakery
# 23           Coffee Shop        Clothing Store                    Yoga Studio
# 24        Sandwich Place                  Café                    Coffee Shop
# 27                  Café               Theater                            Bar
# 28           Coffee Shop                  Café             Italian Restaurant
# 30                  Café                   Bar  Vegetarian / Vegan Restaurant
# 31           Coffee Shop   Fried Chicken Joint            American Restaurant
# 34                  Café          Cocktail Bar                         Bakery
# 35           Coffee Shop            Restaurant              Convenience Store
# 36                  Café           Coffee Shop                     Restaurant
#
#    4th Most Common Venue  5th Most Common Venue 6th Most Common Venue  \
# 0                   Park             Restaurant        Breakfast Spot
# 1      College Cafeteria                    Spa         Smoothie Shop
# 2              Bookstore       Ramen Restaurant               Theater
# 3            Coffee Shop     Seafood Restaurant                  Park
# 5                 Bakery           Cocktail Bar    Seafood Restaurant
# 6     Italian Restaurant        Bubble Tea Shop           Yoga Studio
# 7            Candy Store     Italian Restaurant            Restaurant
# 8             Steakhouse    American Restaurant           Pizza Place
# 13            Restaurant     Seafood Restaurant   Japanese Restaurant
# 14           Coffee Shop           Climbing Gym         Burrito Place
# 16                   Gym             Restaurant    Seafood Restaurant
# 17               Brewery                   Café   American Restaurant
# 23    Seafood Restaurant     Salon / Barbershop                 Diner
# 24        History Museum           Liquor Store          Burger Joint
# 27             Bookstore    Japanese Restaurant        Sandwich Place
# 28      Sushi Restaurant            Pizza Place                   Pub
# 30          Burger Joint  Vietnamese Restaurant    Mexican Restaurant
# 31      Sushi Restaurant             Bagel Shop                  Bank
# 34           Coffee Shop               Creperie           Cheese Shop
# 35           Pizza Place                   Café                Bakery
# 36    Seafood Restaurant           Concert Hall                   Gym
#
#    7th Most Common Venue 8th Most Common Venue      9th Most Common Venue  \
# 0                   Café               Theater                  Wine Shop
# 1               Beer Bar        Sandwich Place              Burrito Place
# 2         Cosmetics Shop  Fast Food Restaurant             Sandwich Place
# 3                 Bakery              Creperie             Farmers Market
# 5            Cheese Shop            Restaurant             Clothing Store
# 6           Burger Joint     Indian Restaurant             Discount Store
# 7     Athletics & Sports            Baby Store                Coffee Shop
# 8        Thai Restaurant            Restaurant     Gluten-free Restaurant
# 13                Bakery             Gastropub                   Beer Bar
# 14             Nightclub            Restaurant         Italian Restaurant
# 16             Gastropub   American Restaurant                     Bakery
# 17     Convenience Store    Seafood Restaurant                Cheese Shop
# 23                   Spa   Sporting Goods Shop                 Restaurant
# 24     Indian Restaurant             BBQ Joint  Middle Eastern Restaurant
# 27                Bakery            Restaurant                   Beer Bar
# 28            Restaurant    Falafel Restaurant              Smoothie Shop
# 30           Coffee Shop                Bakery               Cocktail Bar
# 31            Restaurant           Pizza Place                        Pub
# 34                   Pub            Restaurant        Japanese Restaurant
# 35                   Pub    Italian Restaurant             Sandwich Place
# 36         Deli / Bodega                 Hotel        American Restaurant
#
#    10th Most Common Venue   11th Most Common Venue     12th Most Common Venue
# 0          Farmers Market    Performing Arts Venue         Mexican Restaurant
# 1                    Café       College Auditorium                Music Venue
# 2           Burrito Place            Shopping Mall                      Hotel
# 3            Cocktail Bar         Department Store  Middle Eastern Restaurant
# 5                     Pub                    Hotel                     Bistro
# 6               Bookstore                    Diner                Salad Place
# 7               Nightclub                  Dog Run              Deli / Bodega
# 8        Department Store       Seafood Restaurant         Salon / Barbershop
# 13              Speakeasy                      Bar              Deli / Bodega
# 14           Intersection                      Bar                    Stadium
# 16    Japanese Restaurant            Deli / Bodega                       Park
# 17         Clothing Store                Pet Store    Comfort Food Restaurant
# 23   Fast Food Restaurant           Ice Cream Shop         Mexican Restaurant
# 24                    Pub               Donut Shop                       Park
# 27             Beer Store       Italian Restaurant                Yoga Studio
# 28    Indie Movie Theater                Bookstore             Sandwich Place
# 30     Belgian Restaurant  Comfort Food Restaurant         Italian Restaurant
# 31            Supermarket             Liquor Store         Light Rail Station
# 34               Beer Bar           Farmers Market         Seafood Restaurant
# 35          Deli / Bodega      Japanese Restaurant                    Butcher
# 36       Asian Restaurant      Japanese Restaurant             Sandwich Place

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 1, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#    Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 19     Roselawn               1                Garden                  Pool
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 19          Home Service             Wine Shop          Cupcake Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 19   Dumpling Restaurant            Donut Shop      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 19               Dog Run    Distribution Center         Discount Store
#
#    12th Most Common Venue
# 19                  Diner

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 2, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                    Neighborhood  Cluster Labels 1st Most Common Venue  \
# 29  Moore Park, Summerhill East               2            Restaurant
#
#    2nd Most Common Venue        3rd Most Common Venue 4th Most Common Venue  \
# 29    College Auditorium  Eastern European Restaurant   Dumpling Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 29            Donut Shop      Doner Restaurant               Dog Run
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 29   Distribution Center        Discount Store                  Diner
#
#    11th Most Common Venue 12th Most Common Venue
# 29           Dessert Shop       Department Store

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 3, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                          Neighborhood  Cluster Labels  \
# 4                                         The Beaches               3
# 9                        Dufferin, Dovercourt Village               3
# 10  Harbourfront East, Union Station, Toronto Islands               3
# 11                           Little Portugal, Trinity               3
# 12                       The Danforth West, Riverdale               3
# 15                     India Bazaar, The Beaches West               3
# 18                                      Lawrence Park               3
# 20                                   Davisville North               3
# 22                      High Park, The Junction South               3
# 25                             Parkdale, Roncesvalles               3
# 26                                         Davisville               3
# 32  CN Tower, King and Spadina, Railway Lands, Har...               3
# 37                               Church and Wellesley               3
# 38  Business reply mail Processing Centre, South C...               3
#
#    1st Most Common Venue  2nd Most Common Venue  \
# 4                  Trail      Health Food Store
# 9                 Bakery               Pharmacy
# 10              Aquarium         Scenic Lookout
# 11                   Bar  Vietnamese Restaurant
# 12      Greek Restaurant     Italian Restaurant
# 15                  Park      Fish & Chips Shop
# 18                  Park               Bus Line
# 20                 Hotel                    Gym
# 22    Mexican Restaurant                   Café
# 25             Gift Shop         Breakfast Spot
# 26           Pizza Place         Sandwich Place
# 32       Airport Service       Airport Terminal
# 37           Coffee Shop            Yoga Studio
# 38    Light Rail Station            Pizza Place
#
#             3rd Most Common Venue        4th Most Common Venue  \
# 4                             Pub                    Wine Shop
# 9       Middle Eastern Restaurant                  Supermarket
# 10                          Plaza                  Coffee Shop
# 11  Vegetarian / Vegan Restaurant                   Restaurant
# 12                    Coffee Shop       Furniture / Home Store
# 15                        Brewery                 Liquor Store
# 18                    Swim School             Business Service
# 20               Department Store               Sandwich Place
# 22                Thai Restaurant           Italian Restaurant
# 25               Cuban Restaurant  Eastern European Restaurant
# 26                   Dessert Shop           Italian Restaurant
# 32                    Coffee Shop              Harbor / Marina
# 37            Japanese Restaurant                      Gay Bar
# 38           Gym / Fitness Center               Farmers Market
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 4           Cupcake Shop   Dumpling Restaurant            Donut Shop
# 9                   Bank                   Bar                  Café
# 10                  Café                 Hotel                  Park
# 11                  Café      Asian Restaurant           Men's Store
# 12        Ice Cream Shop        Cosmetics Shop               Brewery
# 15         Burrito Place            Restaurant    Italian Restaurant
# 18         Deli / Bodega   Dumpling Restaurant            Donut Shop
# 20     Food & Drink Shop  Gym / Fitness Center           Pizza Place
# 22             Bookstore                   Bar             Speakeasy
# 25    Italian Restaurant                   Bar               Dog Run
# 26           Coffee Shop                  Café      Sushi Restaurant
# 32                 Plane   Rental Car Location      Sculpture Garden
# 37            Restaurant      Sushi Restaurant           Men's Store
# 38         Auto Workshop            Restaurant                   Spa
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 4       Doner Restaurant               Dog Run    Distribution Center
# 9   Gym / Fitness Center         Grocery Store            Music Venue
# 10           Pizza Place                   Bar       Baseball Stadium
# 11           Yoga Studio          Cupcake Shop                Brewery
# 12       Bubble Tea Shop            Restaurant                    Pub
# 15          Intersection                   Pub         Ice Cream Shop
# 18      Doner Restaurant               Dog Run    Distribution Center
# 20        Breakfast Spot                  Park    Distribution Center
# 22  Fast Food Restaurant             Irish Pub         Discount Store
# 25          Dessert Shop            Restaurant              Bookstore
# 26                   Gym                  Park             Restaurant
# 32              Boutique                   Bar          Boat or Ferry
# 37    Salon / Barbershop              Sake Bar           Burger Joint
# 38         Burrito Place               Butcher   Fast Food Restaurant
#
#    11th Most Common Venue 12th Most Common Venue
# 4          Discount Store                  Diner
# 9                    Park                Brewery
# 10           Skating Rink     Basketball Stadium
# 11            Pizza Place           Cocktail Bar
# 12                   Café   Caribbean Restaurant
# 15             Steakhouse   Fast Food Restaurant
# 18         Discount Store                  Diner
# 20                Dog Run         Discount Store
# 22             Restaurant            Flea Market
# 25          Movie Theater            Coffee Shop
# 26                  Diner     Seafood Restaurant
# 32     Airport Food Court         Airport Lounge
# 37      Indian Restaurant    Distribution Center
# 38             Comic Shop             Skate Park

# %%
Toronto_merged.loc[Toronto_merged['Cluster Labels'] == 4, Toronto_merged.columns[[2] + list(range(5, Toronto_merged.shape[1]))]]
# Out:
#                                        Neighborhood  Cluster Labels  \
# 21  Forest Hill North & West, Forest Hill Road Park               4
# 33                                         Rosedale               4
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 21                  Park         Jewelry Store                 Trail
# 33                  Park            Playground                 Trail
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 21      Sushi Restaurant          Dance Studio   Dumpling Restaurant
# 33          Cupcake Shop   Dumpling Restaurant            Donut Shop
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 21            Donut Shop      Doner Restaurant               Dog Run
# 33      Doner Restaurant               Dog Run   Distribution Center
#
#    10th Most Common Venue 11th Most Common Venue 12th Most Common Venue
# 21    Distribution Center         Discount Store                  Diner
# 33         Discount Store                  Diner           Dessert Shop

# %%
# !jupyter trust *.ipynb
# Out:
# Signing notebook: DS0103ES-Ejercicio-De-Los-Requerimientos-A-La-Recoleccion-py-v2.0_ES.ipynb
# Signing notebook: DS0103ES-Ejercicio-Del-Problema-al-Enfoque-v2.0_ES (2).ipynb
# Signing notebook: DV0101ES-Ejercicio-Creacion-de-Mapas-con-Python-py_ES (1).ipynb
# Signing notebook: DV0101ES-Ejercicio-Creacion-de-Mapas-con-Python-py_ES.ipynb
# Signing notebook: DV0101ES-Ejercicio-Diagramas-de-Pastel-y-Gráficos-de-Caja-Dispersión-y-Burbuja-py_ES (1).ipynb
# Signing notebook: ML0101ES-Clas-Decision-Trees-drug-py-v1.ipynb
# Signing notebook: ML0101ES-Clas-K-Nearest-neighbors-CustCat-py-v1.ipynb
# Signing notebook: ML0101ES-Clas-Logistic-Reg-churn-py-v1 (1).ipynb
# Signing notebook: ML0101ES-Clus-Hierarchical-Cars-py-v1.ipynb
# Signing notebook: ML0101ES-Reg-Mulitple-Linear-Regression-Co2-py-v1.ipynb
# Signing notebook: ML0101ES-Reg-Simple-Linear-Regression-Co2-py-v1.ipynb
# Signing notebook: ML0101ES-regresion-polinomica-Co2-py-v1_ES.ipynb
# Signing notebook: Proyecto Final DC.ipynb
# Signing notebook: TorontoFinal.ipynb
# Signing notebook: TorontoFinal2.ipynb
# Signing notebook: TorontoFinal3.ipynb
# Signing notebook: TorontoFinal33.ipynb
# Signing notebook: TorontoFinal333.ipynb
# Signing notebook: TorontoFinal333fin.ipynb
# Notebook already signed: TorontoFinal444.ipynb
# Signing notebook: Untitled.ipynb
# Signing notebook: Untitled1.ipynb
# Signing notebook: Untitled10.ipynb
# Signing notebook: Untitled11.ipynb
# Signing notebook: Untitled12.ipynb
# Signing notebook: Untitled13.ipynb
# Signing notebook: Untitled14.ipynb
# Signing notebook: Untitled15.ipynb
# Signing notebook: Untitled16.ipynb
# Signing notebook: Untitled17.ipynb
# Signing notebook: Untitled18.ipynb
# Signing notebook: Untitled19.ipynb
# Notebook already signed: Untitled2.ipynb
# Signing notebook: Untitled20.ipynb
# Signing notebook: Untitled21.ipynb
# Signing notebook: Untitled22.ipynb
# Signing notebook: Untitled23.ipynb
# [TrustNotebookApp] ERROR | Notebook JSON is invalid: Additional properties are not allowed ('execution_count' was unexpected)
#
# Failed validating 'additionalProperties' in error:
#
# On instance['cells'][4]['outputs'][0]:
# {'ename': 'ERROR',
#  'evalue': 'Error in parse(text = x, srcfile = src): <text>:1:5: unexpected '
#            '...',
#  'execution_count': 5,
#  'output_type': 'error',
#  'traceback': ['Error in parse(text = x, srcfile = src): <text>:1:5: '
#                'unexpected ...']}
# Signing notebook: Untitled24.ipynb
# Notebook already signed: Untitled3.ipynb
# Notebook already signed: Untitled4.ipynb
# Signing notebook: Untitled5.ipynb
# Signing notebook: Untitled6.ipynb
# Signing notebook: Untitled7.ipynb
# Signing notebook: Untitled8.ipynb
# Notebook already signed: Untitled9.ipynb
# Signing notebook: Vecindarios Toronto Final.ipynb
# Signing notebook: Venta-de-Casas-en-el-Condado-King-EEUU_ES.ipynb
# Signing notebook: mikibro.ipynb
